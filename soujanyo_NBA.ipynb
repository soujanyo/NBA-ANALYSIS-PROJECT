# %% [markdown]
# ## INF-510 Fall 2019 Final Project

# %% [markdown]
# 1.	**How to run the code**
#
#     **This project requires the following packages:**
#
#     pandas, numpy, requests, BeautifulSoup and Comment from bs4, csv, and matplotlib
#
#     You should be good if you are in the conda base environment, but always make sure above packages are installed.
#
#
#     **IMPORTANT**
#
#     One of the dataset used in this project called 'ori_position_2.csv' is downloaded directly from the web. Either to run the code either in the notebook or to run the .py files from command line, you have to put the 'ori_position_2.csv' file in the same directory for the code to work properly. Otherwise, it will throw an error!
#
#     'ori_position_2.csv' is in the /data folder as submission guideline required, but please make sure you put this file to where the notebook and .py file is when you are ready to test
#
#     **To Run the notebook**
#
#     just simply run the notebook.
#
#     **To Run the .py files**
#
#     In the command line, switch to the directory where the .py files reside. Type 'python3 main.py -source=remote' in the cmd so the code will grab the data from API and websites, store the raw data to the disk, get dat from the disk do modeling, and print the final visualization result. The whole process should take 1 minute depending on your network connection.
#
#     Once you have done '-source=remote', you can now try type 'python3 main.py -source=local', for which the code won’t run the web scraper, but will grab the raw data that are already stored to the disk in the previous run and do the modeling and output conclusions as well.
#
#     **Outputs you should expect**
#
#     You will see 7 csv files all with 'ori_' in the namings, including 'ori_position_2.csv' mentioned previously. These are the raw data that our program scraped from API and online. You will also see another 4 csv files all with 'position_' in the namings. They are modeled datasets that are ready for visualization. You will finally see a 'Visualization.png' file which is the visualization of this project.
#
#
#
# 2. **major “gotchas” to the code**
#
#    As what is stated in Question 7 below, in order to solve the “name conversion” problem, we combined the API data set and the downloaded static dataset and create a new one. we could probably improve my code here by creating two separate versions of datasets where one contains all players’ position information with “normal” names and the other one contains all players’ position information with names written in special characters. That would give a clearer view when merging with other data sources.
#
#
#
# 3. **What did we set out to study:**
#
#     We set out to study the change of positional dominance of NBA players in the past 20 years. People are always talking about in recent several years that the ‘Bigs’ are fading and it’s the guards’ league. We want to investigate into this subject and find out if what people saying are true and if it is true, when does it start to happen. We divided player based on the position on court into guards, forwards and center. We look at the change of field goal attempted per game, usage percentage per game, salary and draft expected value based on 3 positions over the year. We wanted to find the trend through the graph we created in the last step.
#
#     MINOR CHANGE TO MILESTONE 1: We originally put guards and forwards in 1 category and centers in another. As the project progressing, we decided to put forwards into its own category to make it more intuitive and reasonable.
#
#
#
# 4. **conclusions:**
#
#     The original assumption is partially confirmed as the result shows that it is the guards that are dominating the league in recent years and centers faded. However, since 1998, centers were already not as dominant as guards and forwards, and their dominance was dropping during the year 2000 to 2008 period. Centers are making a small comeback after year 2008 and 2009, but they are still down. An interesting finding is that forwards were at the level with guards before around year 2008 but started to go down after that time and on the same dominance level as centers till today.
#
#
#
# 5. **difficulties**
#
#     We were struggling at getting enough player’s position data from the API. When we were testing the API at milestone 1, we thought it was working fine as it returned players name with their position, but when we started to retrieve the 20 years players information, there are a lot of players with empty values in the position column. We had to scrape data from other places to make up the missing values.
#
#     Another difficulty is that some player names contain special characters such as “Toni Kukoč”, which is written as “Toni Kukoc” in the salary data source. Therefore, we have a hard time mapping these player names. Solution to the problem is that the player position dataset we downloaded from Basketball-Reference has player names contain special characters which helps to merge with three other datasets: FGA, USG, and draft; while the API data contains “normal” versions of player names that easily map the salary dataset. In this case, after combining the API data set and the downloaded static data set, and creating a new data set, when we merge it with other datasets using Pandas data frames, it automatically maps the version of names that the other data sources share.
#
#
#
# 6. **What would we do “next” to expand or augment the project:**
#
#     We can add more relevant metrics to the analysis to further concrete the conclusion. We should devise an appropriate weighting method to put all the metrics together in one graph to get a conclusive trend. We can also extend the years of selection to 50 years and see the change in this long period. Since we’ve had the conclusion in this project, we can further dive into it and see what the reason is that caused this dominance change.

# %% [markdown]
# ### Access the data
#
# This module will scrape data from multiple websites and pass to lists

# %%
import requests
from bs4 import BeautifulSoup, Comment


## Build scrapers and API crawlers to create functions 
## Retrieve URLs with parameters pages/years, return the corresponding soup objects 
def url_to_soup_API():
    
    API_url = 'https://www.fantasybasketballnerd.com/service/players'
    API_response = requests.get(API_url)
    position_soup = BeautifulSoup(API_response.content, 'lxml')
    
    return position_soup


def url_to_soup_FGA(year):
    
    FGA_url = f'https://www.basketball-reference.com/leagues/NBA_{year + 1}_per_game.html'
    
    try:
        FGA_response = requests.get(FGA_url)
        FGA_response.raise_for_status()
          
    except requests.exceptions.HTTPError as e:
        print(e)
        return None
    
    FGA_soup = BeautifulSoup(FGA_response.content, 'lxml')
    
    return FGA_soup
    

def url_to_soup_USG(year):
    
    USG_url = f'https://www.basketball-reference.com/leagues/NBA_{year + 1}_advanced.html'

    try:
        USG_response = requests.get(USG_url)
        USG_response.raise_for_status()
          
    except requests.exceptions.HTTPError as e:
        print(e)
        return None
    
    USG_soup = BeautifulSoup(USG_response.content, 'lxml')
    
    return USG_soup
    
    
def url_to_soup_salary(year_start, year_end):
    
    salary_url = f'https://hoopshype.com/salaries/players/{year_start}-{year_end}/'
    
    if type(year_start) == int and type(year_end) == int: 
        if year_start >= 1998 and year_start <= 2018 and year_end >= 1999 and year_end <= 2019 and year_end - year_start == 1:        
            salary_response = requests.get(salary_url)
        else:
            print('Year number out of range!')
            return None 
    else:
        print('Year number accepts integer only!')
        return None 
    
    salary_soup = BeautifulSoup(salary_response.content, 'lxml')
    
    return salary_soup


def url_to_soup_draft(year):
    
    draft_url = f'https://www.basketball-reference.com/draft/NBA_{year}.html'
    
    try:
        draft_response = requests.get(draft_url)
        draft_response.raise_for_status()
          
    except requests.exceptions.HTTPError as e:
        print(e)
        return None
    
    draft_soup = BeautifulSoup(draft_response.content, 'lxml')
    
    return draft_soup


def url_to_soup_EV():
    
    EV_url = 'https://www.basketball-reference.com/draft/preview.html'
    EV_response = requests.get(EV_url)
    EV_soup = BeautifulSoup(EV_response.content, 'lxml')
            
    return EV_soup

    
## Transfer soup objects into data structures
def soup_API_to_list(position_soup):
    
    position_record = []
    name = []
    position = []
    
    main_table = position_soup.find_all('player')
    
    for player in main_table:
        player_name = player.find('name').text
        player_position = player.find('position').text
        
        name.append(player_name)
        position.append(player_position)
       
    for i in range(len(name)):
        position_record.append((name[i], position[i]))
        
    return position_record


def soup_FGA_to_list(FGA_soup):
    
    FGA_record_old = []
    name = []
    FGA = []
    games_played = []
    minutes_played_per_game = []
    
    main_table = FGA_soup.find('table', {'id': 'per_game_stats'})
    
    for player in main_table.find_all('tr')[1:]:
        if len(player.find_all('td')) > 0:
            ## player name
            player_name = player.find_all('td')[0].text.strip('*')
            ## player FGA
            player_FGA = player.find_all('td')[8].text
            ## player total games played
            player_GP = player.find_all('td')[4].text
            ## player minutes played per game 
            player_MP = player.find_all('td')[6].text
            
            name.append(player_name)
            FGA.append(player_FGA)
            games_played.append(player_GP)
            minutes_played_per_game.append(player_MP)
                
    for i in range(len(name)):
        FGA_record_old.append((name[i], FGA[i], games_played[i], minutes_played_per_game[i]))
       
    name_no_repeat = [i for n, i in enumerate(name) if i not in name[:n]]
    FGA_record = []
    
    for item in name_no_repeat:
        index = name.index(item)
        FGA_record.append(FGA_record_old[index])
    
    return FGA_record


def soup_USG_to_list(USG_soup):
    
    USG_record_old = []
    name = []
    USG = []
    games_played = []
    minutes_played = []

    main_table = USG_soup.find('table', {'id': 'advanced_stats'})

    for player in main_table.find_all('tr')[1:]:
        if len(player.find_all('td')) > 0:
            ## player name
            player_name = player.find_all('td')[0].text.strip('*')
            ## player USG%
            player_USG = player.find_all('td')[17].text
            ## player total games played
            player_GP = player.find_all('td')[4].text
            ## player total minutes played 
            player_MP = player.find_all('td')[5].text
            
            name.append(player_name)
            USG.append(player_USG)
            games_played.append(player_GP)
            minutes_played.append(player_MP)
    
    for i in range(len(name)):
        USG_record_old.append((name[i], USG[i], games_played[i], minutes_played[i]))
    
    name_no_repeat = [i for n, i in enumerate(name) if i not in name[:n]]
    USG_record = []
    
    for item in name_no_repeat:
        index = name.index(item)
        USG_record.append(USG_record_old[index])
       
    return USG_record


def soup_salary_to_list(salary_soup):
    
    salary_record = []
    name = []
    salary = []
    
    main_table = salary_soup.find('table', {'class': 'hh-salaries-ranking-table hh-salaries-table-sortable responsive'})

    for player in main_table.find_all('tr')[1:]:
        if len(player.find_all('td')) > 0:
            ## player name
            player_name = player.find_all('td')[1].find('a').text.strip()
            ## player salary
            player_salary = player.find_all('td')[2].get('data-value')
            
            name.append(player_name)
            salary.append(player_salary)
    
    for i in range(len(name)):
        salary_record.append((name[i], salary[i]))
    
    return salary_record
      
    
def soup_draft_to_list(draft_soup):
    
    draft_record = []
    Pk = []
    name = []
    
    
    main_table = draft_soup.find('table', {'id': 'stats'})
    
    for player in main_table.find_all('tr'):
        if (len(player.find_all('td')) > 2):
            ## player pick rank
            player_Pk = player.find_all('td')[0].get('csk')
            ## player name 
            player_name = player.find_all('td')[2].text
                
            Pk.append(player_Pk)
            name.append(player_name)
            
                   
    for i in range(len(Pk)):
        draft_record.append((Pk[i], name[i]))
    
    return draft_record


def soup_EV_to_list(EV_soup):
    
    EV_record = []
    Pk = []
    EV = []
      
    comments = EV_soup.find_all(string = lambda text: isinstance(text, Comment))

    for comment in comments:
        if comment.find("table") > 0:
            EV_soup = BeautifulSoup(comment, 'lxml')
            main_table = EV_soup.find('table', {'id': 'picks'})
            if main_table == None:
                break
            else:
                for player in main_table.find_all('tr')[1:]:
                    if len(player.find_all('td')) > 0:
                        ## player pick rank 
                        player_Pk = player.find_all('td')[0].text
                        ## pick's expected value 
                        pick_EV = player.find_all('td')[2].text
            
                        Pk.append(player_Pk)
                        EV.append(pick_EV)
    
    for i in range(len(Pk)):
        EV_record.append((Pk[i], EV[i]))
    
    return EV_record


## Collect each data set individually 
def position():
    
    position_records = []
    
    
    position_soup = url_to_soup_API()
    position_record = soup_API_to_list(position_soup)    
    position_records = [list(record) for record in position_record]
    #print(len(position_records))
    
    return position_records


def FGA():
    
    FGA_records = []
    
    for year in range(1998, 2019):
        FGA_soup = url_to_soup_FGA(year)
        FGA_record = soup_FGA_to_list(FGA_soup)
        
        for item in FGA_record:
            item += (year,)
            FGA_records.append(item)
    
    FGA_records = [list(FGA_record) for FGA_record in FGA_records]
    #print(len(FGA_records))
      
    return FGA_records


def USG():
    
    USG_records = []
    
    for year in range(1998, 2019):
        USG_soup = url_to_soup_USG(year)
        USG_record = soup_USG_to_list(USG_soup)
        
        for item in USG_record:
            item += (year,)
            USG_records.append(item)
    
    USG_records = [list(USG_record) for USG_record in USG_records]
    #print(len(USG_records))
      
    return USG_records


def salary(): 
    
    salary_records = []
    
    for year in range(1998, 2019):
        salary_soup = url_to_soup_salary(year, year + 1)
        salary_record = soup_salary_to_list(salary_soup)
        
        for item in salary_record:
            item += (year,)
            salary_records.append(item)
    
    salary_records = [list(salary_record) for salary_record in salary_records]
    #print(len(salary_records))
      
    return salary_records


def draft():
    
    draft_records = []
    
    for year in range(1998, 2019):
        draft_soup = url_to_soup_draft(year)
        draft_record = soup_draft_to_list(draft_soup)
        
        for item in draft_record:
            item += (year,)
            draft_records.append(item)
    
    draft_records = [list(draft_record) for draft_record in draft_records]
    #print(len(draft_records))
      
    return draft_records


def EV():
    
    EV_records = []
    
    EV_soup = url_to_soup_EV()
    EV_record = soup_EV_to_list(EV_soup)
    EV_records = [list(record) for record in EV_record]
    #print(len(EV_record))
    
    return EV_records


## Driver function that collect all information from 1998 to 2018
def scrape_all():

    NBA_records = [position(), FGA(), USG(), salary(), draft(), EV()]
    
    return NBA_records

records = scrape_all()

# %% [markdown]
# #### Print out all the lists here and simply investigate and see if we got the data we want

# %%
position()
# Out:
# [['Avery Bradley', 'SG'],
#  ['Jaylen Brown', 'SF'],
#  ['Jae Crowder', 'PF'],
#  ['Gerald Green', 'SF'],
#  ['Al Horford', 'C'],
#  ['R.J. Hunter', 'SG'],
#  ['Demetrius Jackson', 'PG'],
#  ['Jonas Jerebko', 'PF'],
#  ['Amir Johnson', 'C'],
#  ['Jalen Jones', 'PF'],
#  ['Damion Lee', 'SF'],
#  ['Jordan Mickey', 'C'],
#  ['Kelly Olynyk', 'C'],
#  ['Terry Rozier', 'SG'],
#  ['Marcus Smart', 'SG'],
#  ['Isaiah Thomas', 'PG'],
#  ['James Young', 'SG'],
#  ['Tyler Zeller', 'C'],
#  ['Anthony Bennett', 'PF'],
#  ['Bojan Bogdanovic', 'PF'],
#  ['Trevor Booker', 'PF'],
#  ['Randy Foye', 'SG'],
#  ['Jorge Gutierrez', 'PG'],
#  ['Joe Harris', 'SG'],
#  ['Rondae Hollis-Jefferson', 'C'],
#  ['Sean Kilpatrick', 'SG'],
#  ['Caris LeVert', 'SF'],
#  ['Jeremy Lin', 'PG'],
#  ['Brook Lopez', 'C'],
#  ['Chris McCullough', 'PF'],
#  ['Isaiah Whitehead', 'SG'],
#  ['Carmelo Anthony', 'PF'],
#  ['Ron Baker', 'SG'],
#  ['Willy Hernangomez', 'C'],
#  ['Justin Holiday', 'SF'],
#  ['Brandon Jennings', 'PG'],
#  ['Mindaugas Kuzminskas', 'SF'],
#  ['Courtney Lee', 'SF'],
#  ['Joakim Noah', 'C'],
#  ["Kyle O'Quinn", 'C'],
#  ['Marshall Plumlee', 'C'],
#  ['Kristaps Porzingis', 'C'],
#  ['Chasson Randle', 'PG'],
#  ['Derrick Rose', 'SG'],
#  ['Lance Thomas', 'PF'],
#  ['Jerryd Bayless', 'PG'],
#  ['Robert Covington', 'PF'],
#  ['Joel Embiid', 'C'],
#  ['Jerami Grant', 'C'],
#  ['Richaun Holmes', 'C'],
#  ['Shawn Long', 'PF'],
#  ['Timothe Luwawu-Cabarrot', 'SG'],
#  ['T.J. McConnell', 'PG'],
#  ['Nerlens Noel', 'C'],
#  ['Jahlil Okafor', 'C'],
#  ['Brandon Paul', 'SF'],
#  ['Dario Saric', 'PF'],
#  ['Ben Simmons', 'PG'],
#  ['Nik Stauskas', 'SG'],
#  ['James Webb III', 'SF'],
#  ['Bruno Caboclo', 'C'],
#  ['DeMarre Carroll', 'PF'],
#  ['DeMar DeRozan', 'SF'],
#  ['Cory Joseph', 'SG'],
#  ['Kyle Lowry', 'PG'],
#  ['Lucas Nogueira', 'C'],
#  ['Patrick Patterson', 'C'],
#  ['Jakob Poeltl', 'C'],
#  ['Norman Powell', 'SF'],
#  ['Terrence Ross', 'SF'],
#  ['Pascal Siakam', 'C'],
#  ['Jonas Valanciunas', 'C'],
#  ['Delon Wright', 'PG'],
#  ['Jimmy Butler', 'SF'],
#  ['Isaiah Canaan', 'PG'],
#  ['Spencer Dinwiddie', 'SG'],
#  ['Cristiano Felicio', 'C'],
#  ['Taj Gibson', 'C'],
#  ['Jerian Grant', 'PG'],
#  ['Vince Hunter', 'SF'],
#  ['Robin Lopez', 'C'],
#  ['Doug McDermott', 'PF'],
#  ['Nikola Mirotic', 'PF'],
#  ['Bobby Portis', 'C'],
#  ['Rajon Rondo', 'PG'],
#  ['Tony Snell', 'SF'],
#  ['Denzel Valentine', 'SF'],
#  ['Dwyane Wade', 'SG'],
#  ['Paul Zipser', 'SF'],
#  ['Markel Brown', 'SG'],
#  ['Kay Felder', 'PG'],
#  ['Channing Frye', 'PF'],
#  ['John Holland', 'SG'],
#  ['Jonathan Holmes', 'PF'],
#  ['Kyrie Irving', 'PG'],
#  ['LeBron James', 'PF'],
#  ['Richard Jefferson', 'SF'],
#  ['Dahntay Jones', 'SG'],
#  ['DeAndre Liggins', 'SG'],
#  ['Kevin Love', 'C'],
#  ['Jordan McRae', 'SG'],
#  ['Eric Moreland', 'C'],
#  ['Iman Shumpert', 'SF'],
#  ['Tristan Thompson', 'C'],
#  ['Aron Baynes', 'C'],
#  ['Lorenzo Brown', 'PG'],
#  ['Reggie Bullock', 'SF'],
#  ['Kentavious Caldwell-Pope', 'SF'],
#  ['Andre Drummond', 'C'],
#  ['Henry Ellenson', 'C'],
#  ['Michael Gbinije', 'SG'],
#  ['Tobias Harris', 'PF'],
#  ['Darrun Hilliard', 'SG'],
#  ['Reggie Jackson', 'PG'],
#  ['Stanley Johnson', 'PF'],
#  ['Jon Leuer', 'PF'],
#  ['Boban Marjanovic', 'C'],
#  ['Marcus Morris', 'PF'],
#  ['Ish Smith', 'PG'],
#  ['Lavoy Allen', 'PF'],
#  ['Aaron Brooks', 'PG'],
#  ['Monta Ellis', 'SG'],
#  ['Jeremy Evans', 'SF'],
#  ['Paul George', 'PF'],
#  ['Al Jefferson', 'C'],
#  ['C.J. Miles', 'SG'],
#  ['Georges Niang', 'PF'],
#  ['Alex Poythress', 'PF'],
#  ['Glenn Robinson III', 'SF'],
#  ['Julyan Stone', 'PG'],
#  ['Jeff Teague', 'PG'],
#  ['Myles Turner', 'C'],
#  ['Joe Young', 'PG'],
#  ['Thaddeus Young', 'PF'],
#  ['Giannis Antetokounmpo', 'PF'],
#  ['Michael Beasley', 'SF'],
#  ['Malcolm Brogdon', 'SG'],
#  ['Michael Carter-Williams', 'SG'],
#  ['Matthew Dellavedova', 'SG'],
#  ['John Henson', 'C'],
#  ['Thon Maker', 'C'],
#  ['Khris Middleton', 'SF'],
#  ['Greg Monroe', 'C'],
#  ['Jabari Parker', 'PF'],
#  ['Miles Plumlee', 'C'],
#  ['Mirza Teletovic', 'PF'],
#  ['Jason Terry', 'SG'],
#  ['Rashad Vaughn', 'SG'],
#  ['Kent Bazemore', 'SF'],
#  ['DeAndre Bembry', 'SF'],
#  ['Matt Costello', 'SF'],
#  ['Malcolm Delaney', 'PG'],
#  ['Tim Hardaway Jr.', 'SF'],
#  ['Dwight Howard', 'C'],
#  ['Kris Humphries', 'PF'],
#  ['Jarrett Jack', 'PG'],
#  ['Kyle Korver', 'SG'],
#  ['Paul Millsap', 'C'],
#  ['Mike Muscala', 'C'],
#  ['Taurean Prince', 'PF'],
#  ['Dennis Schroder', 'SG'],
#  ['Mike Scott', 'PF'],
#  ['Thabo Sefolosha', 'PF'],
#  ['Tiago Splitter', 'C'],
#  ['Walter Tavares', 'C'],
#  ['Nicolas Batum', 'SF'],
#  ['Marco Belinelli', 'SF'],
#  ['Treveon Graham', 'PF'],
#  ['Roy Hibbert', 'C'],
#  ['Frank Kaminsky III', 'C'],
#  ['Michael Kidd-Gilchrist', 'PF'],
#  ['Jeremy Lamb', 'SF'],
#  ['Ramon Sessions', 'PG'],
#  ['Kemba Walker', 'PG'],
#  ['Marvin Williams', 'PF'],
#  ['Christian Wood', 'C'],
#  ['Cody Zeller', 'C'],
#  ['Luke Babbitt', 'SF'],
#  ['Goran Dragic', 'PG'],
#  ['Wayne Ellington', 'SF'],
#  ['Udonis Haslem', 'C'],
#  ['James Johnson', 'PF'],
#  ['Tyler Johnson', 'SG'],
#  ['Rodney McGruder', 'SF'],
#  ['Josh McRoberts', 'PF'],
#  ['Willie Reed', 'C'],
#  ['Josh Richardson', 'SF'],
#  ['Beno Udrih', 'PG'],
#  ['Dion Waiters', 'SF'],
#  ['Briante Weber', 'PG'],
#  ['Okaro White', 'PF'],
#  ['Hassan Whiteside', 'C'],
#  ['Derrick Williams', 'PF'],
#  ['Justise Winslow', 'PF'],
#  ['Cliff Alexander', 'PF'],
#  ['D.J. Augustin', 'PG'],
#  ['Bismack Biyombo', 'C'],
#  ['Evan Fournier', 'SF'],
#  ['Aaron Gordon', 'PF'],
#  ['Jeff Green', 'PF'],
#  ['Mario Hezonja', 'PF'],
#  ['Serge Ibaka', 'C'],
#  ['Jodie Meeks', 'SG'],
#  ['Elfrid Payton', 'PG'],
#  ['Damjan Rudez', 'PF'],
#  ['Nikola Vucevic', 'C'],
#  ['C.J. Wilcox', 'SG'],
#  ['Stephen Zimmerman Jr.', 'C'],
#  ['Bradley Beal', 'SG'],
#  ['Trey Burke', 'SG'],
#  ['Jarell Eddie', 'SG'],
#  ['Marcin Gortat', 'C'],
#  ['Ian Mahinmi', 'C'],
#  ['Markieff Morris', 'C'],
#  ['Daniel Ochefu', 'C'],
#  ['Kelly Oubre Jr.', 'PF'],
#  ['Otto Porter Jr.', 'PF'],
#  ['Tomas Satoransky', 'SF'],
#  ['Jason Smith', 'PF'],
#  ['John Wall', 'PG'],
#  ['Darrell Arthur', 'PF'],
#  ['Will Barton', 'SF'],
#  ['Malik Beasley', 'SG'],
#  ['Wilson Chandler', 'PF'],
#  ['Kenneth Faried', 'PF'],
#  ['Danilo Gallinari', 'PF'],
#  ['Gary Harris', 'SG'],
#  ['Juancho Hernangomez', 'PF'],
#  ['Nikola Jokic', 'C'],
#  ['Emmanuel Mudiay', 'PG'],
#  ['Jamal Murray', 'SG'],
#  ['Jameer Nelson', 'PG'],
#  ['Jusuf Nurkic', 'C'],
#  ['JaKarr Sampson', 'PF'],
#  ['Jarnell Stokes', 'PF'],
#  ['Nate Wolters', 'PG'],
#  ['Cole Aldrich', 'C'],
#  ['Nemanja Bjelica', 'PF'],
#  ['Gorgui Dieng', 'C'],
#  ['Kris Dunn', 'SF'],
#  ['Tyus Jones', 'SG'],
#  ['Zach LaVine', 'SG'],
#  ['Shabazz Muhammad', 'SG'],
#  ['Adreian Payne', 'PF'],
#  ['Ricky Rubio', 'PG'],
#  ['Brandon Rush', 'SG'],
#  ['Karl-Anthony Towns', 'C'],
#  ['Andrew Wiggins', 'SF'],
#  ['Alex Abrines', 'SG'],
#  ['Steven Adams', 'C'],
#  ['Alex Caruso', 'SG'],
#  ['Semaj Christon', 'PG'],
#  ['Nick Collison', 'PF'],
#  ['Daniel Hamilton', 'SF'],
#  ['Josh Huestis', 'SG'],
#  ['Ersan Ilyasova', 'C'],
#  ['Enes Kanter', 'C'],
#  ['Joffrey Lauvergne', 'C'],
#  ['Anthony Morrow', 'SG'],
#  ['Victor Oladipo', 'PG'],
#  ['Cameron Payne', 'SG'],
#  ['Ronnie Price', 'PG'],
#  ['Andre Roberson', 'SF'],
#  ['Domantas Sabonis', 'C'],
#  ['Kyle Singler', 'SF'],
#  ['Russell Westbrook', 'PG'],
#  ['Al-Farouq Aminu', 'PF'],
#  ['Pat Connaughton', 'SF'],
#  ['Allen Crabbe', 'SF'],
#  ['Ed Davis', 'C'],
#  ['Maurice Harkless', 'PF'],
#  ['Jake Layman', 'PF'],
#  ['Meyers Leonard', 'C'],
#  ['Damian Lillard', 'PG'],
#  ['C.J. McCollum', 'SG'],
#  ['Luis Montero', 'SG'],
#  ['Shabazz Napier', 'SG'],
#  ['Mason Plumlee', 'C'],
#  ['Evan Turner', 'SF'],
#  ['Noah Vonleh', 'C'],
#  ['Joel Bolomboy', 'PF'],
#  ['Alec Burks', 'SG'],
#  ['Dante Exum', 'SG'],
#  ['Derrick Favors', 'C'],
#  ['Rudy Gobert', 'C'],
#  ['Gordon Hayward', 'PF'],
#  ['George Hill', 'PG'],
#  ['Rodney Hood', 'SG'],
#  ['Joe Ingles', 'PF'],
#  ['Chris Johnson', 'SG'],
#  ['Joe Johnson', 'SF'],
#  ['Trey Lyles', 'C'],
#  ['Shelvin Mack', 'PG'],
#  ['Raul Neto', 'PG'],
#  ['Marcus Paige', 'PG'],
#  ['Tyrone Wallace', 'PG'],
#  ['Jeff Withey', 'C'],
#  ['Ian Clark', 'SG'],
#  ['Stephen Curry', 'PG'],
#  ['Kevin Durant', 'SF'],
#  ['Draymond Green', 'C'],
#  ['Andre Iguodala', 'SG'],
#  ['Damian Jones', 'C'],
#  ['Shaun Livingston', 'PG'],
#  ['Kevon Looney', 'C'],
#  ['James Michael McAdoo', 'SF'],
#  ['Patrick McCaw', 'SF'],
#  ['JaVale McGee', 'C'],
#  ['Zaza Pachulia', 'C'],
#  ['Klay Thompson', 'SG'],
#  ['David West', 'PF'],
#  ['Alan Anderson', 'SG'],
#  ['Jamal Crawford', 'SF'],
#  ['Raymond Felton', 'PG'],
#  ['Blake Griffin', 'PF'],
#  ['Brice Johnson', 'PF'],
#  ['Wesley Johnson', 'SF'],
#  ['DeAndre Jordan', 'C'],
#  ['Luc Richard Mbah a Moute', 'PF'],
#  ['Xavier Munford', 'PG'],
#  ['Chris Paul', 'PG'],
#  ['JJ Redick', 'SF'],
#  ['Austin Rivers', 'SG'],
#  ['Marreese Speights', 'PF'],
#  ['Diamond Stone', 'C'],
#  ['Tarik Black', 'PF'],
#  ['Anthony Brown', 'SF'],
#  ['Jose Calderon', 'PG'],
#  ['Jordan Clarkson', 'SF'],
#  ['Luol Deng', 'SF'],
#  ['Brandon Ingram', 'PF'],
#  ['Timofey Mozgov', 'C'],
#  ['Larry Nance Jr.', 'C'],
#  ['Julius Randle', 'C'],
#  ['Thomas Robinson', 'PF'],
#  ["D'Angelo Russell", 'PG'],
#  ['Travis Wear', 'PF'],
#  ['Louis Williams', 'SG'],
#  ['Nick Young', 'SG'],
#  ['Ivica Zubac', 'C'],
#  ['Dragan Bender', 'C'],
#  ['Eric Bledsoe', 'PG'],
#  ['Devin Booker', 'SG'],
#  ['Tyson Chandler', 'C'],
#  ['Marquese Chriss', 'C'],
#  ['Jared Dudley', 'PF'],
#  ['Archie Goodwin', 'SG'],
#  ['Shaquille Harrison', 'SF'],
#  ['John Jenkins', 'SG'],
#  ['Derrick Jones', 'PF'],
#  ['Brandon Knight', 'SG'],
#  ['Alex Len', 'C'],
#  ['P.J. Tucker', 'C'],
#  ['Tyler Ulis', 'PG'],
#  ['T.J. Warren', 'PF'],
#  ['Alan Williams', 'PF'],
#  ['Arron Afflalo', 'SG'],
#  ['Matt Barnes', 'SF'],
#  ['Omri Casspi', 'SF'],
#  ['Willie Cauley-Stein', 'C'],
#  ['Darren Collison', 'PG'],
#  ['DeMarcus Cousins', 'C'],
#  ['Rudy Gay', 'PF'],
#  ['Kosta Koufos', 'C'],
#  ['Skal Labissiere', 'C'],
#  ['Ty Lawson', 'PG'],
#  ['Ben McLemore', 'SF'],
#  ['Georgios Papagiannis', 'C'],
#  ['Malachi Richardson', 'SG'],
#  ['Garrett Temple', 'SF'],
#  ['Anthony Tolliver', 'C'],
#  ['Quincy Acy', 'SF'],
#  ['Justin Anderson', 'PF'],
#  ['J.J. Barea', 'SG'],
#  ['Harrison Barnes', 'PF'],
#  ['Andrew Bogut', 'C'],
#  ['Nicolas Brussino', 'SF'],
#  ['Kyle Collinsworth', 'SG'],
#  ['Seth Curry', 'SG'],
#  ['Dorian Finney-Smith', 'PF'],
#  ['Jonathan Gibson', 'SG'],
#  ['A.J. Hammons', 'C'],
#  ['Devin Harris', 'PG'],
#  ['Wesley Matthews', 'SF'],
#  ['Salah Mejri', 'C'],
#  ['Dirk Nowitzki', 'PF'],
#  ['Dwight Powell', 'C'],
#  ['C.J. Williams', 'SG'],
#  ['Deron Williams', 'PG'],
#  ['Ryan Anderson', 'C'],
#  ['Trevor Ariza', 'PF'],
#  ['Patrick Beverley', 'PG'],
#  ['Corey Brewer', 'SG'],
#  ['Clint Capela', 'C'],
#  ['Sam Dekker', 'SF'],
#  ['Tyler Ennis', 'PG'],
#  ['Eric Gordon', 'SF'],
#  ['James Harden', 'SG'],
#  ['Montrezl Harrell', 'C'],
#  ['Nene Hilario', 'C'],
#  ['K.J. McDaniels', 'SG'],
#  ['Donatas Motiejunas', 'PF'],
#  ['Chinanu Onuaku', 'PF'],
#  ['Gary Payton', 'PG'],
#  ['Josh Smith', 'PF'],
#  ['Isaiah Taylor', 'PG'],
#  ['Tony Allen', 'SG'],
#  ['Wade Baldwin', 'PG'],
#  ['Vince Carter', 'PF'],
#  ['Mike Conley', 'PG'],
#  ['Troy Daniels', 'SG'],
#  ['Deyonta Davis', 'PG'],
#  ['James Ennis', 'PF'],
#  ['Marc Gasol', 'C'],
#  ['JaMychal Green', 'PF'],
#  ['Andrew Harrison', 'PG'],
#  ['Jarell Martin', 'PF'],
#  ['Chandler Parsons', 'PF'],
#  ['Zach Randolph', 'PF'],
#  ['Wayne Selden', 'SG'],
#  ['D.J. Stephens', 'SG'],
#  ['Troy Williams', 'SF'],
#  ['Brandan Wright', 'C'],
#  ['Alexis Ajinca', 'C'],
#  ['Omer Asik', 'C'],
#  ['Dante Cunningham', 'SF'],
#  ['Anthony Davis', 'C'],
#  ['Cheick Diallo', 'C'],
#  ['Tyreke Evans', 'SG'],
#  ['Tim Frazier', 'PG'],
#  ['Langston Galloway', 'SG'],
#  ['Buddy Hield', 'SF'],
#  ['Solomon Hill', 'PF'],
#  ['Jrue Holiday', 'SG'],
#  ["E'Twaun Moore", 'SF'],
#  ['Quincy Pondexter', 'SF'],
#  ['Lance Stephenson', 'SG'],
#  ['LaMarcus Aldridge', 'C'],
#  ['Kyle Anderson', 'PF'],
#  ['Joel Anthony', 'C'],
#  ['Ryan Arcidiacono', 'SG'],
#  ['Davis Bertans', 'PF'],
#  ['Dewayne Dedmon', 'C'],
#  ['Bryn Forbes', 'SG'],
#  ['Pau Gasol', 'C'],
#  ['Manu Ginobili', 'SG'],
#  ['Danny Green', 'SF'],
#  ['David Lee', 'PF'],
#  ['Kawhi Leonard', 'PF'],
#  ['Patty Mills', 'SG'],
#  ['Dejounte Murray', 'PG'],
#  ['Tony Parker', 'PG'],
#  ['Jonathon Simmons', 'SF'],
#  ['Marcus Georges-Hunt', 'SG'],
#  ['Yogi Ferrell', 'SG'],
#  ['Jarrod Uthoff', 'SF'],
#  ['Fred VanVleet', 'SG'],
#  ['J.R. Smith', 'SG'],
#  ['Josh Magette', 'PG'],
#  ['Danuel House', 'SF'],
#  ['Sheldon McClellan', 'SG'],
#  ["Johnny O'Bryant", 'C'],
#  ['Tim Quarterman', 'PG'],
#  ['Bobby Brown', 'PG'],
#  ['Kyle Wiltjer', 'PF'],
#  ['Quinn Cook', 'PG'],
#  ['Kadeem Allen', 'SG'],
#  ['Jabari Bird', 'SG'],
#  ['Shane Larkin', 'PG'],
#  ['Abdel Nader', 'SF'],
#  ['Semi Ojeleye', 'PF'],
#  ['L.J. Peak', 'SG'],
#  ['Jayson Tatum', 'PF'],
#  ['Daniel Theis', 'C'],
#  ['Andrew White III', 'SF'],
#  ['Guerschon Yabusele', 'PF'],
#  ['Jarrett Allen', 'C'],
#  ['Yakuba Ouattara', 'SG'],
#  ['Jacob Wiley', 'SF'],
#  ['Jamel Artis', 'SG'],
#  ['Damyean Dotson', 'SF'],
#  ['Nigel Hayes', 'SF'],
#  ['Ognjen Jaramaz', 'PG'],
#  ['Luke Kornet', 'C'],
#  ['Frank Ntilikina', 'PG'],
#  ['Xavier Rathan-Mayes', 'SG'],
#  ['James Blackmon Jr.', 'SG'],
#  ['Markelle Fultz', 'SG'],
#  ['Furkan Korkmaz', 'SG'],
#  ['Jacob Pullen', 'PG'],
#  ['OG Anunoby', 'PF'],
#  ['Kennedy Meeks', 'C'],
#  ['Malcolm Miller', 'SF'],
#  ['Antonio Blakeney', 'SG'],
#  ['Jaylen Johnson', 'SG'],
#  ['Lauri Markkanen', 'C'],
#  ['David Nwaba', 'SF'],
#  ['Cedi Osman', 'PF'],
#  ['Ante Zizic', 'C'],
#  ['Dwight Buycks', 'PG'],
#  ['Luke Kennard', 'SF'],
#  ['Ike Anigbogu', 'C'],
#  ['DeQuan Jones', 'SF'],
#  ['T.J. Leaf', 'C'],
#  ['Ben Moore', 'PF'],
#  ['Edmond Sumner', 'SF'],
#  ['Damien Wilkins', 'SG'],
#  ['Sterling Brown', 'SF'],
#  ['Kendall Marshall', 'PG'],
#  ['D.J. Wilson', 'C'],
#  ['Tyler Cavanaugh', 'PF'],
#  ['John Collins', 'C'],
#  ['Tyler Dorsey', 'SG'],
#  ['Jordan Mathews', 'SG'],
#  ['Dwayne Bacon', 'SF'],
#  ['Terry Henderson', 'SG'],
#  ['Isaiah Hicks', 'PF'],
#  ['Mangok Mathiang', 'C'],
#  ['Malik Monk', 'SG'],
#  ['Luke Petrasek', 'SF'],
#  ['T.J. Williams', 'PG'],
#  ['Bam Adebayo', 'C'],
#  ['Larry Drew II', 'PG'],
#  ['Erik McCree', 'SF'],
#  ['Derrick Walton Jr.', 'PG'],
#  ['Matt Williams', 'SG'],
#  ['Khem Birch', 'C'],
#  ['Troy Caupain', 'PG'],
#  ['Jonathan Isaac', 'PF'],
#  ['Wesley Iwundu', 'SF'],
#  ['Kalin Lucas', 'PG'],
#  ['Carrick Felix', 'SF'],
#  ['Devin Robinson', 'SF'],
#  ['Donald Sloan', 'PG'],
#  ['Michael Young', 'SF'],
#  ['Josh Childress', 'SF'],
#  ['Torrey Craig', 'SF'],
#  ['Tyler Lydon', 'PF'],
#  ['Monte Morris', 'PG'],
#  ['Amile Jefferson', 'C'],
#  ['Justin Patton', 'C'],
#  ['Melo Trimble', 'PG'],
#  ['Norris Cole', 'PG'],
#  ['Terrance Ferguson', 'SF'],
#  ['Dakari Johnson', 'C'],
#  ['Isaiah Briscoe', 'PG'],
#  ['Zach Collins', 'C'],
#  ['Caleb Swanigan', 'C'],
#  ['Tony Bradley', 'C'],
#  ['Eric Griffin', 'C'],
#  ['Donovan Mitchell', 'SG'],
#  ['Nazareth Mitrou-Long', 'PG'],
#  ["Royce O'Neale", 'SF'],
#  ['Ekpe Udoh', 'C'],
#  ['Jordan Bell', 'C'],
#  ['Chris Boucher', 'C'],
#  ['Antonius Cleveland', 'SG'],
#  ['Alex Hamilton', 'SG'],
#  ['Jawun Evans', 'PG'],
#  ['LaDontae Henton', 'SF'],
#  ['Milos Teodosic', 'PG'],
#  ['Sindarius Thornwell', 'SF'],
#  ['Jamil Wilson', 'SF'],
#  ['Lonzo Ball', 'PG'],
#  ['V.J. Beachem', 'SF'],
#  ['Vander Blue', 'SG'],
#  ['Thomas Bryant', 'C'],
#  ['Josh Hart', 'SF'],
#  ['Kyle Kuzma', 'C'],
#  ['Josh Jackson', 'SF'],
#  ['Mike James', 'PG'],
#  ['Peter Jok', 'SF'],
#  ['Elijah Millsap', 'SF'],
#  ['Alec Peters', 'PF'],
#  ['Davon Reed', 'SG'],
#  ['Bogdan Bogdanovic', 'SF'],
#  ['Jack Cooley', 'C'],
#  ["De'Aaron Fox", 'PG'],
#  ['Harry Giles', 'C'],
#  ['Justin Jackson', 'PF'],
#  ['Matt Jones', 'SG'],
#  ['Frank Mason', 'PG'],
#  ['Brandon Ashley', 'PF'],
#  ['Gian Clavell', 'SG'],
#  ['PJ Dozier', 'PG'],
#  ['Maximilian Kleber', 'C'],
#  ['Johnathan Motley', 'C'],
#  ['Dennis Smith Jr.', 'PG'],
#  ['Maalik Wayns', 'PG'],
#  ['Isaiah Hartenstein', 'C'],
#  ['Cameron Oliver', 'PF'],
#  ['Zhou Qi', 'PF'],
#  ['Dillon Brooks', 'SF'],
#  ['Mario Chalmers', 'PG'],
#  ['Ivan Rabb', 'C'],
#  ['Kobi Simmons', 'PG'],
#  ['Rade Zagorac', 'SF'],
#  ['Charles Cooke', 'SG'],
#  ['Jordan Crawford', 'SG'],
#  ['Frank Jackson', 'PG'],
#  ['Perry Jones', 'SF'],
#  ['Darius Miller', 'SF'],
#  ['Jaron Blossomgame', 'SF'],
#  ['London Perrantes', 'PG'],
#  ['Derrick White', 'PG'],
#  ['Milton Doyle', 'SG'],
#  ['Akil Mitchell', 'SG'],
#  ['Jeremy Senglin', 'G'],
#  ['Emeka Okafor', 'C'],
#  ['Alfonzo McKinnie', 'PF'],
#  ['Bronson Koenig', 'PG'],
#  ['Kendrick Perkins', 'C'],
#  ['Landry Nnoko', 'C'],
#  ['Derek Willis', 'F'],
#  ['Trey McKinney-Jones', 'SG'],
#  ['Bryce Alford', 'SG'],
#  ['Rashawn Thomas', 'PF'],
#  ['Marcus Williams', 'PG'],
#  ['George de Paula', 'PG'],
#  ['Durand Scott', 'SG'],
#  ['Amida Brimah', 'C'],
#  ['Reggie Hearn', 'SG'],
#  ['Myke Henry', 'SF'],
#  ['Walt Lemon Jr.', 'PG'],
#  ['Brad Wanamaker', 'SG'],
#  ['Robert Williams', 'C'],
#  ['Mitchell Creek', 'SF'],
#  ['Rodions Kurucs', 'PF'],
#  ['Jordan McLaughlin', 'PG'],
#  ['Dzanan Musa', 'PF'],
#  ['Kevin Knox', 'PF'],
#  ['Mitchell Robinson', 'C'],
#  ['Shake Milton', 'SG'],
#  ['Norvel Pelle', 'C'],
#  ['Landry Shamet', 'SG'],
#  ['Zhaire Smith', 'SG'],
#  ['Jordan Loyd', 'PG'],
#  ['Rawle Alkins', 'SG'],
#  ['Wendell Carter Jr.', 'C'],
#  ['Chandler Hutchison', 'PF'],
#  ['Collin Sexton', 'SG'],
#  ['JaCorey Williams', 'F'],
#  ['Bruce Brown', 'SF'],
#  ['Keenan Evans', 'PG'],
#  ['Zach Lofton', 'G'],
#  ['Khyri Thomas', 'SG'],
#  ['Aaron Holiday', 'SG'],
#  ['Alize Johnson', 'PF'],
#  ['Jordan Barnett', 'F'],
#  ['Donte DiVincenzo', 'SF'],
#  ['Trevon Duval', 'PG'],
#  ['Brandon McCoy', 'C'],
#  ['Jaylen Morris', 'SG'],
#  ['Jaylen Adams', 'PG'],
#  ['Kevin Huerter', 'SG'],
#  ['Omari Spellman', 'C'],
#  ['Trae Young', 'PG'],
#  ['Miles Bridges', 'PF'],
#  ["Devonte' Graham", 'PG'],
#  ['Arnoldas Kulboka', 'SF'],
#  ['J.P. Macura', 'SG'],
#  ['Isaiah Wilkins', 'F'],
#  ['Marcus Lee', 'F'],
#  ['Yante Maten', 'PF'],
#  ['Malik Newman', 'SG'],
#  ['Mohamed Bamba', 'C'],
#  ['Melvin Frazier Jr.', 'SG'],
#  ['Justin Jackson', 'SF'],
#  ['Jarred Vanderbilt', 'SF'],
#  ['Troy Brown Jr.', 'SF'],
#  ['Tiwian Kendley', 'G'],
#  ['Issuf Sanon', 'SG'],
#  ['DeVaughn Akoon-Purcell', 'SG'],
#  ['Michael Porter Jr.', 'PF'],
#  ['Thomas Welsh', 'C'],
#  ['Keita Bates-Diop', 'PF'],
#  ['James Nunnally', 'SF'],
#  ['Josh Okogie', 'SF'],
#  ['Deonte Burton', 'SF'],
#  ['Tyler Davis', 'C'],
#  ['Hamidou Diallo', 'SF'],
#  ['Devon Hall', 'SG'],
#  ['Kevin Hervey', 'PF'],
#  ['Anfernee Simons', 'SG'],
#  ['Gary Trent Jr.', 'SG'],
#  ['Grayson Allen', 'SG'],
#  ['Isaac Haas', 'C'],
#  ['Jairus Lyles', 'G'],
#  ['Marcus Derrickson', 'SF'],
#  ['Jacob Evans', 'SF'],
#  ['Shai Gilgeous-Alexander', 'SG'],
#  ['Jerome Robinson', 'SG'],
#  ['Joel Berry II', 'PG'],
#  ['Isaac Bonga', 'SF'],
#  ['Jeffrey Carroll', 'G'],
#  ['Andre Ingram', 'SG'],
#  ['Sviatoslav Mykhailiuk', 'SF'],
#  ['Moritz Wagner', 'C'],
#  ['Johnathan Williams', 'PF'],
#  ['Deandre Ayton', 'C'],
#  ['Mikal Bridges', 'SF'],
#  ['George King', 'SF'],
#  ["De'Anthony Melton", 'SG'],
#  ['Elie Okobo', 'PG'],
#  ['Marvin Bagley III', 'C'],
#  ['Kostas Antetokounmpo', 'PF'],
#  ['Ryan Broekhoff', 'SF'],
#  ['Jalen Brunson', 'SG'],
#  ['Luka Doncic', 'SF'],
#  ['Scotty Hopson', 'SG'],
#  ['Daryl Macon', 'PG'],
#  ['Codi Miller-McIntyre', 'G'],
#  ['Ray Spalding', 'PF'],
#  ['Ding Yanyuhang', 'F'],
#  ['Vincent Edwards', 'SF'],
#  ['Rob Gray', 'G'],
#  ['Aaron Jackson', 'SF'],
#  ['MarShon Brooks', 'SG'],
#  ['Jevon Carter', 'SG'],
#  ['Markel Crawford', 'G'],
#  ['Tyler Harvey', 'G'],
#  ['Jaren Jackson Jr.', 'C'],
#  ['Doral Moore', 'C'],
#  ['Yuta Watanabe', 'SF'],
#  ['Trevon Bluiett', 'SG'],
#  ['Tony Carr', 'PG'],
#  ['Garlon Green', 'F'],
#  ['Darius Morris', 'PG'],
#  ['Chimezie Metu', 'C'],
#  ['Lonnie Walker IV', 'SF'],
#  ['Theo Pinson', 'SG'],
#  ['Allonzo Trier', 'SG'],
#  ['Jonah Bolden', 'C'],
#  ['Billy Preston', 'SF'],
#  ['Joe Chealey', 'PG'],
#  ['Duncan Robinson', 'SF'],
#  ['Jared Terrell', 'PG'],
#  ['Angel Delgado', 'C'],
#  ['Moritz Wagner', 'C'],
#  ['Wenyen Gabriel', 'PF'],
#  ['Gary Clark', 'PF'],
#  ['Drew Eubanks', 'C'],
#  ['Haywood Highsmith', 'F'],
#  ['Brandon Sampson', 'SG'],
#  ['Deng Adel', 'SF'],
#  ['Stephan Hicks', 'G'],
#  ['Bonzie Colson', 'PF'],
#  ['Brandon Goodwin', 'PG'],
#  ['Donte Grantham', 'SF'],
#  ['Julian Washburn', 'SF'],
#  ['Kenrich Williams', 'PF'],
#  ['Carsen Edwards', 'PG'],
#  ['Tacko Fall', 'C'],
#  ['Javonte Green', 'SG'],
#  ['Romeo Langford', 'SG'],
#  ['Vincent Poirier', 'C'],
#  ['Max Strus', 'SG'],
#  ['Tremont Waters', 'PG'],
#  ['Grant Williams', 'PF'],
#  ['Nicolas Claxton', 'C'],
#  ['Jaylen Hands', 'PG'],
#  ['RJ Barrett', 'SF'],
#  ['Ignas Brazdeikis', 'SF'],
#  ['Isaiah Miles', 'F'],
#  ['Marial Shayok', 'SG'],
#  ['Matisse Thybulle', 'SF'],
#  ['Terence Davis', 'SG'],
#  ['Dewan Hernandez', 'C'],
#  ['Matt Thomas', 'SG'],
#  ['Daniel Gafford', 'C'],
#  ['Adam Mokoka', 'SG'],
#  ['Justin Simon', 'G'],
#  ['Coby White', 'SG'],
#  ['Marques Bolden', 'C'],
#  ['Darius Garland', 'PG'],
#  ['Kevin Porter Jr.', 'SF'],
#  ['Dean Wade', 'PF'],
#  ['Dylan Windler', 'SF'],
#  ['Jordan Bone', 'PG'],
#  ['Sekou Doumbouya', 'PF'],
#  ['Deividas Sirvydis', 'SG'],
#  ['Goga Bitadze', 'C'],
#  ['Brian Bowen II', 'SG'],
#  ['JaKeenan Gant', 'PF'],
#  ['Thanasis Antetokounmpo', 'PF'],
#  ['Cameron Reynolds', 'SG'],
#  ['Rayjon Tucker', 'F'],
#  ['Armoni Brooks', 'G'],
#  ['Charlie Brown Jr.', 'SG'],
#  ['Bruno Fernando', 'C'],
#  ['Isaac Humphries', 'PF'],
#  ["De'Andre Hunter", 'PF'],
#  ['Cam Reddish', 'SF'],
#  ['Robert Franks', 'PF'],
#  ['Ahmed Hill', 'G'],
#  ['Cody Martin', 'SG'],
#  ['Jalen McDaniels', 'PF'],
#  ['PJ Washington', 'C'],
#  ['Kyle Alexander', 'C'],
#  ['Tyler Herro', 'SG'],
#  ['Jeremiah Martin', 'SG'],
#  ['Kendrick Nunn', 'SG'],
#  ['KZ Okpala', 'PF'],
#  ['Chris Silva', 'C'],
#  ['DaQuan Jeffries', 'F'],
#  ['Vic Law', 'F'],
#  ['Chuma Okeke', 'C'],
#  ['Rui Hachimura', 'C'],
#  ['Jemerrio Jones', 'SG'],
#  ['Garrison Mathews', 'SF'],
#  ['Admiral Schofield', 'PF'],
#  ['Bol Bol', 'C'],
#  ['Vlatko Cancar', 'SF'],
#  ['Tyler Cook', 'PF'],
#  ['Jarrett Culver', 'SF'],
#  ['Jaylen Nowell', 'PG'],
#  ['Darius Bazley', 'PF'],
#  ['Luguentz Dort', 'SG'],
#  ['Jaylen Hoard', 'PF'],
#  ['Nassir Little', 'PF'],
#  ['Jarrell Brantley', 'PF'],
#  ['William Howard', 'SG'],
#  ['Stanton Kidd', 'PF'],
#  ['Juwan Morgan', 'F'],
#  ['Miye Oni', 'SG'],
#  ['Justin Wright-Foreman', 'SG'],
#  ['Eric Paschall', 'PF'],
#  ['Jordan Poole', 'SF'],
#  ['Alen Smailagic', 'C'],
#  ['Mfiondu Kabengele', 'C'],
#  ['Terance Mann', 'SF'],
#  ['Devontae Cacok', 'PF'],
#  ['Talen Horton-Tucker', 'SG'],
#  ['Zach Norvell Jr.', 'SG'],
#  ['Ty Jerome', 'SG'],
#  ['Cameron Johnson', 'PF'],
#  ['Jalen Lecque', 'SG'],
#  ['Cody Demps', 'F'],
#  ['Kyle Guy', 'PG'],
#  ['Justin James', 'SF'],
#  ['Vanja Marinkovic', 'SG'],
#  ['Eric Mika', 'C'],
#  ['Isaiah Pineiro', 'SF'],
#  ['Josh Reaves', 'SG'],
#  ['Isaiah Roby', 'PF'],
#  ['Chris Chiozza', 'PG'],
#  ['Michael Frazier', 'SG'],
#  ['Shamorie Ponds', 'PG'],
#  ['Brandon Clarke', 'C'],
#  ['John Konchar', 'SG'],
#  ['Matt Mooney', 'SG'],
#  ['Ja Morant', 'PG'],
#  ['Nickeil Alexander-Walker', 'SG'],
#  ['Kavell Bigby-Williams', 'C'],
#  ['Zylan Cheatham', 'PF'],
#  ['Jaxson Hayes', 'C'],
#  ['Nicolo Melli', 'C'],
#  ['Zion Williamson', 'C'],
#  ['Keldon Johnson', 'SF'],
#  ['Jeff Ledbetter', 'G'],
#  ['Luka Samanic', 'PF'],
#  ['Quinndary Weatherspoon', 'SG']]

# %%
FGA()
# Out:
# [['Tariq Abdul-Wahad', '8.3', '49', '24.6', 1998],
#  ['Shareef Abdur-Rahim', '17.9', '50', '40.4', 1998],
#  ['Cory Alexander', '7.2', '36', '21.6', 1998],
#  ['Ray Allen', '13.5', '50', '34.4', 1998],
#  ['Peter Aluma', '1.0', '2', '2.5', 1998],
#  ['Derek Anderson', '8.3', '38', '25.7', 1998],
#  ['Kenny Anderson', '10.5', '34', '29.7', 1998],
#  ['Nick Anderson', '13.6', '47', '33.6', 1998],
#  ['Shandon Anderson', '7.3', '50', '21.4', 1998],
#  ['Chris Anstey', '3.4', '41', '11.5', 1998],
#  ['Greg Anthony', '5.0', '50', '16.1', 1998],
#  ['B.J. Armstrong', '2.8', '32', '11.2', 1998],
#  ['Darrell Armstrong', '10.4', '50', '30.0', 1998],
#  ['Keith Askins', '1.9', '33', '12.6', 1998],
#  ['Stacey Augmon', '3.6', '48', '18.2', 1998],
#  ['Isaac Austin', '9.2', '49', '25.7', 1998],
#  ['Anthony Avent', '2.6', '5', '8.8', 1998],
#  ['Thurl Bailey', '4.1', '43', '12.6', 1998],
#  ['Toby Bailey', '3.2', '27', '9.2', 1998],
#  ['LaMark Baker', '1.0', '1', '2.0', 1998],
#  ['Vin Baker', '12.9', '34', '34.2', 1998],
#  ['Charles Barkley', '12.0', '42', '36.3', 1998],
#  ['Dana Barros', '7.4', '50', '23.1', 1998],
#  ['Brent Barry', '9.6', '37', '31.9', 1998],
#  ['Drew Barry', '1.9', '17', '10.8', 1998],
#  ['Jon Barry', '3.2', '43', '17.1', 1998],
#  ['Tony Battie', '5.7', '50', '22.4', 1998],
#  ['Corey Beck', '1.6', '24', '7.5', 1998],
#  ['Benoit Benjamin', '1.2', '6', '5.5', 1998],
#  ['Corey Benjamin', '3.8', '31', '10.3', 1998],
#  ['Mario Bennett', '2.0', '3', '6.3', 1998],
#  ['Travis Best', '6.2', '49', '21.3', 1998],
#  ['Mike Bibby', '12.1', '50', '35.2', 1998],
#  ['Chauncey Billups', '11.0', '45', '33.1', 1998],
#  ['Mookie Blaylock', '13.6', '48', '36.7', 1998],
#  ['Corie Blount', '2.9', '34', '15.6', 1998],
#  ['Muggsy Bogues', '4.3', '36', '19.8', 1998],
#  ['Etdrick Bohannon', '0.0', '2', '2.0', 1998],
#  ['Keith Booth', '3.9', '39', '11.1', 1998],
#  ['Bruce Bowen', '3.1', '30', '16.5', 1998],
#  ['Earl Boykins', '3.6', '22', '10.0', 1998],
#  ['Shawn Bradley', '7.1', '49', '26.4', 1998],
#  ['Terrell Brandon', '14.1', '36', '33.8', 1998],
#  ['Chucky Brown', '7.8', '48', '24.8', 1998],
#  ['Dee Brown', '10.1', '49', '28.1', 1998],
#  ['Gerald Brown', '2.7', '33', '7.2', 1998],
#  ['P.J. Brown', '9.5', '50', '32.2', 1998],
#  ['Randy Brown', '8.2', '39', '29.2', 1998],
#  ['Rick Brunson', '1.2', '17', '5.6', 1998],
#  ['Kobe Bryant', '15.6', '50', '37.9', 1998],
#  ['Mark Bryant', '7.7', '45', '26.8', 1998],
#  ['Jud Buechler', '4.8', '50', '21.1', 1998],
#  ['Matt Bullard', '2.8', '41', '10.1', 1998],
#  ['Scott Burrell', '6.5', '32', '22.1', 1998],
#  ['Willie Burton', '2.3', '3', '6.0', 1998],
#  ['Mitchell Butler', '4.5', '31', '13.5', 1998],
#  ['Jason Caffey', '7.9', '35', '25.0', 1998],
#  ['Marcus Camby', '5.7', '46', '20.5', 1998],
#  ['Elden Campbell', '9.5', '49', '29.8', 1998],
#  ['Antoine Carr', '2.9', '18', '8.4', 1998],
#  ['Chris Carr', '5.3', '39', '11.4', 1998],
#  ['Cory Carr', '5.1', '42', '14.9', 1998],
#  ['Vince Carter', '15.3', '50', '35.2', 1998],
#  ['Sam Cassell', '11.6', '8', '24.9', 1998],
#  ['Kelvin Cato', '3.0', '43', '12.7', 1998],
#  ['Duane Causwell', '1.8', '19', '7.2', 1998],
#  ['Cedric Ceballos', '10.8', '13', '27.1', 1998],
#  ['Rex Chapman', '12.1', '38', '31.1', 1998],
#  ['Calbert Cheaney', '8.3', '50', '25.3', 1998],
#  ['Pete Chilcutt', '3.7', '46', '15.2', 1998],
#  ['Chris Childs', '5.6', '48', '27.0', 1998],
#  ['Doug Christie', '13.0', '50', '35.4', 1998],
#  ['Keon Clark', '2.9', '28', '14.6', 1998],
#  ['Keith Closs', '1.5', '15', '5.8', 1998],
#  ['John Coker', '2.2', '14', '7.0', 1998],
#  ['Derrick Coleman', '11.0', '37', '31.8', 1998],
#  ['Bimbo Coles', '8.6', '48', '26.5', 1998],
#  ['Marty Conlon', '1.9', '7', '5.0', 1998],
#  ['Tyrone Corbin', '7.1', '47', '22.7', 1998],
#  ['James Cotton', '1.8', '10', '5.9', 1998],
#  ['Chris Crawford', '6.1', '42', '18.7', 1998],
#  ['Austin Croshere', '2.8', '27', '9.2', 1998],
#  ['John Crotty', '4.6', '27', '14.1', 1998],
#  ['Terry Cummings', '8.5', '50', '20.2', 1998],
#  ['William Cunningham', '1.1', '16', '10.1', 1998],
#  ['Bill Curley', '2.1', '35', '10.6', 1998],
#  ['Dell Curry', '8.0', '42', '20.6', 1998],
#  ['Michael Curry', '4.1', '50', '22.9', 1998],
#  ['Erick Dampier', '8.3', '50', '28.3', 1998],
#  ['Antonio Daniels', '3.9', '47', '13.1', 1998],
#  ['Kornél Dávid', '4.9', '50', '18.0', 1998],
#  ['Antonio Davis', '7.1', '49', '25.9', 1998],
#  ['Ben Davis', '2.1', '8', '2.6', 1998],
#  ['Dale Davis', '6.0', '50', '27.5', 1998],
#  ['Hubert Davis', '7.9', '50', '27.6', 1998],
#  ['Mark Davis', '1.5', '4', '8.8', 1998],
#  ['Ricky Davis', '4.3', '46', '12.1', 1998],
#  ['Terry Davis', '2.5', '37', '15.6', 1998],
#  ['Andrew DeClercq', '5.9', '47', '23.4', 1998],
#  ['Terry Dehere', '3.3', '26', '11.2', 1998],
#  ['Vinny Del Negro', '5.6', '48', '22.8', 1998],
#  ['Bison Dele', '8.8', '49', '24.0', 1998],
#  ['Tony Delk', '7.0', '36', '17.5', 1998],
#  ['Michael Dickerson', '9.2', '50', '31.2', 1998],
#  ['Vlade Divac', '11.1', '50', '35.2', 1998],
#  ['Michael Doleac', '5.4', '49', '15.9', 1998],
#  ['Sherman Douglas', '7.3', '30', '28.1', 1998],
#  ['Bryce Drew', '3.8', '34', '13.0', 1998],
#  ['Chris Dudley', '2.4', '46', '14.9', 1998],
#  ['Joe Dumars', '9.2', '38', '29.4', 1998],
#  ['Tim Duncan', '16.9', '50', '39.3', 1998],
#  ['Blue Edwards', '3.0', '24', '11.8', 1998],
#  ['Howard Eisley', '6.3', '50', '20.8', 1998],
#  ['Mario Elie', '7.0', '47', '27.5', 1998],
#  ['Sean Elliott', '10.1', '50', '30.2', 1998],
#  ['Dale Ellis', '8.2', '48', '25.7', 1998],
#  ['LaPhonso Ellis', '9.5', '20', '27.0', 1998],
#  ['Brian Evans', '2.8', '16', '9.1', 1998],
#  ['Patrick Ewing', '14.9', '38', '34.2', 1998],
#  ['Jamie Feick', '4.8', '28', '30.4', 1998],
#  ['Duane Ferrell', '1.8', '8', '5.8', 1998],
#  ['Danny Ferry', '5.9', '50', '21.2', 1998],
#  ['Michael Finley', '17.5', '50', '41.0', 1998],
#  ['Derek Fisher', '5.3', '50', '22.6', 1998],
#  ['Danny Fortson', '7.7', '50', '28.3', 1998],
#  ['Greg Foster', '3.3', '42', '10.9', 1998],
#  ['Rick Fox', '7.5', '44', '21.5', 1998],
#  ['Adonal Foyle', '2.8', '44', '14.0', 1998],
#  ['Todd Fuller', '3.0', '42', '11.0', 1998],
#  ['Lawrence Funderburke', '6.4', '47', '19.9', 1998],
#  ['Kevin Garnett', '19.1', '47', '37.9', 1998],
#  ['Marlon Garnett', '2.1', '24', '8.5', 1998],
#  ['Dean Garrett', '4.7', '49', '21.5', 1998],
#  ['Pat Garrity', '4.4', '39', '13.8', 1998],
#  ['Chris Gatling', '5.5', '48', '16.1', 1998],
#  ['Andrew Gaze', '1.3', '19', '3.1', 1998],
#  ['Matt Geiger', '11.1', '50', '30.8', 1998],
#  ['Kendall Gill', '11.9', '50', '32.1', 1998],
#  ['Armen Gilliam', '6.6', '34', '19.6', 1998],
#  ['Brian Grant', '8.0', '48', '31.8', 1998],
#  ['Gary Grant', '0.5', '2', '3.5', 1998],
#  ['Harvey Grant', '3.6', '47', '17.0', 1998],
#  ['Horace Grant', '9.1', '50', '33.2', 1998],
#  ['Paul Grant', '1.0', '6', '2.2', 1998],
#  ['Ed Gray', '6.1', '30', '11.2', 1998],
#  ['A.C. Green', '5.1', '50', '18.5', 1998],
#  ['Litterial Green', '1.0', '1', '2.0', 1998],
#  ['Tom Gugliotta', '13.3', '43', '36.3', 1998],
#  ['Tom Hammonds', '3.7', '49', '14.6', 1998],
#  ['Anfernee Hardaway', '14.3', '50', '38.9', 1998],
#  ['Tim Hardaway', '15.7', '48', '36.9', 1998],
#  ['Derek Harper', '6.5', '45', '24.9', 1998],
#  ['Ron Harper', '11.1', '35', '31.6', 1998],
#  ['Matt Harpring', '6.4', '50', '22.3', 1998],
#  ['Al Harrington', '2.7', '21', '7.6', 1998],
#  ['Othella Harrington', '7.4', '41', '22.0', 1998],
#  ['Lucious Harris', '5.0', '36', '16.7', 1998],
#  ['Hersey Hawkins', '8.2', '50', '32.9', 1998],
#  ['Michael Hawkins', '1.7', '24', '8.5', 1998],
#  ['Alan Henderson', '11.1', '38', '30.1', 1998],
#  ['Cedric Henderson', '9.1', '50', '30.3', 1998],
#  ['J.R. Henderson', '3.2', '30', '11.0', 1998],
#  ['Mark Hendrickson', '4.0', '22', '18.1', 1998],
#  ['Steve Henson', '0.5', '4', '6.3', 1998],
#  ['Carl Herrera', '2.7', '28', '11.0', 1998],
#  ['Grant Hill', '16.0', '50', '37.0', 1998],
#  ['Tyrone Hill', '7.1', '38', '29.1', 1998],
#  ['Fred Hoiberg', '1.8', '12', '7.3', 1998],
#  ['Jerald Honeycutt', '2.0', '16', '6.4', 1998],
#  ['Jeff Hornacek', '9.4', '48', '29.9', 1998],
#  ['Robert Horry', '3.8', '38', '19.6', 1998],
#  ['Allan Houston', '14.1', '50', '36.3', 1998],
#  ['Juwan Howard', '16.8', '36', '39.7', 1998],
#  ['Troy Hudson', '6.0', '25', '21.0', 1998],
#  ['Larry Hughes', '8.3', '50', '19.8', 1998],
#  ['Lindsey Hunter', '10.7', '49', '35.8', 1998],
#  ['Zydrunas Ilgauskas', '11.4', '5', '34.2', 1998],
#  ['Allen Iverson', '22.0', '48', '41.5', 1998],
#  ['Bobby Jackson', '7.0', '50', '18.8', 1998],
#  ['Jaren Jackson', '6.0', '47', '18.3', 1998],
#  ['Jim Jackson', '7.6', '49', '24.0', 1998],
#  ['Mark Jackson', '6.7', '49', '28.2', 1998],
#  ['Randell Jackson', '4.0', '27', '10.0', 1998],
#  ['Sam Jacobson', '2.5', '2', '6.0', 1998],
#  ['Jerome James', '1.5', '16', '2.6', 1998],
#  ['Antawn Jamison', '8.4', '47', '22.5', 1998],
#  ['Anthony Johnson', '4.6', '49', '18.1', 1998],
#  ['Avery Johnson', '9.2', '50', '33.4', 1998],
#  ['Eddie Johnson', '4.3', '3', '6.0', 1998],
#  ['Ervin Johnson', '3.8', '50', '20.5', 1998],
#  ['Larry Johnson', '9.3', '49', '33.4', 1998],
#  ['Charles Jones', '4.2', '29', '16.4', 1998],
#  ['Damon Jones', '5.0', '24', '14.3', 1998],
#  ['Eddie Jones', '11.9', '50', '37.6', 1998],
#  ['Popeye Jones', '2.8', '18', '11.4', 1998],
#  ['Adonis Jordan', '1.0', '4', '4.5', 1998],
#  ['Reggie Jordan', '2.0', '27', '11.0', 1998],
#  ['Adam Keefe', '2.8', '44', '14.6', 1998],
#  ['Shawn Kemp', '13.7', '42', '35.1', 1998],
#  ['Jonathan Kerner', '1.0', '1', '5.0', 1998],
#  ['Steve Kerr', '4.0', '44', '16.7', 1998],
#  ['Jerome Kersey', '4.4', '45', '15.5', 1998],
#  ['Jason Kidd', '14.0', '50', '41.2', 1998],
#  ['Chris King', '0.9', '8', '5.3', 1998],
#  ['Gerard King', '0.7', '19', '3.3', 1998],
#  ['Kerry Kittles', '13.3', '46', '34.1', 1998],
#  ['Joe Kleine', '2.4', '31', '12.1', 1998],
#  ['Brevin Knight', '8.1', '39', '30.4', 1998],
#  ['Negele Knight', '1.3', '6', '9.3', 1998],
#  ['Travis Knight', '3.5', '37', '14.2', 1998],
#  ['Toni Kukoč', '17.0', '44', '37.6', 1998],
#  ['Christian Laettner', '6.6', '16', '21.1', 1998],
#  ['Raef LaFrentz', '10.8', '12', '32.3', 1998],
#  ['Andrew Lang', '4.7', '21', '18.4', 1998],
#  ['Antonio Lang', '0.6', '10', '6.5', 1998],
#  ['Rusty LaRue', '5.0', '43', '17.0', 1998],
#  ['Tim Legler', '3.8', '30', '12.6', 1998],
#  ['Voshon Lenard', '6.6', '12', '15.8', 1998],
#  ['Rashard Lewis', '2.6', '20', '7.3', 1998],
#  ['Randy Livingston', '8.0', '1', '22.0', 1998],
#  ['Grant Long', '7.2', '50', '27.6', 1998],
#  ['Luc Longley', '7.4', '39', '23.9', 1998],
#  ['Felipe López', '8.1', '47', '25.9', 1998],
#  ['Tyronn Lue', '4.3', '15', '12.5', 1998],
#  ['George Lynch', '8.1', '43', '30.6', 1998],
#  ['Sam Mack', '8.7', '44', '24.6', 1998],
#  ['Don MacLean', '9.4', '17', '21.5', 1998],
#  ['Mark Macon', '2.9', '7', '9.9', 1998],
#  ['Rick Mahorn', '1.1', '16', '7.9', 1998],
#  ['Dan Majerle', '6.2', '48', '33.8', 1998],
#  ['Karl Malone', '16.3', '49', '37.4', 1998],
#  ['Matt Maloney', '1.9', '15', '12.4', 1998],
#  ['Danny Manning', '7.7', '50', '23.7', 1998],
#  ['Stephon Marbury', '18.0', '49', '38.7', 1998],
#  ['Sean Marks', '1.0', '8', '3.5', 1998],
#  ['Donyell Marshall', '10.3', '48', '26.0', 1998],
#  ['Darrick Martin', '7.5', '37', '25.4', 1998],
#  ['Jamal Mashburn', '12.4', '24', '35.6', 1998],
#  ['Tony Massenburg', '9.0', '43', '26.6', 1998],
#  ['Vernon Maxwell', '9.2', '46', '21.9', 1998],
#  ['Lee Mayberry', '2.1', '9', '14.0', 1998],
#  ['Kelly McCarty', '1.5', '2', '2.0', 1998],
#  ['Walter McCarty', '5.5', '32', '20.6', 1998],
#  ['George McCloud', '6.8', '48', '25.9', 1998],
#  ['Jelani McCoy', '2.9', '26', '12.7', 1998],
#  ['Antonio McDyess', '17.6', '50', '38.7', 1998],
#  ['Tracy McGrady', '7.9', '49', '22.6', 1998],
#  ['Jim McIlvaine', '2.3', '22', '12.2', 1998],
#  ['Jeff McInnis', '3.8', '35', '12.2', 1998],
#  ['Derrick McKey', '4.0', '13', '18.8', 1998],
#  ['Aaron McKie', '4.7', '50', '19.2', 1998],
#  ['Roshown McLeod', '4.8', '34', '10.2', 1998],
#  ['Ron Mercer', '17.2', '41', '37.8', 1998],
#  ['Loren Meyer', '2.0', '14', '5.0', 1998],
#  ['Marko Milič', '1.8', '11', '4.8', 1998],
#  ['Anthony Miller', '2.1', '29', '8.6', 1998],
#  ['Brad Miller', '3.6', '38', '12.3', 1998],
#  ['Oliver Miller', '2.8', '4', '8.8', 1998],
#  ['Reggie Miller', '13.4', '50', '35.7', 1998],
#  ['Chris Mills', '9.6', '47', '29.7', 1998],
#  ['Terry Mills', '8.0', '1', '29.0', 1998],
#  ['Greg Minor', '4.6', '44', '17.4', 1998],
#  ['Sam Mitchell', '10.4', '50', '26.9', 1998],
#  ['Cuttino Mobley', '8.3', '49', '29.7', 1998],
#  ['Nazr Mohammed', '1.6', '26', '4.7', 1998],
#  ['Eric Montross', '1.7', '46', '12.5', 1998],
#  ['Mikki Moore', '0.5', '2', '3.0', 1998],
#  ['Chris Morris', '3.4', '44', '12.2', 1998],
#  ['Alonzo Mourning', '13.8', '46', '38.1', 1998],
#  ['Chris Mullin', '7.4', '50', '23.6', 1998],
#  ['Eric Murdock', '7.6', '15', '26.7', 1998],
#  ['Gheorghe Mureșan', '1.0', '1', '1.0', 1998],
#  ['Lamond Murray', '11.6', '50', '26.3', 1998],
#  ['Tracy Murray', '6.6', '36', '18.1', 1998],
#  ['Dikembe Mutombo', '6.8', '50', '36.6', 1998],
#  ["Makhtar N'Diaye", '1.0', '4', '6.8', 1998],
#  ['Steve Nash', '7.9', '40', '31.7', 1998],
#  ['Tyrone Nesby', '8.1', '50', '25.8', 1998],
#  ['Rasho Nesterović', '6.0', '2', '15.0', 1998],
#  ['Johnny Newman', '5.0', '50', '19.0', 1998],
#  ['Moochie Norris', '3.3', '12', '11.7', 1998],
#  ['Dirk Nowitzki', '7.1', '47', '20.4', 1998],
#  ["Charles O'Bannon", '3.1', '18', '9.2', 1998],
#  ["Jermaine O'Neal", '2.3', '36', '8.6', 1998],
#  ["Shaquille O'Neal", '18.1', '49', '34.8', 1998],
#  ['Charles Oakley', '6.5', '50', '32.7', 1998],
#  ['Hakeem Olajuwon', '14.5', '50', '35.7', 1998],
#  ['Jimmy Oliver', '1.5', '2', '5.5', 1998],
#  ['Kevin Ollie', '1.8', '8', '9.0', 1998],
#  ['Michael Olowokandi', '8.9', '45', '28.4', 1998],
#  ['Greg Ostertag', '4.3', '48', '27.9', 1998],
#  ['Bo Outlaw', '5.0', '31', '27.5', 1998],
#  ['Doug Overton', '3.5', '24', '10.2', 1998],
#  ['Billy Owens', '7.9', '21', '21.5', 1998],
#  ['Robert Pack', '7.0', '25', '18.7', 1998],
#  ['Anthony Parker', '0.5', '2', '1.5', 1998],
#  ['Cherokee Parks', '5.7', '48', '23.3', 1998],
#  ['Andrae Patterson', '2.8', '35', '8.1', 1998],
#  ['Ruben Patterson', '2.1', '24', '6.0', 1998],
#  ['Gary Payton', '18.5', '50', '40.2', 1998],
#  ['Anthony Peeler', '9.7', '28', '28.9', 1998],
#  ['Will Perdue', '1.6', '37', '12.0', 1998],
#  ['Sam Perkins', '4.2', '48', '16.4', 1998],
#  ['Elliot Perry', '2.9', '35', '8.3', 1998],
#  ['Chuck Person', '5.8', '50', '19.8', 1998],
#  ['Wesley Person', '9.7', '45', '29.8', 1998],
#  ['Bobby Phills', '11.6', '43', '36.6', 1998],
#  ['Eric Piatkowski', '8.5', '49', '25.3', 1998],
#  ['Paul Pierce', '13.5', '48', '34.0', 1998],
#  ['Scottie Pippen', '12.1', '50', '40.2', 1998],
#  ['Scot Pollard', '3.8', '16', '16.2', 1998],
#  ['Olden Polynice', '7.5', '48', '30.9', 1998],
#  ['Mark Pope', '1.8', '4', '6.5', 1998],
#  ['Terry Porter', '7.4', '50', '27.3', 1998],
#  ['Vitaly Potapenko', '8.2', '50', '27.9', 1998],
#  ['Brent Price', '5.2', '40', '20.2', 1998],
#  ['Theo Ratliff', '8.4', '50', '32.5', 1998],
#  ['Eldridge Recasner', '4.2', '44', '16.1', 1998],
#  ['Bryant Reeves', '10.0', '25', '28.1', 1998],
#  ['Khalid Reeves', '1.9', '11', '10.2', 1998],
#  ['Don Reid', '3.7', '47', '19.9', 1998],
#  ['J.R. Reid', '6.8', '41', '25.1', 1998],
#  ['Shawn Respert', '3.0', '12', '8.3', 1998],
#  ['Rodrick Rhodes', '4.0', '13', '12.0', 1998],
#  ['Glen Rice', '14.7', '27', '36.5', 1998],
#  ['Pooh Richardson', '3.3', '11', '11.8', 1998],
#  ['Mitch Richmond', '16.1', '50', '38.2', 1998],
#  ['Isaiah Rider', '12.9', '47', '29.5', 1998],
#  ['Eric Riley', '1.5', '35', '9.6', 1998],
#  ['Stanley Roberts', '2.2', '6', '5.5', 1998],
#  ['Clifford Robinson', '12.6', '50', '34.8', 1998],
#  ['David Robinson', '10.8', '49', '31.7', 1998],
#  ['Glenn Robinson', '16.1', '47', '33.6', 1998],
#  ['James Robinson', '6.0', '31', '16.3', 1998],
#  ['Dennis Rodman', '2.0', '23', '28.6', 1998],
#  ['Carlos Rogers', '1.0', '2', '4.0', 1998],
#  ['Rodney Rogers', '6.3', '47', '20.6', 1998],
#  ['Sean Rooks', '2.2', '36', '8.8', 1998],
#  ['Jalen Rose', '10.1', '49', '25.3', 1998],
#  ['Malik Rose', '4.3', '47', '12.9', 1998],
#  ['Bryon Russell', '9.4', '50', '35.4', 1998],
#  ['Arvydas Sabonis', '9.6', '50', '27.0', 1998],
#  ['Jason Sasser', '1.8', '6', '6.5', 1998],
#  ['Danny Schayes', '1.5', '19', '7.5', 1998],
#  ['Dwayne Schintzius', '1.0', '16', '4.2', 1998],
#  ['Detlef Schrempf', '11.0', '50', '35.3', 1998],
#  ['Dennis Scott', '5.9', '36', '20.5', 1998],
#  ['Malik Sealy', '7.5', '31', '23.6', 1998],
#  ['Rony Seikaly', '2.2', '9', '9.8', 1998],
#  ['Charles Shackleford', '2.8', '32', '11.5', 1998],
#  ['Brian Shaw', '1.0', '1', '5.0', 1998],
#  ['Casey Shaw', '0.9', '9', '1.6', 1998],
#  ['Jeff Sheppard', '2.2', '18', '10.3', 1998],
#  ['Miles Simon', '1.0', '5', '3.8', 1998],
#  ['Dickey Simpkins', '6.5', '50', '29.0', 1998],
#  ['Alvin Sims', '2.5', '4', '6.3', 1998],
#  ['Brian Skinner', '3.4', '21', '12.3', 1998],
#  ['Reggie Slater', '2.7', '30', '8.8', 1998],
#  ['Charles Smith', '4.2', '23', '13.8', 1998],
#  ['Joe Smith', '12.1', '43', '33.0', 1998],
#  ['Michael Smith', '3.0', '48', '22.9', 1998],
#  ['Steve Smith', '15.0', '36', '36.5', 1998],
#  ['Rik Smits', '12.9', '49', '25.9', 1998],
#  ['Eric Snow', '7.3', '48', '35.8', 1998],
#  ['Felton Spencer', '1.3', '26', '6.1', 1998],
#  ['Latrell Sprewell', '14.0', '37', '33.3', 1998],
#  ['Ryan Stack', '2.1', '18', '11.1', 1998],
#  ['Jerry Stackhouse', '11.6', '42', '28.3', 1998],
#  ['John Starks', '14.6', '50', '33.7', 1998],
#  ['Vladimir Stepania', '5.4', '23', '13.6', 1998],
#  ['Michael Stewart', '1.3', '42', '9.4', 1998],
#  ['Bryant Stith', '6.3', '46', '26.0', 1998],
#  ['John Stockton', '8.2', '50', '28.2', 1998],
#  ['Peja Stojaković', '7.8', '48', '21.4', 1998],
#  ['Damon Stoudamire', '12.6', '50', '33.5', 1998],
#  ['Erick Strickland', '6.7', '33', '17.2', 1998],
#  ['Mark Strickland', '3.2', '32', '11.2', 1998],
#  ['Rod Strickland', '13.7', '44', '37.1', 1998],
#  ['Derek Strong', '4.1', '44', '15.8', 1998],
#  ['Bruno Šundov', '2.3', '3', '3.7', 1998],
#  ['Bob Sura', '4.2', '50', '16.8', 1998],
#  ['Johnny Taylor', '5.5', '36', '20.1', 1998],
#  ['Maurice Taylor', '14.7', '46', '32.7', 1998],
#  ['John Thomas', '3.2', '39', '15.2', 1998],
#  ['Kurt Thomas', '7.4', '50', '23.6', 1998],
#  ['Tim Thomas', '5.6', '50', '16.2', 1998],
#  ['Otis Thorpe', '9.0', '49', '31.4', 1998],
#  ['Robert Traylor', '4.1', '49', '16.0', 1998],
#  ['Gary Trent', '13.4', '45', '30.3', 1998],
#  ['Nick Van Exel', '15.4', '50', '36.0', 1998],
#  ['Keith Van Horn', '17.9', '42', '37.5', 1998],
#  ['David Vaughn', '2.4', '10', '10.3', 1998],
#  ['Jacque Vaughn', '1.6', '19', '4.6', 1998],
#  ['Loy Vaught', '4.2', '37', '13.0', 1998],
#  ['Stojko Vranković', '2.0', '2', '6.0', 1998],
#  ['Antoine Walker', '17.5', '42', '36.9', 1998],
#  ['Samaki Walker', '4.9', '39', '14.6', 1998],
#  ['Ben Wallace', '4.3', '46', '26.8', 1998],
#  ['John Wallace', '7.4', '48', '16.9', 1998],
#  ['Rasheed Wallace', '9.7', '49', '28.9', 1998],
#  ['Rex Walters', '2.9', '33', '15.3', 1998],
#  ['Charlie Ward', '6.7', '50', '31.1', 1998],
#  ['Eric Washington', '4.8', '38', '20.0', 1998],
#  ['Jamie Watson', '0.7', '3', '6.0', 1998],
#  ['Clarence Weatherspoon', '5.4', '49', '21.2', 1998],
#  ['Chris Webber', '18.5', '42', '40.9', 1998],
#  ['Bonzi Wells', '2.9', '7', '5.0', 1998],
#  ['Bill Wennington', '4.7', '38', '11.9', 1998],
#  ['David Wesley', '10.9', '50', '37.0', 1998],
#  ['Doug West', '4.6', '14', '21.0', 1998],
#  ['Mark West', '1.2', '49', '10.2', 1998],
#  ['DeJuan Wheat', '4.2', '46', '12.8', 1998],
#  ['Tyson Wheeler', '1.0', '1', '3.0', 1998],
#  ['Jahidi White', '1.6', '20', '9.6', 1998],
#  ['Chris Whitney', '4.0', '39', '11.3', 1998],
#  ['Dominique Wilkins', '4.9', '27', '9.3', 1998],
#  ['Gerald Wilkins', '3.0', '3', '9.3', 1998],
#  ['Aaron Williams', '3.1', '40', '11.5', 1998],
#  ['Alvin Williams', '4.7', '50', '21.0', 1998],
#  ['Brandon Williams', '0.0', '3', '1.3', 1998],
#  ['Eric Williams', '5.8', '38', '20.5', 1998],
#  ['Herb Williams', '1.3', '6', '5.7', 1998],
#  ['Hot Rod Williams', '1.3', '25', '16.1', 1998],
#  ['Jason Williams', '12.3', '50', '36.1', 1998],
#  ['Jayson Williams', '7.3', '30', '34.0', 1998],
#  ['Jerome Williams', '5.0', '50', '23.1', 1998],
#  ['Micheal Williams', '2.5', '2', '7.5', 1998],
#  ['Monty Williams', '2.0', '1', '6.0', 1998],
#  ['Scott Williams', '2.4', '7', '6.6', 1998],
#  ['Shammond Williams', '0.5', '2', '2.0', 1998],
#  ['Travis Williams', '1.6', '8', '7.8', 1998],
#  ['Walt Williams', '7.2', '48', '21.8', 1998],
#  ['Corliss Williamson', '11.1', '50', '27.5', 1998],
#  ['Kevin Willis', '10.6', '42', '29.0', 1998],
#  ['David Wingate', '0.8', '20', '4.6', 1998],
#  ['Trevor Winter', '0.0', '1', '5.0', 1998],
#  ['Joe Wolf', '0.3', '3', '4.0', 1998],
#  ['Haywoode Workman', '5.9', '29', '28.1', 1998],
#  ['Lorenzen Wright', '5.4', '48', '23.6', 1998],
#  ['Korleone Young', '3.3', '3', '5.0', 1998],
#  ['Tariq Abdul-Wahad', '10.6', '61', '25.9', 1999],
#  ['Shareef Abdur-Rahim', '15.6', '82', '39.3', 1999],
#  ['Cory Alexander', '3.4', '29', '11.3', 1999],
#  ['Ray Allen', '17.2', '82', '37.4', 1999],
#  ['Rafer Alston', '3.5', '27', '13.4', 1999],
#  ['John Amaechi', '8.8', '80', '21.1', 1999],
#  ['Derek Anderson', '13.4', '64', '34.4', 1999],
#  ['Kenny Anderson', '12.0', '82', '31.6', 1999],
#  ['Nick Anderson', '10.9', '72', '29.1', 1999],
#  ['Shandon Anderson', '9.5', '82', '32.9', 1999],
#  ['Chris Anstey', '5.0', '73', '13.8', 1999],
#  ['Greg Anthony', '5.1', '82', '18.9', 1999],
#  ['B.J. Armstrong', '6.9', '27', '21.6', 1999],
#  ['Darrell Armstrong', '13.6', '82', '31.6', 1999],
#  ['Chucky Atkins', '9.0', '82', '19.8', 1999],
#  ['Stacey Augmon', '3.0', '59', '11.7', 1999],
#  ['Isaac Austin', '6.0', '59', '19.9', 1999],
#  ['Anthony Avent', '2.0', '49', '7.7', 1999],
#  ['William Avery', '3.1', '59', '8.2', 1999],
#  ['Toby Bailey', '3.0', '46', '9.8', 1999],
#  ['Vin Baker', '14.3', '79', '36.1', 1999],
#  ['Charles Barkley', '11.1', '20', '31.0', 1999],
#  ['Dana Barros', '6.0', '72', '15.8', 1999],
#  ['Brent Barry', '8.8', '80', '34.1', 1999],
#  ['Drew Barry', '2.1', '16', '9.9', 1999],
#  ['Jon Barry', '5.6', '62', '20.7', 1999],
#  ['Tony Battie', '5.6', '82', '18.4', 1999],
#  ['Jonathan Bender', '2.9', '24', '5.4', 1999],
#  ['Benoit Benjamin', '1.0', '3', '2.7', 1999],
#  ['Corey Benjamin', '7.3', '48', '18.0', 1999],
#  ['Mario Bennett', '3.0', '1', '3.0', 1999],
#  ['Travis Best', '6.8', '82', '20.6', 1999],
#  ['Mike Bibby', '12.6', '82', '38.5', 1999],
#  ['Chauncey Billups', '7.8', '13', '23.5', 1999],
#  ['Mookie Blaylock', '11.5', '73', '33.7', 1999],
#  ['Corie Blount', '2.3', '38', '11.7', 1999],
#  ['Muggsy Bogues', '4.5', '80', '21.6', 1999],
#  ['Etdrick Bohannon', '1.0', '13', '9.1', 1999],
#  ['Calvin Booth', '4.2', '11', '13.0', 1999],
#  ['Lazaro Borrell', '3.7', '17', '9.8', 1999],
#  ['Cal Bowdler', '2.5', '46', '9.2', 1999],
#  ['Bruce Bowen', '2.8', '69', '12.7', 1999],
#  ['Ryan Bowen', '2.3', '52', '11.3', 1999],
#  ['Ira Bowman', '0.2', '11', '1.8', 1999],
#  ['Earl Boykins', '4.5', '26', '10.0', 1999],
#  ['Shawn Bradley', '7.2', '77', '24.7', 1999],
#  ['A.J. Bramlett', '2.6', '8', '7.6', 1999],
#  ['Elton Brand', '16.1', '81', '37.0', 1999],
#  ['Terrell Brandon', '14.7', '71', '36.4', 1999],
#  ['Chucky Brown', '5.2', '63', '17.4', 1999],
#  ['Dee Brown', '6.8', '38', '17.7', 1999],
#  ['Marcus Brown', '2.3', '6', '7.5', 1999],
#  ['P.J. Brown', '8.4', '80', '28.8', 1999],
#  ['Randy Brown', '7.4', '59', '27.5', 1999],
#  ['Rick Brunson', '1.9', '37', '7.8', 1999],
#  ['Kobe Bryant', '17.9', '66', '38.2', 1999],
#  ['Mark Bryant', '4.6', '75', '22.8', 1999],
#  ['Greg Buckner', '4.9', '48', '19.2', 1999],
#  ['Jud Buechler', '2.7', '58', '11.3', 1999],
#  ['Rodney Buford', '4.4', '34', '11.4', 1999],
#  ['Matt Bullard', '6.1', '56', '18.3', 1999],
#  ['Scott Burrell', '5.7', '74', '18.1', 1999],
#  ['Jason Caffey', '9.5', '71', '30.4', 1999],
#  ['Michael Cage', '1.2', '20', '12.1', 1999],
#  ['Marcus Camby', '8.0', '59', '26.2', 1999],
#  ['Elden Campbell', '10.6', '78', '32.5', 1999],
#  ['Antoine Carr', '3.0', '21', '10.5', 1999],
#  ['Chris Carr', '8.7', '57', '20.5', 1999],
#  ['Anthony Carter', '6.4', '79', '23.5', 1999],
#  ['Vince Carter', '20.7', '82', '38.1', 1999],
#  ['Sam Cassell', '14.4', '81', '35.8', 1999],
#  ['Kelvin Cato', '6.2', '65', '24.3', 1999],
#  ['Duane Causwell', '1.5', '25', '7.4', 1999],
#  ['Cedric Ceballos', '14.5', '69', '29.9', 1999],
#  ['John Celestand', '2.8', '16', '11.6', 1999],
#  ['Rex Chapman', '6.0', '53', '18.1', 1999],
#  ['Calbert Cheaney', '4.1', '67', '19.5', 1999],
#  ['Pete Chilcutt', '2.3', '56', '10.7', 1999],
#  ['Chris Childs', '5.0', '71', '23.6', 1999],
#  ['Doug Christie', '10.5', '73', '31.0', 1999],
#  ['Keon Clark', '6.5', '81', '22.8', 1999],
#  ['Keith Closs', '3.5', '57', '14.4', 1999],
#  ['Derrick Coleman', '13.2', '74', '31.7', 1999],
#  ['Bimbo Coles', '7.6', '80', '24.1', 1999],
#  ['Marty Conlon', '0.7', '3', '3.0', 1999],
#  ['Tyrone Corbin', '4.6', '54', '17.4', 1999],
#  ['Chris Crawford', '4.2', '55', '12.1', 1999],
#  ['Austin Croshere', '8.1', '81', '23.3', 1999],
#  ['John Crotty', '3.6', '69', '13.6', 1999],
#  ['Terry Cummings', '8.0', '22', '18.1', 1999],
#  ['Vonteego Cummings', '8.7', '75', '23.9', 1999],
#  ['Bill Curley', '2.4', '28', '11.0', 1999],
#  ['Dell Curry', '6.8', '67', '16.3', 1999],
#  ['Michael Curry', '4.6', '82', '19.6', 1999],
#  ['Erick Dampier', '8.2', '21', '23.6', 1999],
#  ['Antonio Daniels', '5.1', '68', '17.6', 1999],
#  ['Kornél Dávid', '4.9', '32', '14.8', 1999],
#  ['Antonio Davis', '9.0', '79', '31.4', 1999],
#  ['Baron Davis', '5.3', '82', '18.6', 1999],
#  ['Ben Davis', '1.2', '5', '4.4', 1999],
#  ['Dale Davis', '8.1', '74', '28.7', 1999],
#  ['Emanual Davis', '4.1', '54', '13.0', 1999],
#  ['Hubert Davis', '5.9', '79', '23.0', 1999],
#  ['Mark Davis', '6.0', '23', '20.2', 1999],
#  ['Ricky Davis', '3.9', '48', '11.9', 1999],
#  ['Todd Day', '5.7', '58', '16.2', 1999],
#  ['Andrew DeClercq', '5.4', '82', '22.3', 1999],
#  ['Vinny Del Negro', '4.9', '67', '18.1', 1999],
#  ['Tony Delk', '6.1', '46', '14.8', 1999],
#  ['Derrick Dial', '5.8', '8', '11.9', 1999],
#  ['Michael Dickerson', '15.5', '82', '37.8', 1999],
#  ['Vlade Divac', '9.3', '82', '29.0', 1999],
#  ['Michael Doleac', '6.6', '81', '16.5', 1999],
#  ['Sherman Douglas', '4.5', '20', '15.5', 1999],
#  ['Bryce Drew', '5.7', '72', '18.0', 1999],
#  ['Chris Dudley', '1.4', '47', '9.8', 1999],
#  ['Tim Duncan', '17.3', '74', '38.9', 1999],
#  ['Howard Eisley', '8.2', '82', '25.6', 1999],
#  ['Obinna Ekezie', '2.3', '39', '9.0', 1999],
#  ['Mario Elie', '5.8', '79', '28.1', 1999],
#  ['Sean Elliott', '5.6', '19', '20.6', 1999],
#  ['Dale Ellis', '3.8', '42', '13.4', 1999],
#  ['LaPhonso Ellis', '8.0', '58', '22.6', 1999],
#  ['Pervis Ellison', '1.4', '30', '9.0', 1999],
#  ['Evan Eschmeyer', '2.3', '31', '12.0', 1999],
#  ['Patrick Ewing', '12.5', '62', '32.8', 1999],
#  ['Tony Farmer', '4.2', '74', '16.2', 1999],
#  ['Jamie Feick', '5.2', '81', '27.7', 1999],
#  ['Danny Ferry', '6.0', '63', '21.0', 1999],
#  ['Michael Finley', '20.0', '82', '42.2', 1999],
#  ['Derek Fisher', '6.2', '78', '23.1', 1999],
#  ['Danny Fortson', '4.8', '55', '15.6', 1999],
#  ['Greg Foster', '3.7', '60', '12.0', 1999],
#  ['Jeff Foster', '1.2', '19', '4.5', 1999],
#  ['Rick Fox', '6.1', '82', '18.0', 1999],
#  ['Adonal Foyle', '5.0', '76', '21.8', 1999],
#  ['Steve Francis', '14.5', '77', '36.1', 1999],
#  ['Todd Fuller', '3.0', '41', '9.7', 1999],
#  ['Lawrence Funderburke', '4.7', '75', '13.7', 1999],
#  ['Kevin Garnett', '18.8', '81', '40.0', 1999],
#  ['Dean Garrett', '1.9', '56', '10.8', 1999],
#  ['Kiwane Garris', '3.3', '3', '7.7', 1999],
#  ['Pat Garrity', '7.1', '82', '18.0', 1999],
#  ['Chris Gatling', '9.4', '85', '21.3', 1999],
#  ['Matt Geiger', '9.1', '65', '21.6', 1999],
#  ['Devean George', '2.9', '49', '7.0', 1999],
#  ['Kendall Gill', '12.6', '76', '31.0', 1999],
#  ['Armen Gilliam', '6.1', '50', '15.6', 1999],
#  ['Dion Glover', '5.7', '30', '14.9', 1999],
#  ['Brian Grant', '5.6', '63', '21.0', 1999],
#  ['Gary Grant', '4.7', '3', '8.0', 1999],
#  ['Horace Grant', '7.9', '76', '35.4', 1999],
#  ['Devin Gray', '1.8', '21', '5.9', 1999],
#  ['A.C. Green', '4.7', '82', '23.5', 1999],
#  ['Adrian Griffin', '5.7', '72', '26.8', 1999],
#  ['Tom Gugliotta', '11.9', '54', '32.7', 1999],
#  ['Darvin Ham', '3.7', '35', '22.6', 1999],
#  ['Richard Hamilton', '8.5', '71', '19.3', 1999],
#  ['Thomas Hamilton', '3.6', '22', '12.4', 1999],
#  ['Tom Hammonds', '1.7', '56', '6.6', 1999],
#  ['Anfernee Hardaway', '13.3', '60', '37.6', 1999],
#  ['Tim Hardaway', '12.3', '52', '32.2', 1999],
#  ['Ron Harper', '6.6', '80', '25.5', 1999],
#  ['Matt Harpring', '4.3', '4', '15.8', 1999],
#  ['Al Harrington', '5.3', '50', '17.1', 1999],
#  ['Othella Harrington', '10.1', '82', '32.6', 1999],
#  ['Lucious Harris', '6.0', '77', '19.6', 1999],
#  ['Antonio Harvey', '1.6', '19', '7.2', 1999],
#  ['Hersey Hawkins', '6.1', '61', '26.6', 1999],
#  ['Michael Hawkins', '1.1', '12', '3.0', 1999],
#  ['Alan Henderson', '11.3', '82', '33.8', 1999],
#  ['Cedric Henderson', '5.3', '61', '18.1', 1999],
#  ['Mark Hendrickson', '0.5', '15', '4.7', 1999],
#  ['Chris Herren', '2.8', '45', '13.3', 1999],
#  ['Grant Hill', '19.2', '74', '37.5', 1999],
#  ['Tyrone Hill', '9.6', '68', '31.7', 1999],
#  ['Fred Hoiberg', '7.4', '31', '27.3', 1999],
#  ['Derek Hood', '1.5', '2', '2.0', 1999],
#  ['Jeff Hornacek', '9.5', '77', '27.7', 1999],
#  ['Robert Horry', '4.8', '76', '22.2', 1999],
#  ['Allan Houston', '15.5', '82', '38.6', 1999],
#  ['Juwan Howard', '13.5', '82', '35.5', 1999],
#  ['Troy Hudson', '8.7', '62', '25.7', 1999],
#  ['Larry Hughes', '14.0', '82', '28.3', 1999],
#  ['Rick Hughes', '3.4', '21', '10.7', 1999],
#  ['Lindsey Hunter', '10.9', '82', '35.6', 1999],
#  ['Allen Iverson', '24.8', '70', '40.8', 1999],
#  ['Bobby Jackson', '4.7', '73', '14.2', 1999],
#  ['Jaren Jackson', '6.0', '81', '20.9', 1999],
#  ['Jermaine Jackson', '1.6', '7', '10.4', 1999],
#  ['Jim Jackson', '15.6', '79', '35.0', 1999],
#  ['Mark Jackson', '7.0', '81', '27.0', 1999],
#  ['Randell Jackson', '0.0', '1', '1.0', 1999],
#  ['Sam Jacobson', '4.1', '52', '13.1', 1999],
#  ['Tim James', '3.5', '4', '5.8', 1999],
#  ['Antawn Jamison', '17.6', '43', '36.2', 1999],
#  ['Harold Jamison', '1.7', '12', '6.2', 1999],
#  ['Anthony Johnson', '2.9', '56', '11.4', 1999],
#  ['Avery Johnson', '10.4', '82', '31.4', 1999],
#  ['DeMarco Johnson', '1.8', '5', '7.4', 1999],
#  ['Ervin Johnson', '3.5', '80', '26.6', 1999],
#  ['Kevin Johnson', '4.7', '6', '18.8', 1999],
#  ['Larry Johnson', '9.3', '70', '32.6', 1999],
#  ['Charles Jones', '3.6', '56', '11.8', 1999],
#  ['Damon Jones', '3.8', '55', '11.1', 1999],
#  ['Eddie Jones', '15.5', '72', '39.0', 1999],
#  ['Jumaine Jones', '1.8', '33', '4.2', 1999],
#  ['Popeye Jones', '2.6', '40', '8.3', 1999],
#  ['Reggie Jordan', '1.5', '36', '6.8', 1999],
#  ['Adam Keefe', '2.1', '62', '9.7', 1999],
#  ['Shawn Kemp', '14.1', '82', '30.4', 1999],
#  ['Steve Kerr', '2.3', '32', '8.4', 1999],
#  ['Jerome Kersey', '4.9', '72', '18.2', 1999],
#  ['Lari Ketner', '1.5', '22', '6.0', 1999],
#  ['Jason Kidd', '12.8', '67', '39.0', 1999],
#  ['Gerard King', '4.5', '62', '17.1', 1999],
#  ['Kerry Kittles', '11.3', '62', '30.6', 1999],
#  ['Joe Kleine', '1.6', '7', '4.4', 1999],
#  ['Brevin Knight', '8.6', '65', '27.0', 1999],
#  ['Travis Knight', '1.9', '63', '6.5', 1999],
#  ['Toni Kukoč', '13.0', '56', '31.9', 1999],
#  ['Christian Laettner', '9.8', '82', '29.8', 1999],
#  ['Raef LaFrentz', '10.9', '81', '30.1', 1999],
#  ['Andrew Lang', '3.4', '19', '12.8', 1999],
#  ['Antonio Lang', '0.6', '10', '3.8', 1999],
#  ['Trajan Langdon', '4.0', '10', '14.5', 1999],
#  ['Rusty LaRue', '10.8', '4', '32.3', 1999],
#  ['Tim Legler', '3.4', '23', '12.3', 1999],
#  ['Voshon Lenard', '10.6', '53', '27.1', 1999],
#  ['Quincy Lewis', '4.0', '74', '12.1', 1999],
#  ['Rashard Lewis', '6.9', '82', '19.2', 1999],
#  ['Randy Livingston', '4.7', '79', '13.7', 1999],
#  ['Grant Long', '4.0', '42', '21.9', 1999],
#  ['Luc Longley', '5.5', '72', '19.7', 1999],
#  ['Felipe López', '4.0', '65', '12.0', 1999],
#  ['Tyronn Lue', '4.9', '8', '18.3', 1999],
#  ['George Lynch', '8.6', '75', '32.2', 1999],
#  ['Todd MacCulloch', '2.9', '56', '9.4', 1999],
#  ['Sam Mack', '5.3', '23', '14.5', 1999],
#  ['Don MacLean', '3.1', '16', '8.9', 1999],
#  ['Corey Maggette', '6.1', '77', '17.8', 1999],
#  ['Dan Majerle', '6.1', '69', '33.4', 1999],
#  ['Karl Malone', '18.0', '82', '35.9', 1999],
#  ['Matt Maloney', '6.2', '51', '23.0', 1999],
#  ['Danny Manning', '4.7', '72', '16.9', 1999],
#  ['Stephon Marbury', '17.8', '74', '38.9', 1999],
#  ['Shawn Marion', '9.2', '51', '24.7', 1999],
#  ['Sean Marks', '1.2', '5', '2.4', 1999],
#  ['Donny Marshall', '1.8', '6', '6.5', 1999],
#  ['Donyell Marshall', '13.1', '64', '32.4', 1999],
#  ['Darrick Martin', '4.9', '71', '12.6', 1999],
#  ['Jamal Mashburn', '15.2', '76', '37.2', 1999],
#  ['Anthony Mason', '8.1', '82', '38.2', 1999],
#  ['Tony Massenburg', '3.6', '10', '10.9', 1999],
#  ['Vernon Maxwell', '10.4', '47', '21.0', 1999],
#  ['Walter McCarty', '3.8', '61', '14.4', 1999],
#  ['George McCloud', '8.2', '78', '27.2', 1999],
#  ['Jelani McCoy', '3.1', '58', '12.9', 1999],
#  ['Antonio McDyess', '15.0', '81', '33.3', 1999],
#  ['Tracy McGrady', '12.9', '79', '31.2', 1999],
#  ['Jim McIlvaine', '2.3', '66', '15.9', 1999],
#  ['Jeff McInnis', '7.4', '25', '23.9', 1999],
#  ['Derrick McKey', '3.4', '32', '19.8', 1999],
#  ['Aaron McKie', '7.2', '82', '23.8', 1999],
#  ['Roshown McLeod', '7.5', '44', '19.5', 1999],
#  ['Ron Mercer', '15.9', '68', '35.0', 1999],
#  ['Andre Miller', '9.2', '82', '25.5', 1999],
#  ['Anthony Miller', '2.8', '35', '13.6', 1999],
#  ['Brad Miller', '5.3', '55', '17.5', 1999],
#  ['Oliver Miller', '4.6', '51', '21.3', 1999],
#  ['Reggie Miller', '12.9', '81', '36.9', 1999],
#  ['Chris Mills', '14.6', '20', '32.5', 1999],
#  ['Terry Mills', '6.0', '82', '22.5', 1999],
#  ['Jason Miskiri', '1.0', '1', '3.0', 1999],
#  ['Sam Mitchell', '5.7', '66', '18.6', 1999],
#  ['Cuttino Mobley', '12.5', '81', '30.8', 1999],
#  ['Nazr Mohammed', '1.9', '28', '6.8', 1999],
#  ['Eric Montross', '1.1', '51', '6.5', 1999],
#  ['Mikki Moore', '4.8', '29', '16.8', 1999],
#  ['Alonzo Mourning', '15.0', '79', '34.8', 1999],
#  ['Chris Mullin', '4.0', '47', '12.4', 1999],
#  ['Eric Murdock', '5.1', '40', '17.3', 1999],
#  ['Gheorghe Mureșan', '3.0', '30', '8.9', 1999],
#  ['Lamond Murray', '13.8', '74', '32.0', 1999],
#  ['Tracy Murray', '8.4', '80', '22.9', 1999],
#  ['Dikembe Mutombo', '7.0', '82', '36.4', 1999],
#  ['Steve Nash', '6.5', '56', '27.4', 1999],
#  ['Tyrone Nesby', '12.5', '73', '31.7', 1999],
#  ['Rasho Nesterović', '5.3', '82', '21.0', 1999],
#  ['Johnny Newman', '7.6', '82', '21.5', 1999],
#  ['Moochie Norris', '5.3', '30', '16.7', 1999],
#  ['Dirk Nowitzki', '13.6', '82', '35.8', 1999],
#  ["Jermaine O'Neal", '3.2', '70', '12.3', 1999],
#  ["Shaquille O'Neal", '21.1', '79', '40.0', 1999],
#  ['Charles Oakley', '7.0', '80', '30.4', 1999],
#  ['Lamar Odom', '13.5', '76', '36.4', 1999],
#  ['Hakeem Olajuwon', '9.6', '44', '23.8', 1999],
#  ['Kevin Ollie', '1.2', '40', '7.3', 1999],
#  ['Michael Olowokandi', '9.5', '80', '31.2', 1999],
#  ['Greg Ostertag', '3.3', '81', '19.8', 1999],
#  ['Bo Outlaw', '4.1', '82', '28.4', 1999],
#  ['Doug Overton', '3.2', '48', '9.0', 1999],
#  ['Billy Owens', '5.8', '62', '21.0', 1999],
#  ['Robert Pack', '7.9', '29', '22.9', 1999],
#  ['Scott Padgett', '3.0', '47', '9.2', 1999],
#  ['Milt Palacio', '1.8', '53', '7.4', 1999],
#  ['Anthony Parker', '3.6', '16', '11.6', 1999],
#  ['Cherokee Parks', '2.6', '56', '14.4', 1999],
#  ['Andrae Patterson', '0.8', '5', '4.0', 1999],
#  ['Ruben Patterson', '8.2', '81', '25.9', 1999],
#  ['Gary Payton', '20.3', '82', '41.8', 1999],
#  ['Anthony Peeler', '8.8', '82', '25.3', 1999],
#  ['Will Perdue', '2.5', '67', '15.1', 1999],
#  ['Sam Perkins', '5.4', '81', '20.0', 1999],
#  ['Elliot Perry', '4.9', '60', '13.4', 1999],
#  ['Chuck Person', '3.3', '37', '9.2', 1999],
#  ['Wesley Person', '8.3', '79', '26.0', 1999],
#  ['Bobby Phills', '12.0', '28', '29.5', 1999],
#  ['Eric Piatkowski', '7.6', '75', '22.8', 1999],
#  ['Paul Pierce', '15.1', '73', '35.4', 1999],
#  ['Scottie Pippen', '10.5', '82', '33.5', 1999],
#  ['Scot Pollard', '3.7', '76', '17.6', 1999],
#  ['Olden Polynice', '4.9', '82', '22.2', 1999],
#  ['Terry Porter', '6.8', '68', '23.7', 1999],
#  ['James Posey', '6.6', '81', '25.3', 1999],
#  ['Vitaly Potapenko', '7.8', '79', '22.7', 1999],
#  ['Brent Price', '2.9', '41', '10.3', 1999],
#  ['Laron Profit', '1.8', '33', '6.8', 1999],
#  ['Aleksandar Radojević', '2.3', '3', '8.0', 1999],
#  ['Theo Ratliff', '8.6', '57', '31.5', 1999],
#  ['Eldridge Recasner', '1.0', '7', '4.0', 1999],
#  ['Bryant Reeves', '8.1', '69', '25.7', 1999],
#  ['Khalid Reeves', '4.0', '3', '16.0', 1999],
#  ['Don Reid', '2.9', '38', '13.1', 1999],
#  ['J.R. Reid', '3.7', '34', '17.7', 1999],
#  ['Rodrick Rhodes', '3.0', '1', '8.0', 1999],
#  ['Glen Rice', '12.3', '80', '31.6', 1999],
#  ['Mitch Richmond', '14.2', '74', '32.4', 1999],
#  ['Isaiah Rider', '17.9', '60', '34.7', 1999],
#  ['Stanley Roberts', '3.2', '5', '10.2', 1999],
#  ['Ryan Robertson', '6.0', '1', '25.0', 1999],
#  ['Clifford Robinson', '14.3', '80', '35.5', 1999],
#  ['David Robinson', '12.9', '80', '32.0', 1999],
#  ['Eddie Robinson', '5.8', '67', '16.6', 1999],
#  ['Glenn Robinson', '18.0', '81', '35.9', 1999],
#  ['Dennis Rodman', '2.6', '12', '32.4', 1999],
#  ['Carlos Rogers', '6.1', '53', '20.8', 1999],
#  ['Rodney Rogers', '10.7', '82', '27.9', 1999],
#  ['Roy Rogers', '2.2', '40', '8.9', 1999],
#  ['Sean Rooks', '4.0', '71', '14.1', 1999],
#  ['Jalen Rose', '15.0', '80', '37.2', 1999],
#  ['Malik Rose', '5.2', '74', '18.1', 1999],
#  ['Michael Ruffin', '1.9', '71', '13.7', 1999],
#  ['Bryon Russell', '11.1', '82', '35.4', 1999],
#  ['Arvydas Sabonis', '9.1', '66', '25.6', 1999],
#  ['John Salley', '1.5', '45', '6.7', 1999],
#  ['Detlef Schrempf', '5.6', '77', '21.6', 1999],
#  ['Dennis Scott', '5.0', '66', '19.1', 1999],
#  ['Malik Sealy', '9.5', '82', '29.2', 1999],
#  ['Brian Shaw', '4.4', '74', '16.9', 1999],
#  ['Dickey Simpkins', '4.0', '69', '23.9', 1999],
#  ['Brian Skinner', '4.1', '33', '23.5', 1999],
#  ['Joe Smith', '8.0', '78', '25.3', 1999],
#  ['Michael Smith', '4.2', '46', '24.9', 1999],
#  ['Steve Smith', '11.0', '82', '32.8', 1999],
#  ['Rik Smits', '11.3', '79', '23.4', 1999],
#  ['Eric Snow', '7.3', '82', '35.0', 1999],
#  ['Felton Spencer', '1.3', '26', '5.7', 1999],
#  ['Latrell Sprewell', '15.9', '82', '40.0', 1999],
#  ['Ryan Stack', '2.0', '25', '7.9', 1999],
#  ['Jerry Stackhouse', '17.6', '82', '38.4', 1999],
#  ['John Starks', '14.6', '37', '32.2', 1999],
#  ['Vladimir Stepania', '2.6', '30', '6.7', 1999],
#  ['Joe Stephens', '3.9', '13', '13.9', 1999],
#  ['Michael Stewart', '1.3', '42', '9.3', 1999],
#  ['Bryant Stith', '4.2', '45', '15.4', 1999],
#  ['John Stockton', '8.8', '82', '29.7', 1999],
#  ['Peja Stojaković', '9.7', '74', '23.6', 1999],
#  ['Damon Stoudamire', '11.5', '78', '30.4', 1999],
#  ['Erick Strickland', '10.7', '68', '29.8', 1999],
#  ['Mark Strickland', '3.9', '58', '11.4', 1999],
#  ['Rod Strickland', '11.0', '69', '31.7', 1999],
#  ['Derek Strong', '2.4', '20', '7.4', 1999],
#  ['Bruno Šundov', '2.2', '14', '4.4', 1999],
#  ['Bob Sura', '11.2', '73', '30.4', 1999],
#  ['Wally Szczerbiak', '9.2', '73', '29.7', 1999],
#  ['Žan Tabak', '1.9', '18', '6.3', 1999],
#  ['Johnny Taylor', '2.3', '6', '5.7', 1999],
#  ['Maurice Taylor', '15.9', '62', '35.9', 1999],
#  ['Jason Terry', '7.4', '81', '23.3', 1999],
#  ['Jamel Thomas', '2.6', '7', '6.6', 1999],
#  ['John Thomas', '1.9', '55', '8.7', 1999],
#  ['Kenny Thomas', '7.4', '72', '25.0', 1999],
#  ['Kurt Thomas', '6.7', '80', '24.6', 1999],
#  ['Tim Thomas', '9.4', '80', '26.2', 1999],
#  ['Otis Thorpe', '4.8', '51', '15.2', 1999],
#  ['Robert Traylor', '2.8', '44', '10.2', 1999],
#  ['Gary Trent', '12.9', '11', '27.4', 1999],
#  ['Mirsad Türkcan', '2.2', '17', '5.3', 1999],
#  ['Wayne Turner', '2.0', '3', '13.7', 1999],
#  ['Nick Van Exel', '15.4', '79', '37.3', 1999],
#  ['Keith Van Horn', '15.7', '80', '34.8', 1999],
#  ['Jacque Vaughn', '3.4', '78', '11.3', 1999],
#  ['Loy Vaught', '2.1', '43', '6.8', 1999],
#  ['Fred Vinson', '2.1', '8', '5.0', 1999],
#  ['Antoine Walker', '18.4', '82', '36.6', 1999],
#  ['Samaki Walker', '4.3', '71', '13.8', 1999],
#  ['Ben Wallace', '4.1', '81', '24.2', 1999],
#  ['John Wallace', '5.5', '60', '13.3', 1999],
#  ['Rasheed Wallace', '12.9', '81', '35.1', 1999],
#  ['Rex Walters', '2.8', '33', '11.8', 1999],
#  ['Charlie Ward', '6.2', '72', '27.6', 1999],
#  ['Clarence Weatherspoon', '5.4', '78', '20.7', 1999],
#  ['Chris Webber', '20.6', '75', '38.4', 1999],
#  ['Bonzi Wells', '7.3', '66', '17.6', 1999],
#  ['Bill Wennington', '2.7', '7', '8.1', 1999],
#  ['David Wesley', '11.6', '82', '33.7', 1999],
#  ['Doug West', '3.8', '38', '15.3', 1999],
#  ['Mark West', '0.5', '22', '5.8', 1999],
#  ['Jahidi White', '5.6', '80', '19.2', 1999],
#  ['Chris Whitney', '6.4', '82', '19.8', 1999],
#  ['Aaron Williams', '5.6', '81', '19.1', 1999],
#  ['Alvin Williams', '5.2', '55', '14.2', 1999],
#  ['Eric Williams', '5.7', '68', '20.3', 1999],
#  ['Jason Williams', '12.0', '81', '34.1', 1999],
#  ['Jerome Williams', '5.6', '82', '25.6', 1999],
#  ['Lorenzo Williams', '1.1', '8', '9.5', 1999],
#  ['Monty Williams', '7.2', '75', '20.0', 1999],
#  ['Scott Williams', '6.3', '68', '21.9', 1999],
#  ['Shammond Williams', '5.2', '43', '12.0', 1999],
#  ['Walt Williams', '9.0', '76', '24.5', 1999],
#  ['Corliss Williamson', '8.2', '76', '22.5', 1999],
#  ['Kevin Willis', '7.2', '79', '21.3', 1999],
#  ['Dedric Willoughby', '7.2', '25', '20.3', 1999],
#  ['David Wingate', '1.3', '7', '4.6', 1999],
#  ['Haywoode Workman', '2.5', '36', '9.7', 1999],
#  ['Metta World Peace', '10.5', '72', '31.1', 1999],
#  ['Lorenzen Wright', '4.8', '75', '16.1', 1999],
#  ['Tim Young', '1.6', '25', '5.5', 1999],
#  ['Mahmoud Abdul-Rauf', '6.0', '41', '11.9', 2000],
#  ['Tariq Abdul-Wahad', '3.8', '29', '14.5', 2000],
#  ['Shareef Abdur-Rahim', '15.8', '81', '40.0', 2000],
#  ['Cory Alexander', '2.2', '26', '8.7', 2000],
#  ['Courtney Alexander', '8.8', '65', '21.3', 2000],
#  ['Ray Allen', '16.0', '82', '38.2', 2000],
#  ['Rafer Alston', '2.3', '37', '7.8', 2000],
#  ['John Amaechi', '7.2', '82', '20.9', 2000],
#  ['Derek Anderson', '12.1', '82', '34.9', 2000],
#  ['Kenny Anderson', '6.9', '33', '25.7', 2000],
#  ['Nick Anderson', '2.7', '21', '8.0', 2000],
#  ['Shandon Anderson', '7.2', '82', '29.2', 2000],
#  ['Greg Anthony', '4.4', '58', '14.8', 2000],
#  ['Darrell Armstrong', '13.4', '75', '36.9', 2000],
#  ['Chucky Atkins', '11.8', '81', '29.2', 2000],
#  ['Stacey Augmon', '4.0', '66', '17.9', 2000],
#  ['Isaac Austin', '5.2', '52', '16.3', 2000],
#  ['William Avery', '2.6', '55', '8.4', 2000],
#  ['Dalibor Bagarić', '1.9', '35', '7.4', 2000],
#  ['Vin Baker', '10.8', '76', '28.0', 2000],
#  ['Erick Barkley', '2.8', '8', '4.8', 2000],
#  ['Dana Barros', '6.9', '60', '18.0', 2000],
#  ['Brent Barry', '6.0', '67', '26.5', 2000],
#  ['Jon Barry', '4.1', '62', '16.3', 2000],
#  ['Tony Battie', '5.0', '40', '21.1', 2000],
#  ['Raja Bell', '1.4', '5', '6.0', 2000],
#  ['Jonathan Bender', '3.2', '59', '9.7', 2000],
#  ['Corey Benjamin', '4.6', '65', '13.2', 2000],
#  ['David Benoit', '3.0', '49', '9.1', 2000],
#  ['Travis Best', '10.2', '77', '31.9', 2000],
#  ['Mike Bibby', '14.1', '82', '38.9', 2000],
#  ['Chauncey Billups', '7.6', '77', '23.2', 2000],
#  ['Mookie Blaylock', '11.6', '69', '34.1', 2000],
#  ['Corie Blount', '4.3', '68', '19.2', 2000],
#  ['Mark Blount', '3.1', '64', '17.2', 2000],
#  ['Muggsy Bogues', '0.7', '3', '11.3', 2000],
#  ['Etdrick Bohannon', '0.7', '6', '3.2', 2000],
#  ['Calvin Booth', '4.6', '55', '17.0', 2000],
#  ['Cal Bowdler', '2.6', '44', '8.5', 2000],
#  ['Bruce Bowen', '7.1', '82', '32.7', 2000],
#  ['Ryan Bowen', '2.5', '57', '12.2', 2000],
#  ['Ira Bowman', '0.7', '3', '6.3', 2000],
#  ['Earl Boykins', '6.3', '10', '14.9', 2000],
#  ['Shawn Bradley', '5.5', '82', '24.4', 2000],
#  ['Elton Brand', '16.4', '74', '39.3', 2000],
#  ['Terrell Brandon', '14.5', '78', '36.2', 2000],
#  ['Chucky Brown', '3.7', '26', '13.0', 2000],
#  ['Dee Brown', '6.3', '7', '22.1', 2000],
#  ['P.J. Brown', '7.0', '80', '35.1', 2000],
#  ['Randy Brown', '4.4', '54', '22.9', 2000],
#  ['Rick Brunson', '2.5', '22', '9.5', 2000],
#  ['Kobe Bryant', '22.2', '68', '40.9', 2000],
#  ['Mark Bryant', '1.1', '18', '5.6', 2000],
#  ['Greg Buckner', '5.2', '37', '22.2', 2000],
#  ['Jud Buechler', '2.9', '57', '12.9', 2000],
#  ['Rodney Buford', '5.1', '47', '12.2', 2000],
#  ['Matt Bullard', '5.0', '61', '16.4', 2000],
#  ['Scott Burrell', '3.8', '4', '10.3', 2000],
#  ['Jason Caffey', '5.2', '70', '20.9', 2000],
#  ['Marcus Camby', '9.2', '63', '33.8', 2000],
#  ['Elden Campbell', '10.7', '78', '30.0', 2000],
#  ['Brian Cardinal', '2.1', '15', '8.4', 2000],
#  ['Chris Carr', '3.2', '35', '8.8', 2000],
#  ['Anthony Carter', '6.7', '72', '22.6', 2000],
#  ['Vince Carter', '22.1', '75', '39.7', 2000],
#  ['Sam Cassell', '14.9', '76', '35.6', 2000],
#  ['Kelvin Cato', '3.2', '35', '17.8', 2000],
#  ['Duane Causwell', '2.7', '31', '12.4', 2000],
#  ['Cedric Ceballos', '5.7', '40', '14.0', 2000],
#  ['Calbert Cheaney', '3.3', '9', '17.0', 2000],
#  ['Chris Childs', '4.4', '77', '24.1', 2000],
#  ['Doug Christie', '9.7', '81', '36.3', 2000],
#  ['Keon Clark', '6.4', '81', '21.2', 2000],
#  ['Mateen Cleaves', '5.1', '78', '16.3', 2000],
#  ['John Coker', '1.3', '6', '5.3', 2000],
#  ['Derrick Coleman', '7.5', '34', '20.1', 2000],
#  ['Bimbo Coles', '5.1', '47', '17.1', 2000],
#  ['Jason Collier', '3.1', '23', '9.7', 2000],
#  ['Sean Colson', '1.8', '13', '3.4', 2000],
#  ['Tyrone Corbin', '2.5', '15', '7.8', 2000],
#  ['Chris Crawford', '5.7', '47', '19.2', 2000],
#  ['Jamal Crawford', '5.0', '61', '17.2', 2000],
#  ['Austin Croshere', '8.7', '81', '23.1', 2000],
#  ['John Crotty', '2.1', '31', '8.5', 2000],
#  ['Vonteego Cummings', '7.8', '66', '22.7', 2000],
#  ['Bill Curley', '2.4', '20', '9.6', 2000],
#  ['Dell Curry', '5.4', '71', '13.5', 2000],
#  ['Michael Curry', '4.7', '68', '21.8', 2000],
#  ['Erick Dampier', '7.3', '43', '24.1', 2000],
#  ['Antonio Daniels', '7.4', '79', '26.1', 2000],
#  ['Kornél Dávid', '1.9', '27', '7.7', 2000],
#  ['Antonio Davis', '11.1', '78', '35.0', 2000],
#  ['Baron Davis', '11.7', '82', '38.9', 2000],
#  ['Dale Davis', '6.0', '81', '26.7', 2000],
#  ['Emanual Davis', '5.1', '62', '20.8', 2000],
#  ['Hubert Davis', '6.6', '66', '25.6', 2000],
#  ['Ricky Davis', '4.1', '7', '10.0', 2000],
#  ['Terry Davis', '1.3', '19', '12.0', 2000],
#  ['Todd Day', '3.8', '31', '11.1', 2000],
#  ['Andrew DeClercq', '2.9', '67', '13.5', 2000],
#  ['Vinny Del Negro', '3.6', '65', '14.2', 2000],
#  ['Tony Delk', '11.3', '82', '27.9', 2000],
#  ['Derrick Dial', '2.5', '33', '6.3', 2000],
#  ['Michael Dickerson', '14.6', '70', '37.4', 2000],
#  ['Vlade Divac', '9.3', '81', '29.9', 2000],
#  ['Michael Doleac', '6.8', '77', '18.2', 2000],
#  ['Keyon Dooling', '4.8', '76', '16.3', 2000],
#  ['Sherman Douglas', '5.1', '59', '18.5', 2000],
#  ['Bryce Drew', '6.8', '48', '27.2', 2000],
#  ['Chris Dudley', '1.4', '53', '11.6', 2000],
#  ['Tim Duncan', '17.1', '82', '38.7', 2000],
#  ['Tyus Edney', '3.8', '24', '11.0', 2000],
#  ['Kevin Edwards', '3.7', '46', '13.8', 2000],
#  ['Howard Eisley', '8.2', '82', '29.6', 2000],
#  ['Obinna Ekezie', '2.5', '33', '8.5', 2000],
#  ['Khalid El-Amin', '6.2', '50', '18.7', 2000],
#  ['Mario Elie', '3.6', '68', '22.1', 2000],
#  ['Sean Elliott', '6.5', '52', '23.6', 2000],
#  ['LaPhonso Ellis', '7.8', '82', '23.8', 2000],
#  ['Pervis Ellison', '0.8', '9', '4.4', 2000],
#  ['Evan Eschmeyer', '2.7', '74', '18.0', 2000],
#  ...]

# %%
USG()
# Out:
# [['Tariq Abdul-Wahad', '19.0', '49', '1205', 1998],
#  ['Shareef Abdur-Rahim', '28.9', '50', '2021', 1998],
#  ['Cory Alexander', '20.3', '36', '778', 1998],
#  ['Ray Allen', '24.5', '50', '1719', 1998],
#  ['Peter Aluma', '34.1', '2', '5', 1998],
#  ['Derek Anderson', '23.4', '38', '978', 1998],
#  ['Kenny Anderson', '20.9', '34', '1010', 1998],
#  ['Nick Anderson', '22.8', '47', '1581', 1998],
#  ['Shandon Anderson', '21.6', '50', '1072', 1998],
#  ['Chris Anstey', '18.2', '41', '470', 1998],
#  ['Greg Anthony', '19.6', '50', '806', 1998],
#  ['B.J. Armstrong', '15.8', '32', '358', 1998],
#  ['Darrell Armstrong', '22.9', '50', '1502', 1998],
#  ['Keith Askins', '9.4', '33', '415', 1998],
#  ['Stacey Augmon', '12.4', '48', '874', 1998],
#  ['Isaac Austin', '22.9', '49', '1259', 1998],
#  ['Anthony Avent', '22.7', '5', '44', 1998],
#  ['Thurl Bailey', '19.1', '43', '543', 1998],
#  ['Toby Bailey', '19.0', '27', '249', 1998],
#  ['LaMark Baker', '45.4', '1', '2', 1998],
#  ['Vin Baker', '22.8', '34', '1162', 1998],
#  ['Charles Barkley', '22.2', '42', '1526', 1998],
#  ['Dana Barros', '19.0', '50', '1156', 1998],
#  ['Brent Barry', '18.8', '37', '1181', 1998],
#  ['Drew Barry', '12.3', '17', '183', 1998],
#  ['Jon Barry', '12.9', '43', '736', 1998],
#  ['Tony Battie', '14.1', '50', '1121', 1998],
#  ['Corey Beck', '15.4', '24', '180', 1998],
#  ['Benoit Benjamin', '13.7', '6', '33', 1998],
#  ['Corey Benjamin', '22.9', '31', '320', 1998],
#  ['Mario Bennett', '21.7', '3', '19', 1998],
#  ['Travis Best', '18.5', '49', '1043', 1998],
#  ['Mike Bibby', '21.5', '50', '1758', 1998],
#  ['Chauncey Billups', '20.3', '45', '1488', 1998],
#  ['Mookie Blaylock', '21.5', '48', '1763', 1998],
#  ['Corie Blount', '13.0', '34', '530', 1998],
#  ['Muggsy Bogues', '13.5', '36', '714', 1998],
#  ['Etdrick Bohannon', '0.0', '2', '4', 1998],
#  ['Keith Booth', '22.7', '39', '432', 1998],
#  ['Bruce Bowen', '10.5', '30', '494', 1998],
#  ['Earl Boykins', '21.5', '22', '221', 1998],
#  ['Shawn Bradley', '16.1', '49', '1294', 1998],
#  ['Terrell Brandon', '23.0', '36', '1217', 1998],
#  ['Chucky Brown', '17.4', '48', '1192', 1998],
#  ['Dee Brown', '19.7', '49', '1377', 1998],
#  ['Gerald Brown', '22.9', '33', '236', 1998],
#  ['P.J. Brown', '18.7', '50', '1611', 1998],
#  ['Randy Brown', '18.4', '39', '1139', 1998],
#  ['Rick Brunson', '20.7', '17', '95', 1998],
#  ['Kobe Bryant', '25.3', '50', '1896', 1998],
#  ['Mark Bryant', '18.1', '45', '1204', 1998],
#  ['Jud Buechler', '12.1', '50', '1056', 1998],
#  ['Matt Bullard', '15.1', '41', '413', 1998],
#  ['Scott Burrell', '15.6', '32', '706', 1998],
#  ['Willie Burton', '25.7', '3', '18', 1998],
#  ['Mitchell Butler', '21.2', '31', '418', 1998],
#  ['Jason Caffey', '20.0', '35', '876', 1998],
#  ['Marcus Camby', '17.5', '46', '945', 1998],
#  ['Elden Campbell', '21.3', '49', '1459', 1998],
#  ['Antoine Carr', '19.8', '18', '152', 1998],
#  ['Chris Carr', '24.8', '39', '445', 1998],
#  ['Cory Carr', '20.8', '42', '624', 1998],
#  ['Vince Carter', '25.6', '50', '1760', 1998],
#  ['Sam Cassell', '31.0', '8', '199', 1998],
#  ['Kelvin Cato', '15.6', '43', '545', 1998],
#  ['Duane Causwell', '21.0', '19', '137', 1998],
#  ['Cedric Ceballos', '24.7', '13', '352', 1998],
#  ['Rex Chapman', '21.6', '38', '1183', 1998],
#  ['Calbert Cheaney', '17.7', '50', '1266', 1998],
#  ['Pete Chilcutt', '13.7', '46', '697', 1998],
#  ['Chris Childs', '14.3', '48', '1297', 1998],
#  ['Doug Christie', '22.5', '50', '1768', 1998],
#  ['Keon Clark', '13.0', '28', '409', 1998],
#  ['Keith Closs', '17.4', '15', '87', 1998],
#  ['John Coker', '16.8', '14', '98', 1998],
#  ['Derrick Coleman', '23.3', '37', '1178', 1998],
#  ['Bimbo Coles', '18.9', '48', '1272', 1998],
#  ['Marty Conlon', '23.8', '7', '35', 1998],
#  ['Tyrone Corbin', '18.2', '47', '1066', 1998],
#  ['James Cotton', '22.2', '10', '59', 1998],
#  ['Chris Crawford', '20.0', '42', '784', 1998],
#  ['Austin Croshere', '20.8', '27', '249', 1998],
#  ['John Crotty', '21.3', '27', '382', 1998],
#  ['Terry Cummings', '23.4', '50', '1011', 1998],
#  ['William Cunningham', '6.5', '16', '162', 1998],
#  ['Bill Curley', '10.8', '35', '372', 1998],
#  ['Dell Curry', '21.9', '42', '864', 1998],
#  ['Michael Curry', '11.6', '50', '1146', 1998],
#  ['Erick Dampier', '18.7', '50', '1414', 1998],
#  ['Antonio Daniels', '19.4', '47', '614', 1998],
#  ['Kornél Dávid', '17.7', '50', '902', 1998],
#  ['Antonio Davis', '18.2', '49', '1271', 1998],
#  ['Ben Davis', '47.2', '8', '21', 1998],
#  ['Dale Davis', '13.9', '50', '1374', 1998],
#  ['Hubert Davis', '15.9', '50', '1378', 1998],
#  ['Mark Davis', '22.1', '4', '35', 1998],
#  ['Ricky Davis', '23.8', '46', '557', 1998],
#  ['Terry Davis', '9.9', '37', '578', 1998],
#  ['Andrew DeClercq', '17.0', '47', '1102', 1998],
#  ['Terry Dehere', '16.3', '26', '291', 1998],
#  ['Vinny Del Negro', '15.2', '48', '1093', 1998],
#  ['Bison Dele', '24.0', '49', '1177', 1998],
#  ['Tony Delk', '23.2', '36', '630', 1998],
#  ['Michael Dickerson', '16.9', '50', '1558', 1998],
#  ['Vlade Divac', '19.4', '50', '1761', 1998],
#  ['Michael Doleac', '19.1', '49', '780', 1998],
#  ['Sherman Douglas', '17.2', '30', '842', 1998],
#  ['Bryce Drew', '17.4', '34', '441', 1998],
#  ['Chris Dudley', '10.5', '46', '685', 1998],
#  ['Joe Dumars', '18.3', '38', '1116', 1998],
#  ['Tim Duncan', '27.2', '50', '1963', 1998],
#  ['Blue Edwards', '17.2', '24', '283', 1998],
#  ['Howard Eisley', '21.1', '50', '1038', 1998],
#  ['Mario Elie', '16.0', '47', '1291', 1998],
#  ['Sean Elliott', '19.7', '50', '1509', 1998],
#  ['Dale Ellis', '17.3', '48', '1232', 1998],
#  ['LaPhonso Ellis', '21.9', '20', '539', 1998],
#  ['Brian Evans', '14.5', '16', '145', 1998],
#  ['Patrick Ewing', '28.4', '38', '1300', 1998],
#  ['Jamie Feick', '10.1', '28', '852', 1998],
#  ['Duane Ferrell', '16.2', '8', '46', 1998],
#  ['Danny Ferry', '16.1', '50', '1058', 1998],
#  ['Michael Finley', '24.2', '50', '2051', 1998],
#  ['Derek Fisher', '14.9', '50', '1131', 1998],
#  ['Danny Fortson', '18.0', '50', '1417', 1998],
#  ['Greg Foster', '17.9', '42', '458', 1998],
#  ['Rick Fox', '20.3', '44', '944', 1998],
#  ['Adonal Foyle', '12.6', '44', '614', 1998],
#  ['Todd Fuller', '17.9', '42', '462', 1998],
#  ['Lawrence Funderburke', '18.4', '47', '936', 1998],
#  ['Kevin Garnett', '27.8', '47', '1780', 1998],
#  ['Marlon Garnett', '15.6', '24', '205', 1998],
#  ['Dean Garrett', '11.8', '49', '1054', 1998],
#  ['Pat Garrity', '18.4', '39', '538', 1998],
#  ['Chris Gatling', '22.0', '48', '775', 1998],
#  ['Andrew Gaze', '23.2', '19', '58', 1998],
#  ['Matt Geiger', '21.6', '50', '1540', 1998],
#  ['Kendall Gill', '20.3', '50', '1606', 1998],
#  ['Armen Gilliam', '21.7', '34', '668', 1998],
#  ['Brian Grant', '17.3', '48', '1525', 1998],
#  ['Gary Grant', '6.5', '2', '7', 1998],
#  ['Harvey Grant', '11.5', '47', '798', 1998],
#  ['Horace Grant', '14.5', '50', '1660', 1998],
#  ['Paul Grant', '27.9', '6', '13', 1998],
#  ['Ed Gray', '31.7', '30', '337', 1998],
#  ['A.C. Green', '14.8', '50', '924', 1998],
#  ['Litterial Green', '24.4', '1', '2', 1998],
#  ['Tom Gugliotta', '22.4', '43', '1563', 1998],
#  ['Tom Hammonds', '15.0', '49', '716', 1998],
#  ['Anfernee Hardaway', '22.4', '50', '1944', 1998],
#  ['Tim Hardaway', '26.5', '48', '1772', 1998],
#  ['Derek Harper', '14.4', '45', '1120', 1998],
#  ['Ron Harper', '21.2', '35', '1107', 1998],
#  ['Matt Harpring', '18.6', '50', '1114', 1998],
#  ['Al Harrington', '22.0', '21', '160', 1998],
#  ['Othella Harrington', '21.8', '41', '903', 1998],
#  ['Lucious Harris', '16.1', '36', '602', 1998],
#  ['Hersey Hawkins', '15.1', '50', '1644', 1998],
#  ['Michael Hawkins', '11.4', '24', '203', 1998],
#  ['Alan Henderson', '22.5', '38', '1142', 1998],
#  ['Cedric Henderson', '19.0', '50', '1517', 1998],
#  ['J.R. Henderson', '18.6', '30', '331', 1998],
#  ['Mark Hendrickson', '13.8', '22', '399', 1998],
#  ['Steve Henson', '11.2', '4', '25', 1998],
#  ['Carl Herrera', '14.3', '28', '307', 1998],
#  ['Grant Hill', '29.6', '50', '1852', 1998],
#  ['Tyrone Hill', '16.5', '38', '1104', 1998],
#  ['Fred Hoiberg', '14.7', '12', '87', 1998],
#  ['Jerald Honeycutt', '20.3', '16', '102', 1998],
#  ['Jeff Hornacek', '19.7', '48', '1435', 1998],
#  ['Robert Horry', '13.0', '38', '744', 1998],
#  ['Allan Houston', '24.3', '50', '1815', 1998],
#  ['Juwan Howard', '24.6', '36', '1430', 1998],
#  ['Troy Hudson', '17.7', '25', '524', 1998],
#  ['Larry Hughes', '25.2', '50', '988', 1998],
#  ['Lindsey Hunter', '17.7', '49', '1755', 1998],
#  ['Zydrunas Ilgauskas', '22.6', '5', '171', 1998],
#  ['Allen Iverson', '32.6', '48', '1990', 1998],
#  ['Bobby Jackson', '21.4', '50', '941', 1998],
#  ['Jaren Jackson', '18.3', '47', '861', 1998],
#  ['Jim Jackson', '19.3', '49', '1175', 1998],
#  ['Mark Jackson', '16.0', '49', '1382', 1998],
#  ['Randell Jackson', '25.2', '27', '271', 1998],
#  ['Sam Jacobson', '25.8', '2', '12', 1998],
#  ['Jerome James', '38.9', '16', '42', 1998],
#  ['Antawn Jamison', '22.2', '47', '1058', 1998],
#  ['Anthony Johnson', '17.3', '49', '885', 1998],
#  ['Avery Johnson', '17.0', '50', '1672', 1998],
#  ['Eddie Johnson', '39.2', '3', '18', 1998],
#  ['Ervin Johnson', '13.1', '50', '1027', 1998],
#  ['Larry Johnson', '18.1', '49', '1639', 1998],
#  ['Charles Jones', '16.0', '29', '476', 1998],
#  ['Damon Jones', '18.5', '24', '344', 1998],
#  ['Eddie Jones', '20.0', '50', '1881', 1998],
#  ['Popeye Jones', '14.2', '18', '206', 1998],
#  ['Adonis Jordan', '20.6', '4', '18', 1998],
#  ['Reggie Jordan', '12.6', '27', '296', 1998],
#  ['Adam Keefe', '14.6', '44', '642', 1998],
#  ['Shawn Kemp', '28.9', '42', '1475', 1998],
#  ['Jonathan Kerner', '9.1', '1', '5', 1998],
#  ['Steve Kerr', '13.4', '44', '734', 1998],
#  ['Jerome Kersey', '15.7', '45', '699', 1998],
#  ['Jason Kidd', '21.4', '50', '2060', 1998],
#  ['Chris King', '14.5', '8', '42', 1998],
#  ['Gerard King', '19.1', '19', '63', 1998],
#  ['Kerry Kittles', '20.5', '46', '1570', 1998],
#  ['Joe Kleine', '11.0', '31', '374', 1998],
#  ['Brevin Knight', '19.8', '39', '1186', 1998],
#  ['Negele Knight', '13.6', '6', '56', 1998],
#  ['Travis Knight', '15.3', '37', '525', 1998],
#  ['Toni Kukoč', '27.5', '44', '1654', 1998],
#  ['Christian Laettner', '21.2', '16', '337', 1998],
#  ['Raef LaFrentz', '18.6', '12', '387', 1998],
#  ['Andrew Lang', '15.4', '21', '386', 1998],
#  ['Antonio Lang', '10.5', '10', '65', 1998],
#  ['Rusty LaRue', '16.6', '43', '732', 1998],
#  ['Tim Legler', '16.1', '30', '377', 1998],
#  ['Voshon Lenard', '23.6', '12', '190', 1998],
#  ['Rashard Lewis', '24.4', '20', '145', 1998],
#  ['Randy Livingston', '20.7', '1', '22', 1998],
#  ['Grant Long', '18.3', '50', '1380', 1998],
#  ['Luc Longley', '18.6', '39', '933', 1998],
#  ['Felipe López', '19.6', '47', '1218', 1998],
#  ['Tyronn Lue', '20.4', '15', '188', 1998],
#  ['George Lynch', '16.0', '43', '1315', 1998],
#  ['Sam Mack', '19.0', '44', '1083', 1998],
#  ['Don MacLean', '27.2', '17', '365', 1998],
#  ['Mark Macon', '17.9', '7', '69', 1998],
#  ['Rick Mahorn', '9.8', '16', '127', 1998],
#  ['Dan Majerle', '11.4', '48', '1624', 1998],
#  ['Karl Malone', '30.5', '49', '1832', 1998],
#  ['Matt Maloney', '11.8', '15', '186', 1998],
#  ['Danny Manning', '19.7', '50', '1184', 1998],
#  ['Stephon Marbury', '27.2', '49', '1895', 1998],
#  ['Sean Marks', '19.2', '8', '28', 1998],
#  ['Donyell Marshall', '22.3', '48', '1250', 1998],
#  ['Darrick Martin', '18.3', '37', '941', 1998],
#  ['Jamal Mashburn', '23.3', '24', '855', 1998],
#  ['Tony Massenburg', '20.9', '43', '1143', 1998],
#  ['Vernon Maxwell', '22.8', '46', '1007', 1998],
#  ['Lee Mayberry', '11.7', '9', '126', 1998],
#  ['Kelly McCarty', '56.6', '2', '4', 1998],
#  ['Walter McCarty', '16.4', '32', '659', 1998],
#  ['George McCloud', '15.3', '48', '1245', 1998],
#  ['Jelani McCoy', '14.3', '26', '331', 1998],
#  ['Antonio McDyess', '27.3', '50', '1937', 1998],
#  ['Tracy McGrady', '21.9', '49', '1106', 1998],
#  ['Jim McIlvaine', '10.9', '22', '269', 1998],
#  ['Jeff McInnis', '19.0', '35', '427', 1998],
#  ['Derrick McKey', '14.0', '13', '244', 1998],
#  ['Aaron McKie', '15.2', '50', '959', 1998],
#  ['Roshown McLeod', '27.8', '34', '348', 1998],
#  ['Ron Mercer', '24.2', '41', '1551', 1998],
#  ['Loren Meyer', '21.3', '14', '70', 1998],
#  ['Marko Milič', '22.7', '11', '53', 1998],
#  ['Anthony Miller', '14.9', '29', '249', 1998],
#  ['Brad Miller', '21.7', '38', '469', 1998],
#  ['Oliver Miller', '18.3', '4', '35', 1998],
#  ['Reggie Miller', '22.9', '50', '1787', 1998],
#  ['Chris Mills', '17.6', '47', '1395', 1998],
#  ['Terry Mills', '20.3', '1', '29', 1998],
#  ['Greg Minor', '15.4', '44', '765', 1998],
#  ['Sam Mitchell', '20.6', '50', '1344', 1998],
#  ['Cuttino Mobley', '17.2', '49', '1456', 1998],
#  ['Nazr Mohammed', '23.7', '26', '121', 1998],
#  ['Eric Montross', '9.1', '46', '577', 1998],
#  ['Mikki Moore', '14.9', '2', '6', 1998],
#  ['Chris Morris', '16.4', '44', '535', 1998],
#  ['Alonzo Mourning', '27.1', '46', '1753', 1998],
#  ['Chris Mullin', '19.1', '50', '1179', 1998],
#  ['Eric Murdock', '17.0', '15', '401', 1998],
#  ['Gheorghe Mureșan', '88.3', '1', '1', 1998],
#  ['Lamond Murray', '25.7', '50', '1317', 1998],
#  ['Tracy Murray', '20.1', '36', '653', 1998],
#  ['Dikembe Mutombo', '14.3', '50', '1829', 1998],
#  ["Makhtar N'Diaye", '11.5', '4', '27', 1998],
#  ['Steve Nash', '15.1', '40', '1269', 1998],
#  ['Tyrone Nesby', '18.2', '50', '1288', 1998],
#  ['Rasho Nesterović', '20.3', '2', '30', 1998],
#  ['Johnny Newman', '16.9', '50', '949', 1998],
#  ['Moochie Norris', '20.4', '12', '140', 1998],
#  ['Dirk Nowitzki', '22.3', '47', '958', 1998],
#  ["Charles O'Bannon", '19.4', '18', '165', 1998],
#  ["Jermaine O'Neal", '16.5', '36', '311', 1998],
#  ["Shaquille O'Neal", '32.4', '49', '1705', 1998],
#  ['Charles Oakley', '12.8', '50', '1633', 1998],
#  ['Hakeem Olajuwon', '25.9', '50', '1784', 1998],
#  ['Jimmy Oliver', '12.6', '2', '11', 1998],
#  ['Kevin Ollie', '12.0', '8', '72', 1998],
#  ['Michael Olowokandi', '19.0', '45', '1279', 1998],
#  ['Greg Ostertag', '10.9', '48', '1340', 1998],
#  ['Bo Outlaw', '13.2', '31', '851', 1998],
#  ['Doug Overton', '20.6', '24', '244', 1998],
#  ['Billy Owens', '21.5', '21', '451', 1998],
#  ['Robert Pack', '25.7', '25', '468', 1998],
#  ['Anthony Parker', '15.1', '2', '3', 1998],
#  ['Cherokee Parks', '14.3', '48', '1118', 1998],
#  ['Andrae Patterson', '20.9', '35', '284', 1998],
#  ['Ruben Patterson', '24.0', '24', '144', 1998],
#  ['Gary Payton', '27.1', '50', '2008', 1998],
#  ['Anthony Peeler', '17.8', '28', '810', 1998],
#  ['Will Perdue', '9.8', '37', '445', 1998],
#  ['Sam Perkins', '15.1', '48', '789', 1998],
#  ['Elliot Perry', '22.0', '35', '290', 1998],
#  ['Chuck Person', '16.5', '50', '990', 1998],
#  ['Wesley Person', '18.2', '45', '1342', 1998],
#  ['Bobby Phills', '20.0', '43', '1574', 1998],
#  ['Eric Piatkowski', '18.8', '49', '1242', 1998],
#  ['Paul Pierce', '23.1', '48', '1632', 1998],
#  ['Scottie Pippen', '19.7', '50', '2011', 1998],
#  ['Scot Pollard', '12.5', '16', '259', 1998],
#  ['Olden Polynice', '13.7', '48', '1481', 1998],
#  ['Mark Pope', '15.5', '4', '26', 1998],
#  ['Terry Porter', '18.4', '50', '1365', 1998],
#  ['Vitaly Potapenko', '19.1', '50', '1394', 1998],
#  ['Brent Price', '17.4', '40', '806', 1998],
#  ['Theo Ratliff', '17.1', '50', '1627', 1998],
#  ['Eldridge Recasner', '17.4', '44', '708', 1998],
#  ['Bryant Reeves', '22.8', '25', '702', 1998],
#  ['Khalid Reeves', '14.5', '11', '112', 1998],
#  ['Don Reid', '12.4', '47', '935', 1998],
#  ['J.R. Reid', '17.5', '41', '1029', 1998],
#  ['Shawn Respert', '21.2', '12', '99', 1998],
#  ['Rodrick Rhodes', '24.5', '13', '156', 1998],
#  ['Glen Rice', '22.0', '27', '985', 1998],
#  ['Pooh Richardson', '16.3', '11', '130', 1998],
#  ['Mitch Richmond', '25.7', '50', '1912', 1998],
#  ['Isaiah Rider', '25.3', '47', '1385', 1998],
#  ['Eric Riley', '12.4', '35', '337', 1998],
#  ['Stanley Roberts', '29.3', '6', '33', 1998],
#  ['Clifford Robinson', '21.8', '50', '1740', 1998],
#  ['David Robinson', '23.8', '49', '1554', 1998],
#  ['Glenn Robinson', '28.2', '47', '1579', 1998],
#  ['James Robinson', '21.8', '31', '506', 1998],
#  ['Dennis Rodman', '6.5', '23', '657', 1998],
#  ['Carlos Rogers', '21.5', '2', '8', 1998],
#  ['Rodney Rogers', '19.1', '47', '968', 1998],
#  ['Sean Rooks', '17.3', '36', '315', 1998],
#  ['Jalen Rose', '24.7', '49', '1238', 1998],
#  ['Malik Rose', '24.6', '47', '608', 1998],
#  ['Bryon Russell', '16.7', '50', '1770', 1998],
#  ['Arvydas Sabonis', '21.7', '50', '1349', 1998],
#  ['Jason Sasser', '16.3', '6', '39', 1998],
#  ['Danny Schayes', '12.9', '19', '143', 1998],
#  ['Dwayne Schintzius', '18.5', '16', '67', 1998],
#  ['Detlef Schrempf', '19.5', '50', '1765', 1998],
#  ['Dennis Scott', '15.0', '36', '738', 1998],
#  ['Malik Sealy', '17.5', '31', '731', 1998],
#  ['Rony Seikaly', '19.0', '9', '88', 1998],
#  ['Charles Shackleford', '16.8', '32', '367', 1998],
#  ['Brian Shaw', '18.3', '1', '5', 1998],
#  ['Casey Shaw', '32.4', '9', '14', 1998],
#  ['Jeff Sheppard', '13.2', '18', '185', 1998],
#  ['Miles Simon', '19.1', '5', '19', 1998],
#  ['Dickey Simpkins', '16.3', '50', '1448', 1998],
#  ['Alvin Sims', '33.6', '4', '25', 1998],
#  ['Brian Skinner', '18.4', '21', '258', 1998],
#  ['Reggie Slater', '24.7', '30', '263', 1998],
#  ['Charles Smith', '17.8', '23', '317', 1998],
#  ['Joe Smith', '20.8', '43', '1418', 1998],
#  ['Michael Smith', '10.9', '48', '1098', 1998],
#  ['Steve Smith', '26.4', '36', '1314', 1998],
#  ['Rik Smits', '28.9', '49', '1271', 1998],
#  ['Eric Snow', '13.9', '48', '1716', 1998],
#  ['Felton Spencer', '14.9', '26', '159', 1998],
#  ['Latrell Sprewell', '26.5', '37', '1233', 1998],
#  ['Ryan Stack', '13.4', '18', '199', 1998],
#  ['Jerry Stackhouse', '28.7', '42', '1188', 1998],
#  ['John Starks', '22.5', '50', '1686', 1998],
#  ['Vladimir Stepania', '25.3', '23', '313', 1998],
#  ['Michael Stewart', '8.7', '42', '394', 1998],
#  ['Bryant Stith', '13.9', '46', '1194', 1998],
#  ['John Stockton', '20.1', '50', '1410', 1998],
#  ['Peja Stojaković', '19.1', '48', '1025', 1998],
#  ['Damon Stoudamire', '21.7', '50', '1673', 1998],
#  ['Erick Strickland', '23.1', '33', '567', 1998],
#  ['Mark Strickland', '17.4', '32', '357', 1998],
#  ['Rod Strickland', '24.0', '44', '1632', 1998],
#  ['Derek Strong', '17.0', '44', '695', 1998],
#  ['Bruno Šundov', '33.4', '3', '11', 1998],
#  ['Bob Sura', '18.7', '50', '841', 1998],
#  ['Johnny Taylor', '15.1', '36', '724', 1998],
#  ['Maurice Taylor', '26.7', '46', '1505', 1998],
#  ['John Thomas', '12.6', '39', '593', 1998],
#  ['Kurt Thomas', '19.8', '50', '1182', 1998],
#  ['Tim Thomas', '21.7', '50', '812', 1998],
#  ['Otis Thorpe', '17.2', '49', '1539', 1998],
#  ['Robert Traylor', '16.9', '49', '786', 1998],
#  ['Gary Trent', '26.0', '45', '1362', 1998],
#  ['Nick Van Exel', '24.3', '50', '1802', 1998],
#  ['Keith Van Horn', '28.5', '42', '1576', 1998],
#  ['David Vaughn', '16.9', '10', '103', 1998],
#  ['Jacque Vaughn', '30.0', '19', '87', 1998],
#  ['Loy Vaught', '17.6', '37', '481', 1998],
#  ['Stojko Vranković', '15.1', '2', '12', 1998],
#  ['Antoine Walker', '27.2', '42', '1549', 1998],
#  ['Samaki Walker', '21.8', '39', '568', 1998],
#  ['Ben Wallace', '11.0', '46', '1231', 1998],
#  ['John Wallace', '27.4', '48', '812', 1998],
#  ['Rasheed Wallace', '20.5', '49', '1414', 1998],
#  ['Rex Walters', '13.4', '33', '506', 1998],
#  ['Charlie Ward', '15.4', '50', '1556', 1998],
#  ['Eric Washington', '13.8', '38', '761', 1998],
#  ['Jamie Watson', '8.2', '3', '18', 1998],
#  ['Clarence Weatherspoon', '18.4', '49', '1040', 1998],
#  ['Chris Webber', '24.9', '42', '1719', 1998],
#  ['Bonzi Wells', '44.4', '7', '35', 1998],
#  ['Bill Wennington', '21.4', '38', '451', 1998],
#  ['David Wesley', '19.8', '50', '1848', 1998],
#  ['Doug West', '13.7', '14', '294', 1998],
#  ['Mark West', '9.0', '49', '499', 1998],
#  ['DeJuan Wheat', '20.6', '46', '590', 1998],
#  ['Tyson Wheeler', '28.4', '1', '3', 1998],
#  ['Jahidi White', '15.3', '20', '191', 1998],
#  ['Chris Whitney', '21.5', '39', '441', 1998],
#  ['Dominique Wilkins', '31.2', '27', '252', 1998],
#  ['Gerald Wilkins', '20.9', '3', '28', 1998],
#  ['Aaron Williams', '18.4', '40', '458', 1998],
#  ['Alvin Williams', '13.6', '50', '1051', 1998],
#  ['Brandon Williams', '20.5', '3', '4', 1998],
#  ['Eric Williams', '19.1', '38', '780', 1998],
#  ['Herb Williams', '15.4', '6', '34', 1998],
#  ['Hot Rod Williams', '5.7', '25', '403', 1998],
#  ['Jason Williams', '19.1', '50', '1805', 1998],
#  ['Jayson Williams', '13.0', '30', '1020', 1998],
#  ['Jerome Williams', '14.8', '50', '1154', 1998],
#  ['Micheal Williams', '18.1', '2', '15', 1998],
#  ['Monty Williams', '21.7', '1', '6', 1998],
#  ['Scott Williams', '24.8', '7', '46', 1998],
#  ['Shammond Williams', '32.5', '2', '4', 1998],
#  ['Travis Williams', '15.9', '8', '62', 1998],
#  ['Walt Williams', '20.0', '48', '1044', 1998],
#  ['Corliss Williamson', '22.1', '50', '1374', 1998],
#  ['Kevin Willis', '22.4', '42', '1216', 1998],
#  ['David Wingate', '11.5', '20', '92', 1998],
#  ['Trevor Winter', '0.0', '1', '5', 1998],
#  ['Joe Wolf', '7.4', '3', '12', 1998],
#  ['Haywoode Workman', '14.9', '29', '815', 1998],
#  ['Lorenzen Wright', '14.4', '48', '1135', 1998],
#  ['Korleone Young', '37.6', '3', '15', 1998],
#  ['Tariq Abdul-Wahad', '22.5', '61', '1578', 1999],
#  ['Shareef Abdur-Rahim', '25.0', '82', '3223', 1999],
#  ['Cory Alexander', '18.0', '29', '329', 1999],
#  ['Ray Allen', '25.6', '82', '3070', 1999],
#  ['Rafer Alston', '15.5', '27', '361', 1999],
#  ['John Amaechi', '24.1', '80', '1684', 1999],
#  ['Derek Anderson', '23.4', '64', '2201', 1999],
#  ['Kenny Anderson', '20.5', '82', '2593', 1999],
#  ['Nick Anderson', '18.1', '72', '2094', 1999],
#  ['Shandon Anderson', '17.6', '82', '2700', 1999],
#  ['Chris Anstey', '23.1', '73', '1007', 1999],
#  ['Greg Anthony', '16.4', '82', '1548', 1999],
#  ['B.J. Armstrong', '18.6', '27', '583', 1999],
#  ['Darrell Armstrong', '23.9', '82', '2590', 1999],
#  ['Chucky Atkins', '24.3', '82', '1626', 1999],
#  ['Stacey Augmon', '15.8', '59', '692', 1999],
#  ['Isaac Austin', '19.6', '59', '1173', 1999],
#  ['Anthony Avent', '15.8', '49', '377', 1999],
#  ['William Avery', '22.3', '59', '484', 1999],
#  ['Toby Bailey', '18.9', '46', '449', 1999],
#  ['Vin Baker', '23.6', '79', '2849', 1999],
#  ['Charles Barkley', '22.3', '20', '620', 1999],
#  ['Dana Barros', '20.4', '72', '1139', 1999],
#  ['Brent Barry', '14.9', '80', '2726', 1999],
#  ['Drew Barry', '13.1', '16', '159', 1999],
#  ['Jon Barry', '15.7', '62', '1281', 1999],
#  ['Tony Battie', '17.1', '82', '1505', 1999],
#  ['Jonathan Bender', '30.6', '24', '130', 1999],
#  ['Benoit Benjamin', '16.3', '3', '8', 1999],
#  ['Corey Benjamin', '24.4', '48', '862', 1999],
#  ['Mario Bennett', '44.4', '1', '3', 1999],
#  ['Travis Best', '20.2', '82', '1691', 1999],
#  ['Mike Bibby', '20.0', '82', '3155', 1999],
#  ['Chauncey Billups', '20.6', '13', '305', 1999],
#  ['Mookie Blaylock', '17.5', '73', '2459', 1999],
#  ['Corie Blount', '13.0', '38', '446', 1999],
#  ['Muggsy Bogues', '11.6', '80', '1731', 1999],
#  ['Etdrick Bohannon', '12.7', '13', '118', 1999],
#  ['Calvin Booth', '18.0', '11', '143', 1999],
#  ['Lazaro Borrell', '19.5', '17', '167', 1999],
#  ['Cal Bowdler', '16.0', '46', '423', 1999],
#  ['Bruce Bowen', '12.1', '69', '878', 1999],
#  ['Ryan Bowen', '11.4', '52', '589', 1999],
#  ['Ira Bowman', '8.5', '11', '20', 1999],
#  ['Earl Boykins', '23.8', '26', '261', 1999],
#  ['Shawn Bradley', '16.1', '77', '1901', 1999],
#  ['A.J. Bramlett', '17.1', '8', '61', 1999],
#  ['Elton Brand', '27.0', '81', '2999', 1999],
#  ['Terrell Brandon', '23.0', '71', '2587', 1999],
#  ['Chucky Brown', '16.5', '63', '1096', 1999],
#  ['Dee Brown', '20.0', '38', '673', 1999],
#  ['Marcus Brown', '17.5', '6', '45', 1999],
#  ['P.J. Brown', '17.1', '80', '2302', 1999],
#  ['Randy Brown', '16.2', '59', '1625', 1999],
#  ['Rick Brunson', '17.9', '37', '289', 1999],
#  ['Kobe Bryant', '26.8', '66', '2524', 1999],
#  ['Mark Bryant', '12.0', '75', '1712', 1999],
#  ['Greg Buckner', '14.2', '48', '923', 1999],
#  ['Jud Buechler', '11.5', '58', '657', 1999],
#  ['Rodney Buford', '20.5', '34', '386', 1999],
#  ['Matt Bullard', '16.7', '56', '1024', 1999],
#  ['Scott Burrell', '16.0', '74', '1336', 1999],
#  ['Jason Caffey', '19.4', '71', '2159', 1999],
#  ['Michael Cage', '5.4', '20', '242', 1999],
#  ['Marcus Camby', '19.6', '59', '1548', 1999],
#  ['Elden Campbell', '19.7', '78', '2538', 1999],
#  ['Antoine Carr', '16.3', '21', '221', 1999],
#  ['Chris Carr', '26.1', '57', '1166', 1999],
#  ['Anthony Carter', '18.5', '79', '1859', 1999],
#  ['Vince Carter', '30.0', '82', '3126', 1999],
#  ['Sam Cassell', '25.0', '81', '2899', 1999],
#  ['Kelvin Cato', '15.7', '65', '1581', 1999],
#  ['Duane Causwell', '16.1', '25', '185', 1999],
#  ['Cedric Ceballos', '26.4', '69', '2064', 1999],
#  ['John Celestand', '15.1', '16', '185', 1999],
#  ['Rex Chapman', '18.1', '53', '957', 1999],
#  ['Calbert Cheaney', '10.9', '67', '1309', 1999],
#  ['Pete Chilcutt', '11.3', '56', '601', 1999],
#  ['Chris Childs', '13.8', '71', '1675', 1999],
#  ['Doug Christie', '19.6', '73', '2264', 1999],
#  ['Keon Clark', '17.2', '81', '1850', 1999],
#  ['Keith Closs', '14.4', '57', '820', 1999],
#  ['Derrick Coleman', '25.2', '74', '2347', 1999],
#  ['Bimbo Coles', '17.4', '80', '1924', 1999],
#  ['Marty Conlon', '9.9', '3', '9', 1999],
#  ['Tyrone Corbin', '13.0', '54', '941', 1999],
#  ['Chris Crawford', '20.0', '55', '668', 1999],
#  ['Austin Croshere', '21.1', '81', '1885', 1999],
#  ['John Crotty', '16.2', '69', '937', 1999],
#  ['Terry Cummings', '23.4', '22', '398', 1999],
#  ['Vonteego Cummings', '20.2', '75', '1793', 1999],
#  ['Bill Curley', '13.7', '28', '309', 1999],
#  ['Dell Curry', '20.5', '67', '1095', 1999],
#  ['Michael Curry', '14.3', '82', '1611', 1999],
#  ['Erick Dampier', '19.1', '21', '495', 1999],
#  ['Antonio Daniels', '17.2', '68', '1195', 1999],
#  ['Kornél Dávid', '20.7', '32', '474', 1999],
#  ['Antonio Davis', '17.8', '79', '2479', 1999],
#  ['Baron Davis', '18.9', '82', '1523', 1999],
#  ['Ben Davis', '18.0', '5', '22', 1999],
#  ['Dale Davis', '16.7', '74', '2127', 1999],
#  ['Emanual Davis', '17.7', '54', '701', 1999],
#  ['Hubert Davis', '13.8', '79', '1817', 1999],
#  ['Mark Davis', '17.9', '23', '464', 1999],
#  ['Ricky Davis', '20.1', '48', '570', 1999],
#  ['Todd Day', '20.0', '58', '941', 1999],
#  ['Andrew DeClercq', '14.8', '82', '1831', 1999],
#  ['Vinny Del Negro', '14.3', '67', '1211', 1999],
#  ['Tony Delk', '20.6', '46', '682', 1999],
#  ['Derrick Dial', '26.3', '8', '95', 1999],
#  ['Michael Dickerson', '23.1', '82', '3103', 1999],
#  ['Vlade Divac', '19.3', '82', '2374', 1999],
#  ['Michael Doleac', '20.2', '81', '1335', 1999],
#  ['Sherman Douglas', '18.2', '20', '309', 1999],
#  ['Bryce Drew', '17.1', '72', '1293', 1999],
#  ['Chris Dudley', '10.0', '47', '459', 1999],
#  ['Tim Duncan', '28.7', '74', '2875', 1999],
#  ['Howard Eisley', '18.8', '82', '2096', 1999],
#  ['Obinna Ekezie', '18.4', '39', '351', 1999],
#  ['Mario Elie', '13.6', '79', '2217', 1999],
#  ['Sean Elliott', '16.4', '19', '391', 1999],
#  ['Dale Ellis', '14.6', '42', '564', 1999],
#  ['LaPhonso Ellis', '18.9', '58', '1309', 1999],
#  ['Pervis Ellison', '10.5', '30', '269', 1999],
#  ['Evan Eschmeyer', '12.7', '31', '373', 1999],
#  ['Patrick Ewing', '24.3', '62', '2035', 1999],
#  ['Tony Farmer', '17.9', '74', '1199', 1999],
#  ['Jamie Feick', '10.8', '81', '2241', 1999],
#  ['Danny Ferry', '15.1', '63', '1326', 1999],
#  ['Michael Finley', '25.1', '82', '3464', 1999],
#  ['Derek Fisher', '15.1', '78', '1803', 1999],
#  ['Danny Fortson', '21.0', '55', '856', 1999],
#  ['Greg Foster', '16.3', '60', '718', 1999],
#  ['Jeff Foster', '19.0', '19', '86', 1999],
#  ['Rick Fox', '18.5', '82', '1473', 1999],
#  ['Adonal Foyle', '12.5', '76', '1654', 1999],
#  ['Steve Francis', '25.0', '77', '2776', 1999],
#  ['Todd Fuller', '19.4', '41', '399', 1999],
#  ['Lawrence Funderburke', '18.8', '75', '1026', 1999],
#  ['Kevin Garnett', '27.4', '81', '3243', 1999],
#  ['Dean Garrett', '10.5', '56', '604', 1999],
#  ['Kiwane Garris', '20.1', '3', '23', 1999],
#  ['Pat Garrity', '20.4', '82', '1479', 1999],
#  ['Chris Gatling', '26.7', '85', '1811', 1999],
#  ['Matt Geiger', '23.1', '65', '1406', 1999],
#  ['Devean George', '23.3', '49', '345', 1999],
#  ['Kendall Gill', '21.9', '76', '2355', 1999],
#  ['Armen Gilliam', '23.5', '50', '782', 1999],
#  ['Dion Glover', '22.8', '30', '446', 1999],
#  ['Brian Grant', '17.8', '63', '1322', 1999],
#  ['Gary Grant', '30.8', '3', '24', 1999],
#  ['Horace Grant', '11.6', '76', '2688', 1999],
#  ['Devin Gray', '19.0', '21', '124', 1999],
#  ['A.C. Green', '11.0', '82', '1929', 1999],
#  ['Adrian Griffin', '13.0', '72', '1927', 1999],
#  ['Tom Gugliotta', '20.4', '54', '1767', 1999],
#  ['Darvin Ham', '10.7', '35', '792', 1999],
#  ['Richard Hamilton', '24.2', '71', '1373', 1999],
#  ['Thomas Hamilton', '18.8', '22', '273', 1999],
#  ['Tom Hammonds', '17.3', '56', '372', 1999],
#  ['Anfernee Hardaway', '21.1', '60', '2253', 1999],
#  ['Tim Hardaway', '22.8', '52', '1672', 1999],
#  ['Ron Harper', '15.6', '80', '2042', 1999],
#  ['Matt Harpring', '14.1', '4', '63', 1999],
#  ['Al Harrington', '20.1', '50', '854', 1999],
#  ['Othella Harrington', '20.0', '82', '2677', 1999],
#  ['Lucious Harris', '16.2', '77', '1510', 1999],
#  ['Antonio Harvey', '15.9', '19', '137', 1999],
#  ['Hersey Hawkins', '14.9', '61', '1622', 1999],
#  ['Michael Hawkins', '21.0', '12', '36', 1999],
#  ['Alan Henderson', '19.4', '82', '2775', 1999],
#  ['Cedric Henderson', '17.3', '61', '1107', 1999],
#  ['Mark Hendrickson', '7.8', '15', '71', 1999],
#  ['Chris Herren', '13.4', '45', '597', 1999],
#  ['Grant Hill', '30.5', '74', '2776', 1999],
#  ['Tyrone Hill', '18.2', '68', '2155', 1999],
#  ['Fred Hoiberg', '16.6', '31', '845', 1999],
#  ['Derek Hood', '33.6', '2', '4', 1999],
#  ['Jeff Hornacek', '19.9', '77', '2133', 1999],
#  ['Robert Horry', '12.7', '76', '1685', 1999],
#  ['Allan Houston', '24.0', '82', '3169', 1999],
#  ['Juwan Howard', '22.2', '82', '2909', 1999],
#  ['Troy Hudson', '19.2', '62', '1592', 1999],
#  ['Larry Hughes', '27.8', '82', '2324', 1999],
#  ['Rick Hughes', '19.2', '21', '224', 1999],
#  ['Lindsey Hunter', '16.6', '82', '2919', 1999],
#  ['Allen Iverson', '34.4', '70', '2853', 1999],
#  ['Bobby Jackson', '19.5', '73', '1034', 1999],
#  ['Jaren Jackson', '15.7', '81', '1691', 1999],
#  ['Jermaine Jackson', '13.0', '7', '73', 1999],
#  ['Jim Jackson', '24.2', '79', '2767', 1999],
#  ['Mark Jackson', '16.3', '81', '2190', 1999],
#  ['Randell Jackson', '0.0', '1', '1', 1999],
#  ['Sam Jacobson', '16.3', '52', '681', 1999],
#  ['Tim James', '35.1', '4', '23', 1999],
#  ['Antawn Jamison', '26.0', '43', '1556', 1999],
#  ['Harold Jamison', '20.1', '12', '74', 1999],
#  ['Anthony Johnson', '14.6', '56', '637', 1999],
#  ['Avery Johnson', '19.0', '82', '2571', 1999],
#  ['DeMarco Johnson', '15.4', '5', '37', 1999],
#  ['Ervin Johnson', '8.9', '80', '2129', 1999],
#  ['Kevin Johnson', '14.8', '6', '113', 1999],
#  ['Larry Johnson', '17.0', '70', '2281', 1999],
#  ['Charles Jones', '16.0', '56', '662', 1999],
#  ['Damon Jones', '19.2', '55', '612', 1999],
#  ['Eddie Jones', '23.4', '72', '2807', 1999],
#  ['Jumaine Jones', '25.4', '33', '138', 1999],
#  ['Popeye Jones', '16.5', '40', '330', 1999],
#  ['Reggie Jordan', '14.2', '36', '243', 1999],
#  ['Adam Keefe', '14.7', '62', '604', 1999],
#  ['Shawn Kemp', '30.2', '82', '2492', 1999],
#  ['Steve Kerr', '14.8', '32', '268', 1999],
#  ['Jerome Kersey', '14.9', '72', '1310', 1999],
#  ['Lari Ketner', '15.8', '22', '132', 1999],
#  ['Jason Kidd', '20.0', '67', '2616', 1999],
#  ['Gerard King', '14.5', '62', '1060', 1999],
#  ['Kerry Kittles', '19.0', '62', '1896', 1999],
#  ['Joe Kleine', '21.3', '7', '31', 1999],
#  ['Brevin Knight', '19.7', '65', '1754', 1999],
#  ['Travis Knight', '16.7', '63', '410', 1999],
#  ['Toni Kukoč', '24.9', '56', '1784', 1999],
#  ['Christian Laettner', '20.1', '82', '2443', 1999],
#  ['Raef LaFrentz', '19.3', '81', '2435', 1999],
#  ['Andrew Lang', '14.0', '19', '244', 1999],
#  ['Antonio Lang', '11.9', '10', '38', 1999],
#  ['Trajan Langdon', '15.2', '10', '145', 1999],
#  ['Rusty LaRue', '18.8', '4', '129', 1999],
#  ['Tim Legler', '13.6', '23', '284', 1999],
#  ['Voshon Lenard', '22.3', '53', '1434', 1999],
#  ['Quincy Lewis', '18.9', '74', '896', 1999],
#  ['Rashard Lewis', '19.6', '82', '1575', 1999],
#  ['Randy Livingston', '20.1', '79', '1081', 1999],
#  ['Grant Long', '12.2', '42', '920', 1999],
#  ['Luc Longley', '18.0', '72', '1417', 1999],
#  ['Felipe López', '21.1', '65', '781', 1999],
#  ['Tyronn Lue', '15.5', '8', '146', 1999],
#  ['George Lynch', '15.3', '75', '2416', 1999],
#  ['Todd MacCulloch', '17.5', '56', '528', 1999],
#  ['Sam Mack', '18.9', '23', '333', 1999],
#  ['Don MacLean', '18.4', '16', '143', 1999],
#  ['Corey Maggette', '22.1', '77', '1370', 1999],
#  ['Dan Majerle', '10.4', '69', '2308', 1999],
#  ['Karl Malone', '31.9', '82', '2947', 1999],
#  ['Matt Maloney', '15.6', '51', '1175', 1999],
#  ['Danny Manning', '15.2', '72', '1217', 1999],
#  ['Stephon Marbury', '28.2', '74', '2881', 1999],
#  ['Shawn Marion', '19.6', '51', '1260', 1999],
#  ['Sean Marks', '39.7', '5', '12', 1999],
#  ['Donny Marshall', '18.6', '6', '39', 1999],
#  ['Donyell Marshall', '21.9', '64', '2071', 1999],
#  ['Darrick Martin', '21.7', '71', '893', 1999],
#  ['Jamal Mashburn', '23.8', '76', '2828', 1999],
#  ['Anthony Mason', '14.4', '82', '3133', 1999],
#  ['Tony Massenburg', '21.0', '10', '109', 1999],
#  ['Vernon Maxwell', '27.1', '47', '989', 1999],
#  ['Walter McCarty', '15.8', '61', '879', 1999],
#  ['George McCloud', '17.5', '78', '2118', 1999],
#  ['Jelani McCoy', '15.5', '58', '746', 1999],
#  ['Antonio McDyess', '26.9', '81', '2698', 1999],
#  ['Tracy McGrady', '24.3', '79', '2462', 1999],
#  ['Jim McIlvaine', '9.2', '66', '1048', 1999],
#  ['Jeff McInnis', '16.4', '25', '597', 1999],
#  ['Derrick McKey', '10.9', '32', '634', 1999],
#  ['Aaron McKie', '17.3', '82', '1952', 1999],
#  ['Roshown McLeod', '21.7', '44', '860', 1999],
#  ['Ron Mercer', '24.4', '68', '2377', 1999],
#  ['Andre Miller', '21.8', '82', '2093', 1999],
#  ['Anthony Miller', '12.8', '35', '476', 1999],
#  ['Brad Miller', '19.9', '55', '961', 1999],
#  ['Oliver Miller', '13.7', '51', '1088', 1999],
#  ['Reggie Miller', '20.5', '81', '2987', 1999],
#  ['Chris Mills', '23.0', '20', '649', 1999],
#  ['Terry Mills', '13.1', '82', '1842', 1999],
#  ['Jason Miskiri', '14.9', '1', '3', 1999],
#  ['Sam Mitchell', '16.9', '66', '1227', 1999],
#  ['Cuttino Mobley', '23.9', '81', '2496', 1999],
#  ['Nazr Mohammed', '18.9', '28', '190', 1999],
#  ['Eric Montross', '10.9', '51', '332', 1999],
#  ['Mikki Moore', '17.4', '29', '488', 1999],
#  ['Alonzo Mourning', '28.1', '79', '2748', 1999],
#  ['Chris Mullin', '18.2', '47', '582', 1999],
#  ['Eric Murdock', '19.1', '40', '693', 1999],
#  ['Gheorghe Mureșan', '20.5', '30', '267', 1999],
#  ['Lamond Murray', '24.3', '74', '2365', 1999],
#  ['Tracy Murray', '19.8', '80', '1831', 1999],
#  ['Dikembe Mutombo', '13.8', '82', '2984', 1999],
#  ['Steve Nash', '14.5', '56', '1532', 1999],
#  ['Tyrone Nesby', '21.1', '73', '2317', 1999],
#  ['Rasho Nesterović', '14.4', '82', '1723', 1999],
#  ['Johnny Newman', '20.5', '82', '1763', 1999],
#  ['Moochie Norris', '19.3', '30', '502', 1999],
#  ['Dirk Nowitzki', '21.2', '82', '2938', 1999],
#  ["Jermaine O'Neal", '16.8', '70', '859', 1999],
#  ["Shaquille O'Neal", '31.2', '79', '3163', 1999],
#  ['Charles Oakley', '13.7', '80', '2431', 1999],
#  ['Lamar Odom', '23.5', '76', '2767', 1999],
#  ['Hakeem Olajuwon', '22.7', '44', '1049', 1999],
#  ['Kevin Ollie', '11.4', '40', '290', 1999],
#  ['Michael Olowokandi', '18.1', '80', '2493', 1999],
#  ['Greg Ostertag', '12.3', '81', '1606', 1999],
#  ['Bo Outlaw', '9.8', '82', '2326', 1999],
#  ['Doug Overton', '18.4', '48', '432', 1999],
#  ['Billy Owens', '16.3', '62', '1305', 1999],
#  ['Robert Pack', '22.6', '29', '665', 1999],
#  ['Scott Padgett', '18.6', '47', '432', 1999],
#  ['Milt Palacio', '18.3', '53', '394', 1999],
#  ['Anthony Parker', '16.6', '16', '185', 1999],
#  ['Cherokee Parks', '10.7', '56', '808', 1999],
#  ['Andrae Patterson', '11.3', '5', '20', 1999],
#  ['Ruben Patterson', '19.9', '81', '2097', 1999],
#  ['Gary Payton', '26.8', '82', '3425', 1999],
#  ['Anthony Peeler', '18.7', '82', '2073', 1999],
#  ['Will Perdue', '13.2', '67', '1012', 1999],
#  ['Sam Perkins', '15.3', '81', '1620', 1999],
#  ['Elliot Perry', '21.2', '60', '803', 1999],
#  ['Chuck Person', '18.0', '37', '340', 1999],
#  ['Wesley Person', '15.8', '79', '2056', 1999],
#  ['Bobby Phills', '22.4', '28', '825', 1999],
#  ['Eric Piatkowski', '17.5', '75', '1712', 1999],
#  ['Paul Pierce', '24.8', '73', '2583', 1999],
#  ['Scottie Pippen', '19.6', '82', '2749', 1999],
#  ['Scot Pollard', '12.6', '76', '1336', 1999],
#  ['Olden Polynice', '12.9', '82', '1819', 1999],
#  ['Terry Porter', '18.3', '68', '1613', 1999],
#  ['James Posey', '14.8', '81', '2052', 1999],
#  ['Vitaly Potapenko', '20.0', '79', '1797', 1999],
#  ['Brent Price', '19.7', '41', '424', 1999],
#  ['Laron Profit', '16.2', '33', '225', 1999],
#  ['Aleksandar Radojević', '27.0', '3', '24', 1999],
#  ['Theo Ratliff', '17.2', '57', '1795', 1999],
#  ['Eldridge Recasner', '11.2', '7', '28', 1999],
#  ['Bryant Reeves', '19.3', '69', '1773', 1999],
#  ['Khalid Reeves', '19.3', '3', '48', 1999],
#  ['Don Reid', '13.3', '38', '498', 1999],
#  ['J.R. Reid', '12.7', '34', '602', 1999],
#  ['Rodrick Rhodes', '27.6', '1', '8', 1999],
#  ['Glen Rice', '22.0', '80', '2530', 1999],
#  ['Mitch Richmond', '25.0', '74', '2397', 1999],
#  ['Isaiah Rider', '28.8', '60', '2084', 1999],
#  ['Stanley Roberts', '16.6', '5', '51', 1999],
#  ['Ryan Robertson', '10.7', '1', '25', 1999],
#  ['Clifford Robinson', '22.9', '80', '2839', 1999],
#  ['David Robinson', '25.6', '80', '2557', 1999],
#  ['Eddie Robinson', '18.3', '67', '1112', 1999],
#  ['Glenn Robinson', '27.6', '81', '2909', 1999],
#  ['Dennis Rodman', '6.4', '12', '389', 1999],
#  ['Carlos Rogers', '17.8', '53', '1101', 1999],
#  ['Rodney Rogers', '22.2', '82', '2286', 1999],
#  ['Roy Rogers', '14.2', '40', '355', 1999],
#  ['Sean Rooks', '17.3', '71', '1001', 1999],
#  ['Jalen Rose', '23.2', '80', '2978', 1999],
#  ['Malik Rose', '19.7', '74', '1341', 1999],
#  ['Michael Ruffin', '11.1', '71', '975', 1999],
#  ['Bryon Russell', '18.4', '82', '2900', 1999],
#  ['Arvydas Sabonis', '21.4', '66', '1688', 1999],
#  ['John Salley', '14.4', '45', '303', 1999],
#  ['Detlef Schrempf', '17.4', '77', '1662', 1999],
#  ['Dennis Scott', '14.0', '66', '1263', 1999],
#  ['Malik Sealy', '18.6', '82', '2392', 1999],
#  ['Brian Shaw', '14.8', '74', '1249', 1999],
#  ['Dickey Simpkins', '12.6', '69', '1651', 1999],
#  ['Brian Skinner', '11.4', '33', '775', 1999],
#  ['Joe Smith', '19.5', '78', '1975', 1999],
#  ['Michael Smith', '10.9', '46', '1145', 1999],
#  ['Steve Smith', '20.0', '82', '2689', 1999],
#  ['Rik Smits', '26.8', '79', '1852', 1999],
#  ['Eric Snow', '12.8', '82', '2866', 1999],
#  ['Felton Spencer', '17.1', '26', '149', 1999],
#  ['Latrell Sprewell', '24.7', '82', '3276', 1999],
#  ['Ryan Stack', '17.5', '25', '198', 1999],
#  ['Jerry Stackhouse', '29.2', '82', '3148', 1999],
#  ['John Starks', '22.6', '37', '1190', 1999],
#  ['Vladimir Stepania', '25.5', '30', '202', 1999],
#  ['Joe Stephens', '14.8', '13', '181', 1999],
#  ['Michael Stewart', '9.6', '42', '389', 1999],
#  ['Bryant Stith', '16.1', '45', '691', 1999],
#  ['John Stockton', '19.3', '82', '2432', 1999],
#  ['Peja Stojaković', '20.8', '74', '1749', 1999],
#  ['Damon Stoudamire', '21.5', '78', '2372', 1999],
#  ['Erick Strickland', '20.0', '68', '2025', 1999],
#  ['Mark Strickland', '19.2', '58', '663', 1999],
#  ['Rod Strickland', '22.0', '69', '2188', 1999],
#  ['Derek Strong', '18.8', '20', '148', 1999],
#  ['Bruno Šundov', '26.0', '14', '61', 1999],
#  ['Bob Sura', '21.1', '73', '2216', 1999],
#  ['Wally Szczerbiak', '17.1', '73', '2171', 1999],
#  ['Žan Tabak', '19.3', '18', '114', 1999],
#  ['Johnny Taylor', '19.9', '6', '34', 1999],
#  ['Maurice Taylor', '24.8', '62', '2227', 1999],
#  ['Jason Terry', '19.2', '81', '1888', 1999],
#  ['Jamel Thomas', '21.8', '7', '46', 1999],
#  ['John Thomas', '12.9', '55', '477', 1999],
#  ['Kenny Thomas', '18.0', '72', '1797', 1999],
#  ['Kurt Thomas', '16.7', '80', '1971', 1999],
#  ['Tim Thomas', '21.0', '80', '2093', 1999],
#  ['Otis Thorpe', '19.4', '51', '777', 1999],
#  ['Robert Traylor', '17.8', '44', '447', 1999],
#  ['Gary Trent', '25.8', '11', '301', 1999],
#  ['Mirsad Türkcan', '24.8', '17', '90', 1999],
#  ['Wayne Turner', '12.3', '3', '41', 1999],
#  ['Nick Van Exel', '22.7', '79', '2950', 1999],
#  ['Keith Van Horn', '26.8', '80', '2782', 1999],
#  ['Jacque Vaughn', '19.5', '78', '884', 1999],
#  ['Loy Vaught', '16.1', '43', '292', 1999],
#  ['Fred Vinson', '24.1', '8', '40', 1999],
#  ['Antoine Walker', '28.3', '82', '3003', 1999],
#  ['Samaki Walker', '20.0', '71', '980', 1999],
#  ['Ben Wallace', '9.7', '81', '1959', 1999],
#  ['John Wallace', '26.1', '60', '798', 1999],
#  ['Rasheed Wallace', '21.9', '81', '2845', 1999],
#  ['Rex Walters', '15.2', '33', '389', 1999],
#  ['Charlie Ward', '13.7', '72', '1986', 1999],
#  ['Clarence Weatherspoon', '17.3', '78', '1615', 1999],
#  ['Chris Webber', '28.2', '75', '2880', 1999],
#  ['Bonzi Wells', '25.2', '66', '1162', 1999],
#  ['Bill Wennington', '15.3', '7', '57', 1999],
#  ['David Wesley', '20.1', '82', '2760', 1999],
#  ['Doug West', '14.2', '38', '581', 1999],
#  ['Mark West', '7.5', '22', '127', 1999],
#  ['Jahidi White', '18.4', '80', '1537', 1999],
#  ['Chris Whitney', '18.7', '82', '1627', 1999],
#  ['Aaron Williams', '17.8', '81', '1545', 1999],
#  ['Alvin Williams', '20.6', '55', '779', 1999],
#  ['Eric Williams', '16.6', '68', '1378', 1999],
#  ['Jason Williams', '20.3', '81', '2760', 1999],
#  ['Jerome Williams', '14.3', '82', '2102', 1999],
#  ['Lorenzo Williams', '7.0', '8', '76', 1999],
#  ['Monty Williams', '20.2', '75', '1501', 1999],
#  ['Scott Williams', '16.4', '68', '1488', 1999],
#  ['Shammond Williams', '24.5', '43', '517', 1999],
#  ['Walt Williams', '20.0', '76', '1859', 1999],
#  ['Corliss Williamson', '20.2', '76', '1707', 1999],
#  ['Kevin Willis', '19.5', '79', '1679', 1999],
#  ['Dedric Willoughby', '21.5', '25', '508', 1999],
#  ['David Wingate', '16.3', '7', '32', 1999],
#  ['Haywoode Workman', '14.5', '36', '350', 1999],
#  ['Metta World Peace', '21.4', '72', '2238', 1999],
#  ['Lorenzen Wright', '17.9', '75', '1205', 1999],
#  ['Tim Young', '19.6', '25', '137', 1999],
#  ['Mahmoud Abdul-Rauf', '26.8', '41', '486', 2000],
#  ['Tariq Abdul-Wahad', '17.1', '29', '420', 2000],
#  ['Shareef Abdur-Rahim', '24.6', '81', '3241', 2000],
#  ['Cory Alexander', '17.3', '26', '227', 2000],
#  ['Courtney Alexander', '23.2', '65', '1382', 2000],
#  ['Ray Allen', '24.4', '82', '3129', 2000],
#  ['Rafer Alston', '17.2', '37', '288', 2000],
#  ['John Amaechi', '21.7', '82', '1710', 2000],
#  ['Derek Anderson', '21.9', '82', '2859', 2000],
#  ['Kenny Anderson', '16.6', '33', '849', 2000],
#  ['Nick Anderson', '16.7', '21', '169', 2000],
#  ['Shandon Anderson', '15.4', '82', '2396', 2000],
#  ['Greg Anthony', '16.9', '58', '856', 2000],
#  ['Darrell Armstrong', '21.0', '75', '2767', 2000],
#  ['Chucky Atkins', '21.2', '81', '2363', 2000],
#  ['Stacey Augmon', '13.9', '66', '1182', 2000],
#  ['Isaac Austin', '18.5', '52', '845', 2000],
#  ['William Avery', '20.0', '55', '463', 2000],
#  ['Dalibor Bagarić', '17.6', '35', '259', 2000],
#  ['Vin Baker', '23.8', '76', '2129', 2000],
#  ['Erick Barkley', '33.0', '8', '38', 2000],
#  ['Dana Barros', '20.4', '60', '1079', 2000],
#  ['Brent Barry', '13.5', '67', '1778', 2000],
#  ['Jon Barry', '14.9', '62', '1010', 2000],
#  ['Tony Battie', '14.4', '40', '845', 2000],
#  ['Raja Bell', '13.6', '5', '30', 2000],
#  ['Jonathan Bender', '21.0', '59', '574', 2000],
#  ['Corey Benjamin', '21.8', '65', '857', 2000],
#  ['David Benoit', '19.8', '49', '446', 2000],
#  ['Travis Best', '19.3', '77', '2457', 2000],
#  ['Mike Bibby', '21.3', '82', '3190', 2000],
#  ['Chauncey Billups', '19.5', '77', '1790', 2000],
#  ['Mookie Blaylock', '17.3', '69', '2352', 2000],
#  ['Corie Blount', '13.2', '68', '1305', 2000],
#  ['Mark Blount', '12.0', '64', '1098', 2000],
#  ['Muggsy Bogues', '7.9', '3', '34', 2000],
#  ['Etdrick Bohannon', '16.1', '6', '19', 2000],
#  ['Calvin Booth', '16.3', '55', '933', 2000],
#  ['Cal Bowdler', '17.0', '44', '375', 2000],
#  ['Bruce Bowen', '13.1', '82', '2685', 2000],
#  ['Ryan Bowen', '12.0', '57', '696', 2000],
#  ['Ira Bowman', '7.1', '3', '19', 2000],
#  ['Earl Boykins', '24.7', '10', '149', 2000],
#  ['Shawn Bradley', '13.9', '82', '2001', 2000],
#  ['Elton Brand', '26.3', '74', '2906', 2000],
#  ['Terrell Brandon', '22.2', '78', '2821', 2000],
#  ['Chucky Brown', '15.5', '26', '339', 2000],
#  ['Dee Brown', '15.2', '7', '155', 2000],
#  ['P.J. Brown', '12.5', '80', '2811', 2000],
#  ['Randy Brown', '11.4', '54', '1238', 2000],
#  ['Rick Brunson', '17.4', '22', '208', 2000],
#  ['Kobe Bryant', '31.8', '68', '2783', 2000],
#  ['Mark Bryant', '12.2', '18', '101', 2000],
#  ['Greg Buckner', '14.1', '37', '820', 2000],
#  ['Jud Buechler', '11.4', '57', '737', 2000],
#  ['Rodney Buford', '22.3', '47', '573', 2000],
#  ['Matt Bullard', '14.9', '61', '1000', 2000],
#  ['Scott Burrell', '18.8', '4', '41', 2000],
#  ['Jason Caffey', '16.6', '70', '1460', 2000],
#  ['Marcus Camby', '17.0', '63', '2127', 2000],
#  ['Elden Campbell', '22.8', '78', '2337', 2000],
#  ['Brian Cardinal', '16.5', '15', '126', 2000],
#  ['Chris Carr', '23.1', '35', '309', 2000],
#  ['Anthony Carter', '19.2', '72', '1630', 2000],
#  ['Vince Carter', '30.7', '75', '2979', 2000],
#  ['Sam Cassell', '24.9', '76', '2709', 2000],
#  ['Kelvin Cato', '11.9', '35', '624', 2000],
#  ['Duane Causwell', '15.0', '31', '384', 2000],
#  ['Cedric Ceballos', '23.5', '40', '559', 2000],
#  ['Calbert Cheaney', '10.5', '9', '153', 2000],
#  ['Chris Childs', '13.3', '77', '1859', 2000],
#  ['Doug Christie', '16.2', '81', '2939', 2000],
#  ['Keon Clark', '18.6', '81', '1720', 2000],
#  ['Mateen Cleaves', '20.5', '78', '1268', 2000],
#  ['John Coker', '13.2', '6', '32', 2000],
#  ['Derrick Coleman', '22.8', '34', '683', 2000],
#  ['Bimbo Coles', '18.1', '47', '804', 2000],
#  ['Jason Collier', '19.2', '23', '222', 2000],
#  ['Sean Colson', '28.8', '13', '44', 2000],
#  ['Tyrone Corbin', '16.3', '15', '117', 2000],
#  ['Chris Crawford', '18.3', '47', '901', 2000],
#  ['Jamal Crawford', '17.9', '61', '1050', 2000],
#  ['Austin Croshere', '23.4', '81', '1874', 2000],
#  ['John Crotty', '16.1', '31', '264', 2000],
#  ['Vonteego Cummings', '18.6', '66', '1495', 2000],
#  ['Bill Curley', '15.8', '20', '192', 2000],
#  ['Dell Curry', '20.7', '71', '956', 2000],
#  ['Michael Curry', '12.0', '68', '1485', 2000],
#  ['Erick Dampier', '18.4', '43', '1038', 2000],
#  ['Antonio Daniels', '17.5', '79', '2060', 2000],
#  ['Kornél Dávid', '14.3', '27', '209', 2000],
#  ['Antonio Davis', '19.5', '78', '2729', 2000],
#  ['Baron Davis', '19.2', '82', '3192', 2000],
#  ['Dale Davis', '13.4', '81', '2162', 2000],
#  ['Emanual Davis', '14.7', '62', '1290', 2000],
#  ['Hubert Davis', '14.5', '66', '1692', 2000],
#  ['Ricky Davis', '26.0', '7', '70', 2000],
#  ['Terry Davis', '7.8', '19', '228', 2000],
#  ['Todd Day', '19.9', '31', '345', 2000],
#  ['Andrew DeClercq', '13.7', '67', '903', 2000],
#  ['Vinny Del Negro', '13.6', '65', '922', 2000],
#  ['Tony Delk', '22.0', '82', '2288', 2000],
#  ['Derrick Dial', '23.7', '33', '207', 2000],
#  ['Michael Dickerson', '22.7', '70', '2618', 2000],
#  ['Vlade Divac', '20.1', '81', '2420', 2000],
#  ['Michael Doleac', '19.4', '77', '1398', 2000],
#  ['Keyon Dooling', '20.0', '76', '1237', 2000],
#  ['Sherman Douglas', '17.9', '59', '1094', 2000],
#  ['Bryce Drew', '14.4', '48', '1305', 2000],
#  ['Chris Dudley', '8.4', '53', '613', 2000],
#  ['Tim Duncan', '28.7', '82', '3174', 2000],
#  ['Tyus Edney', '23.6', '24', '263', 2000],
#  ['Kevin Edwards', '16.6', '46', '634', 2000],
#  ['Howard Eisley', '15.6', '82', '2426', 2000],
#  ['Obinna Ekezie', '18.8', '33', '281', 2000],
#  ['Khalid El-Amin', '19.7', '50', '936', 2000],
#  ['Mario Elie', '10.0', '68', '1506', 2000],
#  ['Sean Elliott', '16.3', '52', '1229', 2000],
#  ['LaPhonso Ellis', '19.6', '82', '1948', 2000],
#  ['Pervis Ellison', '12.3', '9', '40', 2000],
#  ['Evan Eschmeyer', '10.1', '74', '1331', 2000],
#  ...]

# %%
salary()
# Out:
# [['Patrick Ewing', '18500000', 1998],
#  ["Shaquille O'Neal", '15000000', 1998],
#  ['David Robinson', '14841000', 1998],
#  ['Kevin Garnett', '14000000', 1998],
#  ['Alonzo Mourning', '13130000', 1998],
#  ['Juwan Howard', '13125000', 1998],
#  ['Hakeem Olajuwon', '12943000', 1998],
#  ['Derrick Coleman', '12267000', 1998],
#  ['Dikembe Mutombo', '11218000', 1998],
#  ['Jayson Williams', '11000000', 1998],
#  ['Scottie Pippen', '11000000', 1998],
#  ['Larry Johnson', '10186000', 1998],
#  ['Charles Oakley', '10186000', 1998],
#  ['Chris Webber', '10000000', 1998],
#  ['Shawn Kemp', '9740000', 1998],
#  ['Antonio McDyess', '9000000', 1998],
#  ['Arvydas Sabonis', '9000000', 1998],
#  ['Damon Stoudamire', '9000000', 1998],
#  ['Rasheed Wallace', '9000000', 1998],
#  ['Gary Payton', '8715000', 1998],
#  ['Anfernee Hardaway', '8505000', 1998],
#  ['Rik Smits', '8500000', 1998],
#  ['Latrell Sprewell', '8300000', 1998],
#  ['Vlade Divac', '8300000', 1998],
#  ['Horace Grant', '7843000', 1998],
#  ['Tom Gugliotta', '7800000', 1998],
#  ['Bryant Reeves', '7222000', 1998],
#  ['Elden Campbell', '7000000', 1998],
#  ['Allan Houston', '7000000', 1998],
#  ['Danny Manning', '6833000', 1998],
#  ['Matt Geiger', '6800000', 1998],
#  ['Reggie Miller', '6781000', 1998],
#  ['Shawn Bradley', '6750000', 1998],
#  ['Grant Hill', '6675000', 1998],
#  ['Glenn Robinson', '6380000', 1998],
#  ['Steve Smith', '6300000', 1998],
#  ['Terrell Brandon', '6300000', 1998],
#  ['Karl Malone', '6142000', 1998],
#  ['Jason Kidd', '6041000', 1998],
#  ['Michael Finley', '6000000', 1998],
#  ['Theo Ratliff', '6000000', 1998],
#  ['Brian Grant', '6000000', 1998],
#  ['Kenny Anderson', '5845000', 1998],
#  ['Tim Hardaway', '5600000', 1998],
#  ['Mark Price', '5488000', 1998],
#  ['Christian Laettner', '5360000', 1998],
#  ['Tyrone Hill', '5352000', 1998],
#  ['Sean Elliott', '5333000', 1998],
#  ['Ron Harper', '5280000', 1998],
#  ['Glen Rice', '5248000', 1998],
#  ['A.C. Green', '5125088', 1998],
#  ['Charles Smith', '5052223', 1998],
#  ['Jamal Mashburn', '5033000', 1998],
#  ['Kendall Gill', '5000000', 1998],
#  ['Robert Horry', '5000000', 1998],
#  ['Isaac Austin', '5000000', 1998],
#  ['Bison Dele', '4860000', 1998],
#  ['Isaiah Rider', '4810000', 1998],
#  ['Alan Henderson', '4725000', 1998],
#  ['Bryant Stith', '4666000', 1998],
#  ['Toni Kukoc', '4610000', 1998],
#  ['PJ Brown', '4480000', 1998],
#  ['Otis Thorpe', '4400000', 1998],
#  ['Will Perdue', '4373000', 1998],
#  ['Donyell Marshall', '4370000', 1998],
#  ['Greg Ostertag', '4333000', 1998],
#  ['Chris Gatling', '4266000', 1998],
#  ['Vin Baker', '4264000', 1998],
#  ['Rony Seikaly', '4252000', 1998],
#  ['Brian Shaw', '4250000', 1998],
#  ['Lionel Simmons', '4238500', 1998],
#  ['Jim McIlvaine', '4200000', 1998],
#  ['Wesley Person', '4200000', 1998],
#  ['Derrick McKey', '4200000', 1998],
#  ['Anthony Mason', '4165000', 1998],
#  ['Stojko Vrankovic', '4060000', 1998],
#  ['Dale Davis', '4038000', 1998],
#  ['Bobby Hurley', '4030000', 1998],
#  ['Danny Ferry', '4000000', 1998],
#  ['John Starks', '4000000', 1998],
#  ['Luc Longley', '4000000', 1998],
#  ['Sharone Wright', '4000000', 1998],
#  ['John Stockton', '4000000', 1998],
#  ['Calbert Cheaney', '4000000', 1998],
#  ['Jerry Stackhouse', '3887000', 1998],
#  ['Chuck Person', '3860000', 1998],
#  ['Loy Vaught', '3830000', 1998],
#  ['Robert Pack', '3780000', 1998],
#  ['Ken Norman', '3775000', 1998],
#  ['Dee Brown', '3750000', 1998],
#  ['Jason Caffey', '3675000', 1998],
#  ['BJ Armstrong', '3650000', 1998],
#  ['Hersey Hawkins', '3644000', 1998],
#  ['Chris Childs', '3640000', 1998],
#  ['Mookie Blaylock', '3600000', 1998],
#  ['Brent Barry', '3600000', 1998],
#  ['Chris Mills', '3600000', 1998],
#  ['Mark Jackson', '3600000', 1998],
#  ['Allen Iverson', '3537000', 1998],
#  ['Chris Mullin', '3510000', 1998],
#  ['Dana Barros', '3500000', 1998],
#  ['Antonio Davis', '3500000', 1998],
#  ['Lamond Murray', '3500000', 1998],
#  ['Clifford Robinson', '3500000', 1998],
#  ['Bobby Phills', '3480000', 1998],
#  ['Jeff Hornacek', '3455000', 1998],
#  ['Bryon Russell', '3428000', 1998],
#  ['Tim Duncan', '3413000', 1998],
#  ['Detlef Schrempf', '3333000', 1998],
#  ['Scott Williams', '3300000', 1998],
#  ['Dan Majerle', '3290000', 1998],
#  ['Armen Gilliam', '3244000', 1998],
#  ['Nick Anderson', '3200000', 1998],
#  ['Stacey Augmon', '3200000', 1998],
#  ['Marcus Camby', '3164000', 1998],
#  ['Bob Sura', '3133000', 1998],
#  ['Andrew Lang', '3068000', 1998],
#  ['Keith Van Horn', '3054000', 1998],
#  ['Pooh Richardson', '3030000', 1998],
#  ['Rodney Rogers', '3000000', 1998],
#  ['Sam Cassell', '3000000', 1998],
#  ['Derek Strong', '3000000', 1998],
#  ['Walt Williams', '3000000', 1998],
#  ['Avery Johnson', '3000000', 1998],
#  ['Grant Long', '2977000', 1998],
#  ['Micheal Williams', '2975000', 1998],
#  ['Doug West', '2915000', 1998],
#  ['Darrell Armstrong', '2900000', 1998],
#  ['Shareef Abdur-Rahim', '2842000', 1998],
#  ['Voshon Lenard', '2837000', 1998],
#  ['Muggsy Bogues', '2800000', 1998],
#  ['Rex Chapman', '2800000', 1998],
#  ['Eric Williams', '2780000', 1998],
#  ['Travis Best', '2750000', 1998],
#  ['Carl Herrera', '2742500', 1998],
#  ['Chauncey Billups', '2742000', 1998],
#  ['Michael Olowokandi', '2700000', 1998],
#  ['Adam Keefe', '2650000', 1998],
#  ['Ervin Johnson', '2594000', 1998],
#  ['Stephon Marbury', '2562000', 1998],
#  ['Greg Minor', '2520000', 1998],
#  ['Dino Radja', '2500000', 1998],
#  ['Mitch Richmond', '2500000', 1998],
#  ['Khalid Reeves', '2477000', 1998],
#  ['Antonio Daniels', '2472000', 1998],
#  ['Don MacLean', '2460000', 1998],
#  ['Pervis Ellison', '2420000', 1998],
#  ['Tyrone Corbin', '2400000', 1998],
#  ['Travis Knight', '2400000', 1998],
#  ['Mike Bibby', '2400000', 1998],
#  ['Popeye Jones', '2381000', 1998],
#  ['Tracy Murray', '2380000', 1998],
#  ['Doug Christie', '2353000', 1998],
#  ['Michael Cage', '2350000', 1998],
#  ['James Robinson', '2337500', 1998],
#  ['Ray Allen', '2320000', 1998],
#  ['Anthony Peeler', '2254000', 1998],
#  ['Brent Price', '2240000', 1998],
#  ['Tony Battie', '2238000', 1998],
#  ['Eddie Jones', '2200000', 1998],
#  ['Sherman Douglas', '2200000', 1998],
#  ['Michael Smith', '2180000', 1998],
#  ['Corie Blount', '2162500', 1998],
#  ['Rex Walters', '2162500', 1998],
#  ['David Wesley', '2160000', 1998],
#  ['Dean Garrett', '2160000', 1998],
#  ['Raef LaFrentz', '2150000', 1998],
#  ['Jalen Rose', '2145000', 1998],
#  ['Antoine Walker', '2107000', 1998],
#  ['Mark Strickland', '2100000', 1998],
#  ['Kevin Willis', '2100000', 1998],
#  ['Mark Bryant', '2050000', 1998],
#  ['Lindsey Hunter', '2050000', 1998],
#  ['Haywoode Workman', '2040000', 1998],
#  ['Ron Mercer', '2033000', 1998],
#  ['Elliot Perry', '2000000', 1998],
#  ['Bimbo Coles', '2000000', 1998],
#  ['Cherokee Parks', '2000000', 1998],
#  ['Gerald Wilkins', '2000000', 1998],
#  ['Carlos Rogers', '2000000', 1998],
#  ['Antawn Jamison', '1940000', 1998],
#  ['Lorenzen Wright', '1923000', 1998],
#  ['Erick Strickland', '1920000', 1998],
#  ['Nick Van Exel', '1900000', 1998],
#  ['Tim Thomas', '1856000', 1998],
#  ['Sam Perkins', '1785000', 1998],
#  ['Steve Kerr', '1774000', 1998],
#  ['Kerry Kittles', '1762000', 1998],
#  ['Eric Montross', '1760000', 1998],
#  ['Vince Carter', '1760000', 1998],
#  ['LaPhonso Ellis', '1750000', 1998],
#  ['Eric Murdock', '1750000', 1998],
#  ['John Williams', '1750000', 1998],
#  ['Rick Fox', '1750000', 1998],
#  ['Clarence Weatherspoon', '1750000', 1998],
#  ['Vinny Del Negro', '1750000', 1998],
#  ['Joe Smith', '1750000', 1998],
#  ['Kurt Thomas', '1750000', 1998],
#  ['Billy Owens', '1750000', 1998],
#  ['Dale Ellis', '1750000', 1998],
#  ['Jim Jackson', '1750000', 1998],
#  ['Mario Elie', '1750000', 1998],
#  ['Terry Davis', '1750000', 1998],
#  ['Dennis Scott', '1725000', 1998],
#  ['Adonal Foyle', '1701000', 1998],
#  ['Lucious Harris', '1680000', 1998],
#  ['Sean Rooks', '1680000', 1998],
#  ['Buck Williams', '1670000', 1998],
#  ['Yinka Dare', '1657000', 1998],
#  ['Felton Spencer', '1650000', 1998],
#  ['Eric Piatkowski', '1650000', 1998],
#  ['Kevin Gamble', '1645000', 1998],
#  ['Doug Edwards', '1625000', 1998],
#  ['Samaki Walker', '1619880', 1998],
#  ['Robert Traylor', '1590000', 1998],
#  ['Tracy McGrady', '1563000', 1998],
#  ['Bill Curley', '1544000', 1998],
#  ['Lee Mayberry', '1540000', 1998],
#  ['Erick Dampier', '1538000', 1998],
#  ['Danny Fortson', '1485000', 1998],
#  ['Dirk Nowitzki', '1472640', 1998],
#  ['Todd Fuller', '1461000', 1998],
#  ['Jason Williams', '1460000', 1998],
#  ['Duane Causwell', '1454000', 1998],
#  ['Andrew DeClercq', '1440000', 1998],
#  ['Keith Closs', '1440000', 1998],
#  ['Chris Whitney', '1440000', 1998],
#  ['Duane Ferrell', '1430000', 1998],
#  ['Aaron McKie', '1430000', 1998],
#  ['Tariq Abdul-Wahad', '1411000', 1998],
#  ['B.J. Tyler', '1411000', 1998],
#  ['Howard Eisley', '1400000', 1998],
#  ['Austin Croshere', '1340000', 1998],
#  ['Vitaly Potapenko', '1339000', 1998],
#  ['Larry Hughes', '1330000', 1998],
#  ['Randy Brown', '1320000', 1998],
#  ['Tim Legler', '1320000', 1998],
#  ['Kobe Bryant', '1319000', 1998],
#  ['Lorenzo Williams', '1316000', 1998],
#  ['Shandon Anderson', '1300000', 1998],
#  ['Scot Pollard', '1290920', 1998],
#  ['Derek Anderson', '1273000', 1998],
#  ['Charlie Ward', '1221000', 1998],
#  ['Maurice Taylor', '1209000', 1998],
#  ['Steve Nash', '1190760', 1998],
#  ['Paul Pierce', '1165000', 1998],
#  ['Terry Cummings', '1150000', 1998],
#  ['Bo Outlaw', '1150000', 1998],
#  ['Kelvin Cato', '1149000', 1998],
#  ['Terry Mills', '1145000', 1998],
#  ['Tony Delk', '1131000', 1998],
#  ['Terry Dehere', '1112500', 1998],
#  ['John Crotty', '1104000', 1998],
#  ['Bonzi Wells', '1100000', 1998],
#  ['Brevin Knight', '1092000', 1998],
#  ["Jermaine O'Neal", '1075000', 1998],
#  ['Michael Doleac', '1050000', 1998],
#  ['Johnny Taylor', '1037000', 1998],
#  ['John Wallace', '1021000', 1998],
#  ['Anthony Johnson', '1000000', 1998],
#  ['Mark West', '1000000', 1998],
#  ['Chris Carr', '1000000', 1998],
#  ['Scott Burrell', '1000000', 1998],
#  ['Joe Wolf', '1000000', 1998],
#  ['Bill Wennington', '1000000', 1998],
#  ['Johnny Newman', '1000000', 1998],
#  ['Gary Trent', '1000000', 1998],
#  ['Keon Clark', '1000000', 1998],
#  ['Joe Dumars', '1000000', 1998],
#  ['Charles Barkley', '1000000', 1998],
#  ['Dennis Rodman', '1000000', 1998],
#  ['Derek Harper', '1000000', 1998],
#  ['Terry Porter', '1000000', 1998],
#  ['Dell Curry', '1000000', 1998],
#  ['Malik Sealy', '1000000', 1998],
#  ['David Wingate', '1000000', 1998],
#  ['Herb Williams', '1000000', 1998],
#  ['Olden Polynice', '1000000', 1998],
#  ['Danny Schayes', '1000000', 1998],
#  ['Dominique Wilkins', '1000000', 1998],
#  ['George Lynch', '1000000', 1998],
#  ['Harvey Grant', '1000000', 1998],
#  ['Rick Mahorn', '1000000', 1998],
#  ['Joe Kleine', '1000000', 1998],
#  ['Chris Morris', '1000000', 1998],
#  ['Gary Grant', '1000000', 1998],
#  ['Greg Anthony', '1000000', 1998],
#  ['Vernon Maxwell', '1000000', 1998],
#  ['Jerome Kersey', '1000000', 1998],
#  ['Michael Stewart', '1000000', 1998],
#  ['Chris Anstey', '985200', 1998],
#  ['Walter McCarty', '975000', 1998],
#  ["Dontae' Jones", '953856', 1998],
#  ['Michael Dickerson', '949600', 1998],
#  ['Zydrunas Ilgauskas', '936000', 1998],
#  ['Paul Grant', '903240', 1998],
#  ['Tony Massenburg', '900000', 1998],
#  ['Matt Harpring', '900000', 1998],
#  ['Anthony Parker', '867120', 1998],
#  ['Randolph Childress', '866320', 1998],
#  ['Roy Rogers', '862560', 1998],
#  ['Bryce Drew', '857000', 1998],
#  ['Chucky Brown', '850000', 1998],
#  ['Jud Buechler', '850000', 1998],
#  ['Blue Edwards', '850000', 1998],
#  ['Thurl Bailey', '850000', 1998],
#  ['Eric Snow', '846300', 1998],
#  ['Ed Gray', '832440', 1998],
#  ['Don Reid', '800000', 1998],
#  ['Ben Wallace', '800000', 1998],
#  ['Bobby Jackson', '799200', 1998],
#  ['Derek Fisher', '795000', 1998],
#  ['J.R. Reid', '780000', 1998],
#  ['Radoslav Nesterovic', '775750', 1998],
#  ['Martin Muursepp', '763200', 1998],
#  ['Cedric Ceballos', '750000', 1998],
#  ['George McCloud', '750000', 1998],
#  ['Roshown McLeod', '740000', 1998],
#  ['Pat Garrity', '740000', 1998],
#  ['Mirsad Turkcan', '739400', 1998],
#  ['Jerome Williams', '737880', 1998],
#  ['John Thomas', '737000', 1998],
#  ['Keith Askins', '725000', 1998],
#  ['Priest Lauderdale', '712200', 1998],
#  ['Pete Chilcutt', '700000', 1998],
#  ['Jacque Vaughn', '691560', 1998],
#  ['Keith Booth', '687240', 1998],
#  ['Brian Evans', '686780', 1998],
#  ['Ricky Davis', '680000', 1998],
#  ['Dwayne Schintzius', '662500', 1998],
#  ['Marty Conlon', '662500', 1998],
#  ['Brian Skinner', '653500', 1998],
#  ['Hubert Davis', '645000', 1998],
#  ['Rodrick Rhodes', '639300', 1998],
#  ['Ruben Patterson', '628500', 1998],
#  ['Fred Hoiberg', '600000', 1998],
#  ['Felipe Lopez', '600000', 1998],
#  ['Doug Overton', '600000', 1998],
#  ['Jon Barry', '600000', 1998],
#  ['Oliver Miller', '600000', 1998],
#  ['Greg Foster', '588000', 1998],
#  ['Aaron Williams', '575000', 1998],
#  ['Lawrence Funderburke', '575000', 1998],
#  ['Sam Jacobson', '559000', 1998],
#  ['Michael Curry', '550000', 1998],
#  ['Sam Mack', '545000', 1998],
#  ['Al Harrington', '543000', 1998],
#  ['Vladimir Stepania', '543000', 1998],
#  ['Corey Benjamin', '540000', 1998],
#  ['Eric Riley', '537500', 1998],
#  ['Charles Shackleford', '537500', 1998],
#  ['Mitchell Butler', '537500', 1998],
#  ['Negele Knight', '537500', 1998],
#  ['Nazr Mohammed', '535000', 1998],
#  ['Eric Washington', '520000', 1998],
#  ['Bruce Bowen', '507000', 1998],
#  ['Craig Ehlo', '504082', 1998],
#  ['Marcus Brown', '500000', 1998],
#  ['Corliss Williamson', '500000', 1998],
#  ['Gheorghe Muresan', '475000', 1998],
#  ['Jeff Sanders', '475000', 1998],
#  ['Anthony Miller', '475000', 1998],
#  ['David Vaughn', '450000', 1998],
#  ['Loren Meyer', '450000', 1998],
#  ['Jamie Feick', '425000', 1998],
#  ['Mark Hendrickson', '425000', 1998],
#  ['Corey Beck', '425000', 1998],
#  ['Ben Davis', '425000', 1998],
#  ['Horacio Llamas Grey', '425000', 1998],
#  ['Malik Rose', '425000', 1998],
#  ['Reggie Slater', '400000', 1998],
#  ['Mark Pope', '382000', 1998],
#  ['Chris Robinson', '375000', 1998],
#  ['Chris Crawford', '350000', 1998],
#  ['William Cunningham', '350000', 1998],
#  ['Rusty Larue', '350000', 1998],
#  ['DeJuan Wheat', '350000', 1998],
#  ['Adonis Jordan', '350000', 1998],
#  ['Rick Brunson', '350000', 1998],
#  ['Moochie Norris', '350000', 1998],
#  ['Drew Barry', '350000', 1998],
#  ['Marko Milic', '350000', 1998],
#  ['Michael Hawkins', '350000', 1998],
#  ['Andrew Gaze', '350000', 1998],
#  ['Jeff McInnis', '350000', 1998],
#  ['John Coker', '350000', 1998],
#  ["Charles O'Bannon", '320000', 1998],
#  ['Bubba Wells', '312000', 1998],
#  ['Jerald Honeycutt', '300000', 1998],
#  ['Jeffrey Sheppard', '287500', 1998],
#  ['Damon Jones', '287500', 1998],
#  ['Marlon Garnett', '287500', 1998],
#  ['Brad Miller', '287500', 1998],
#  ['Kornel David', '287500', 1998],
#  ['Charles Jones', '287500', 1998],
#  ['Cory Carr', '287500', 1998],
#  ['Earl Boykins', '287500', 1998],
#  ['Ryan Stack', '287500', 1998],
#  ['Ansu Sesay', '287500', 1998],
#  ['Bruno Sundov', '287500', 1998],
#  ['Kelly McCarty', '287500', 1998],
#  ['Korleone Young', '287500', 1998],
#  ['Cuttino Mobley', '287500', 1998],
#  ['Mate Skelin', '287500', 1998],
#  ['Troy Hudson', '287500', 1998],
#  ['Tyrone Nesby', '287500', 1998],
#  ['Tyronn Lue', '287500', 1998],
#  ['J.R. Henderson', '287500', 1998],
#  ["Makhtar N'Diaye", '287500', 1998],
#  ['Andrae Patterson', '287500', 1998],
#  ['Trevor Winter', '287500', 1998],
#  ['Jelani McCoy', '287500', 1998],
#  ['Rashard Lewis', '287500', 1998],
#  ['Jonathan Kerner', '287500', 1998],
#  ['Miles Simon', '287500', 1998],
#  ['Casey Shaw', '287500', 1998],
#  ['Randy Livingston', '287500', 1998],
#  ['Gerald Brown', '287500', 1998],
#  ['Toby Bailey', '287500', 1998],
#  ['Nikita Morgunov', '287500', 1998],
#  ['Jerome James', '287500', 1998],
#  ['Gerard King', '287500', 1998],
#  ['Brandon Williams', '287500', 1998],
#  ['Sean Marks', '287500', 1998],
#  ['Paul Rogers', '287500', 1998],
#  ['Randell Jackson', '287500', 1998],
#  ["Shaquille O'Neal", '17142858', 1999],
#  ['Kevin Garnett', '16806300', 1999],
#  ['Alonzo Mourning', '15004800', 1999],
#  ['Patrick Ewing', '15000000', 1999],
#  ['Juwan Howard', '15000000', 1999],
#  ['Scottie Pippen', '14795642', 1999],
#  ['Hakeem Olajuwon', '14302001', 1999],
#  ['Karl Malone', '14000000', 1999],
#  ['Dikembe Mutombo', '12820249', 1999],
#  ['Jayson Williams', '12375000', 1999],
#  ['Rik Smits', '12250000', 1999],
#  ['Larry Johnson', '11910714', 1999],
#  ['David Robinson', '11592683', 1999],
#  ['Gary Payton', '11020473', 1999],
#  ['Chris Webber', '11000000', 1999],
#  ['John Stockton', '11000000', 1999],
#  ['Rasheed Wallace', '10800000', 1999],
#  ['Shawn Kemp', '10780000', 1999],
#  ['Damon Stoudamire', '10125000', 1999],
#  ['Mitch Richmond', '10000000', 1999],
#  ['Rod Strickland', '10000000', 1999],
#  ['Antonio McDyess', '9900000', 1999],
#  ['Arvydas Sabonis', '9818481', 1999],
#  ['Reggie Miller', '9031850', 1999],
#  ['Antoine Walker', '9000000', 1999],
#  ['Stephon Marbury', '9000000', 1999],
#  ['Zydrunas Ilgauskas', '9000000', 1999],
#  ['Charles Barkley', '9000000', 1999],
#  ['Kobe Bryant', '9000000', 1999],
#  ['Shareef Abdur-Rahim', '9000000', 1999],
#  ['Ray Allen', '9000000', 1999],
#  ['Latrell Sprewell', '9000000', 1999],
#  ['Vin Baker', '9000000', 1999],
#  ['Allen Iverson', '9000000', 1999],
#  ['Anfernee Hardaway', '9000000', 1999],
#  ['Vlade Divac', '8837774', 1999],
#  ['Bryant Reeves', '8666666', 1999],
#  ['Tom Gugliotta', '8558535', 1999],
#  ['Nick Van Exel', '8354614', 1999],
#  ['Allan Houston', '8000000', 1999],
#  ['Elden Campbell', '7975000', 1999],
#  ['Brian Grant', '7680862', 1999],
#  ['Shawn Bradley', '7560000', 1999],
#  ['Terrell Brandon', '7400000', 1999],
#  ['Derrick Coleman', '7370000', 1999],
#  ['Glenn Robinson', '7250000', 1999],
#  ['Michael Finley', '7200000', 1999],
#  ['Steve Smith', '7200000', 1999],
#  ['Kerry Kittles', '7166666', 1999],
#  ['Chris Dudley', '7100000', 1999],
#  ['Theo Ratliff', '7031250', 1999],
#  ['Glen Rice', '7000000', 1999],
#  ['Grant Hill', '6939000', 1999],
#  ['Matt Geiger', '6889520', 1999],
#  ['Jason Kidd', '6858335', 1999],
#  ['Danny Manning', '6833333', 1999],
#  ['Kenny Anderson', '6680000', 1999],
#  ['Tyrone Hill', '6422400', 1999],
#  ['Clifford Robinson', '6125000', 1999],
#  ['Christian Laettner', '6062500', 1999],
#  ['Horace Grant', '5952381', 1999],
#  ['Bison Dele', '5770000', 1999],
#  ['Kendall Gill', '5600000', 1999],
#  ['Jamal Mashburn', '5600000', 1999],
#  ['Steve Nash', '5500000', 1999],
#  ['Sean Elliott', '5433333', 1999],
#  ['Isaiah Rider', '5410000', 1999],
#  ['Alan Henderson', '5318437', 1999],
#  ['Will Perdue', '5300000', 1999],
#  ['Bryant Stith', '5290000', 1999],
#  ['Donyell Marshall', '5250000', 1999],
#  ['Marcus Camby', '5250000', 1999],
#  ['Charles Oakley', '5236000', 1999],
#  ['Greg Ostertag', '5200000', 1999],
#  ['Jeff Hornacek', '5200000', 1999],
#  ['Luc Longley', '5175000', 1999],
#  ['PJ Brown', '5124800', 1999],
#  ["Jermaine O'Neal", '5075000', 1999],
#  ['Nick Anderson', '5051906', 1999],
#  ['Erick Dampier', '4988000', 1999],
#  ['Wesley Person', '4900000', 1999],
#  ['Chris Gatling', '4875200', 1999],
#  ['Anthony Mason', '4860100', 1999],
#  ['Isaac Austin', '4819451', 1999],
#  ['Jim McIlvaine', '4800000', 1999],
#  ['Derrick McKey', '4800000', 1999],
#  ['Robert Horry', '4800000', 1999],
#  ['Tim Hardaway', '4800000', 1999],
#  ['Jerry Stackhouse', '4781250', 1999],
#  ['Charlie Ward', '4540000', 1999],
#  ['Toni Kukoc', '4500000', 1999],
#  ['Dale Davis', '4490000', 1999],
#  ['Lorenzen Wright', '4400000', 1999],
#  ['Chris Mills', '4200000', 1999],
#  ['Mookie Blaylock', '4200000', 1999],
#  ['Antonio Davis', '4200000', 1999],
#  ['Loy Vaught', '4180000', 1999],
#  ['Hersey Hawkins', '4164100', 1999],
#  ['Chris Childs', '4160000', 1999],
#  ['Darrell Armstrong', '4125000', 1999],
#  ['Chris Mullin', '4079100', 1999],
#  ['Bobby Phills', '4060000', 1999],
#  ['Robert Pack', '4050000', 1999],
#  ['Armen Gilliam', '4019200', 1999],
#  ['John Starks', '4000000', 1999],
#  ['Danny Ferry', '4000000', 1999],
#  ['Mark Jackson', '4000000', 1999],
#  ['Dee Brown', '4000000', 1999],
#  ['Bryon Russell', '4000000', 1999],
#  ['Stacey Augmon', '3960000', 1999],
#  ['Brent Barry', '3960000', 1999],
#  ['Jason Caffey', '3937500', 1999],
#  ['Tim Duncan', '3858240', 1999],
#  ['Vitaly Potapenko', '3810000', 1999],
#  ['Bob Sura', '3760000', 1999],
#  ['Walt Williams', '3750000', 1999],
#  ['Scott Williams', '3750000', 1999],
#  ['Michael Smith', '3660000', 1999],
#  ['Dan Majerle', '3600000', 1999],
#  ['Corliss Williamson', '3560000', 1999],
#  ['Dana Barros', '3500000', 1999],
#  ['Cedric Ceballos', '3500000', 1999],
#  ['Sam Cassell', '3500000', 1999],
#  ['Michael Olowokandi', '3456240', 1999],
#  ['Keith Van Horn', '3451920', 1999],
#  ['Elton Brand', '3375960', 1999],
#  ['Eric Williams', '3336000', 1999],
#  ['Voshon Lenard', '3308516', 1999],
#  ['Doug West', '3295000', 1999],
#  ['Travis Best', '3250000', 1999],
#  ['Avery Johnson', '3200000', 1999],
#  ['Michael Stewart', '3200000', 1999],
#  ['Derek Strong', '3159000', 1999],
#  ['Rex Chapman', '3150000', 1999],
#  ['Chauncey Billups', '3100080', 1999],
#  ['Mike Bibby', '3092400', 1999],
#  ['Rick Fox', '3033000', 1999],
#  ['Steve Francis', '3020520', 1999],
#  ['Lamond Murray', '3000000', 1999],
#  ['Derek Fisher', '3000000', 1999],
#  ['Gerald Wilkins', '3000000', 1999],
#  ['Eric Snow', '3000000', 1999],
#  ['Adam Keefe', '3000000', 1999],
#  ['Ervin Johnson', '2951029', 1999],
#  ['Brent Price', '2944000', 1999],
#  ['Greg Minor', '2880000', 1999],
#  ['Don MacLean', '2800000', 1999],
#  ['Travis Knight', '2800000', 1999],
#  ['Antonio Daniels', '2794920', 1999],
#  ['Raef LaFrentz', '2777160', 1999],
#  ['Pervis Ellison', '2750000', 1999],
#  ['Doug Christie', '2742600', 1999],
#  ['Tracy Murray', '2720000', 1999],
#  ['Tyrone Nesby', '2716667', 1999],
#  ['Samaki Walker', '2716667', 1999],
#  ['Baron Davis', '2712480', 1999],
#  ['Matt Maloney', '2681250', 1999],
#  ['Kevin Willis', '2625000', 1999],
#  ['Terry Cummings', '2600000', 1999],
#  ['Jerome Williams', '2550000', 1999],
#  ['Tony Battie', '2530920', 1999],
#  ['David Wesley', '2520000', 1999],
#  ['Dean Garrett', '2520000', 1999],
#  ['Antawn Jamison', '2503800', 1999],
#  ['Walter McCarty', '2500000', 1999],
#  ['Eddie Jones', '2500000', 1999],
#  ['Anthony Peeler', '2495500', 1999],
#  ['Jaren Jackson', '2483333', 1999],
#  ['Lamar Odom', '2445480', 1999],
#  ['Jalen Rose', '2437500', 1999],
#  ['Cedric Henderson', '2400000', 1999],
#  ['Lawrence Funderburke', '2400000', 1999],
#  ['James Robinson', '2376667', 1999],
#  ['Lindsey Hunter', '2350000', 1999],
#  ['Mark Strickland', '2302400', 1999],
#  ['Bimbo Coles', '2300000', 1999],
#  ['Ron Mercer', '2298840', 1999],
#  ['Malik Rose', '2285000', 1999],
#  ['Dino Radja', '2270500', 1999],
#  ['Vince Carter', '2267280', 1999],
#  ['Erick Strickland', '2240000', 1999],
#  ['Jonathan Bender', '2214600', 1999],
#  ['Carlos Rogers', '2100000', 1999],
#  ['Joe Smith', '2100000', 1999],
#  ['Dell Curry', '2100000', 1999],
#  ['Tim Thomas', '2098560', 1999],
#  ['Dale Ellis', '2095250', 1999],
#  ['Billy Owens', '2090000', 1999],
#  ['Scot Pollard', '2063680', 1999],
#  ['Robert Traylor', '2059320', 1999],
#  ['Othella Harrington', '2025000', 1999],
#  ['Wally Szczerbiak', '2011440', 1999],
#  ['Chris Crawford', '2000000', 1999],
#  ['Calbert Cheaney', '2000000', 1999],
#  ['Elliot Perry', '2000000', 1999],
#  ['Jamie Feick', '2000000', 1999],
#  ['Mark Bryant', '2000000', 1999],
#  ['Gary Trent', '2000000', 1999],
#  ['George McCloud', '2000000', 1999],
#  ['Eric Montross', '2000000', 1999],
#  ['Michael Curry', '2000000', 1999],
#  ['Shandon Anderson', '2000000', 1999],
#  ['Eric Piatkowski', '2000000', 1999],
#  ['Ron Harper', '2000000', 1999],
#  ['Grant Long', '2000000', 1999],
#  ['Otis Thorpe', '2000000', 1999],
#  ['J.R. Reid', '2000000', 1999],
#  ['Sam Mitchell', '2000000', 1999],
#  ['John Wallace', '2000000', 1999],
#  ['Bo Outlaw', '2000000', 1999],
#  ['George Lynch', '2000000', 1999],
#  ['Rodney Rogers', '2000000', 1999],
#  ['Detlef Schrempf', '2000000', 1999],
#  ['Terry Porter', '2000000', 1999],
#  ['Olden Polynice', '2000000', 1999],
#  ['Cory Alexander', '1980000', 1999],
#  ['Steve Kerr', '1968750', 1999],
#  ['Jim Jackson', '1925000', 1999],
#  ['LaPhonso Ellis', '1925000', 1999],
#  ['Hot Rod Williams', '1925000', 1999],
#  ['Sam Perkins', '1925000', 1999],
#  ['Eric Murdock', '1925000', 1999],
#  ['Cherokee Parks', '1925000', 1999],
#  ['Clarence Weatherspoon', '1925000', 1999],
#  ['Vinny Del Negro', '1925000', 1999],
#  ['Kurt Thomas', '1925000', 1999],
#  ['Terry Davis', '1925000', 1999],
#  ['Mario Elie', '1925000', 1999],
#  ['Alvin Williams', '1925000', 1999],
#  ['Adonal Foyle', '1922520', 1999],
#  ['Lucious Harris', '1920000', 1999],
#  ['Sean Rooks', '1920000', 1999],
#  ['Yinka Dare', '1893500', 1999],
#  ['Jason Williams', '1879920', 1999],
#  ['Kevin Gamble', '1868750', 1999],
#  ['Richard Hamilton', '1836240', 1999],
#  ['Tom Hammonds', '1800000', 1999],
#  ['Tracy McGrady', '1767120', 1999],
#  ['Keith Askins', '1752400', 1999],
#  ['Larry Hughes', '1722240', 1999],
#  ['A.C. Green', '1700000', 1999],
#  ['Duane Causwell', '1696387', 1999],
#  ['Andre Miller', '1682280', 1999],
#  ['Andrew DeClercq', '1680000', 1999],
#  ['Keith Closs', '1680000', 1999],
#  ['Chris Whitney', '1680000', 1999],
#  ['Danny Fortson', '1678800', 1999],
#  ['Tim Legler', '1629000', 1999],
#  ['Duane Ferrell', '1625000', 1999],
#  ['Aaron McKie', '1624000', 1999],
#  ['B.J. Tyler', '1614000', 1999],
#  ['Brian Shaw', '1610000', 1999],
#  ['Greg Foster', '1603861', 1999],
#  ['Tariq Abdul-Wahad', '1594920', 1999],
#  ['Dirk Nowitzki', '1583040', 1999],
#  ['Howard Eisley', '1560000', 1999],
#  ['Shawn Marion', '1546320', 1999],
#  ['Lorenzo Williams', '1540000', 1999],
#  ['Austin Croshere', '1515120', 1999],
#  ['Paul Pierce', '1503960', 1999],
#  ['Dickey Simpkins', '1500000', 1999],
#  ['Jason Terry', '1468920', 1999],
#  ['Derek Anderson', '1439400', 1999],
#  ['Vernon Maxwell', '1430000', 1999],
#  ['Bonzi Wells', '1428720', 1999],
#  ['Trajan Langdon', '1394280', 1999],
#  ['Maurice Taylor', '1367400', 1999],
#  ['Michael Doleac', '1357320', 1999],
#  ['Matt Bullard', '1333333', 1999],
#  ['Aleksandar Radojevic', '1325760', 1999],
#  ['Predrag Stojakovic', '1310400', 1999],
#  ['Kelvin Cato', '1299000', 1999],
#  ['Keon Clark', '1289400', 1999],
#  ['Corey Maggette', '1259400', 1999],
#  ['John Crotty', '1237000', 1999],
#  ['Brevin Knight', '1234080', 1999],
#  ['Michael Dickerson', '1224960', 1999],
#  ['Randy Brown', '1200000', 1999],
#  ['Harvey Grant', '1200000', 1999],
#  ['Gary Grant', '1200000', 1999],
#  ['William Avery', '1196520', 1999],
#  ['Johnny Taylor', '1172400', 1999],
#  ['Matt Harpring', '1163760', 1999],
#  ['Tony Massenburg', '1150000', 1999],
#  ['Chris Anstey', '1113720', 1999],
#  ['Bryce Drew', '1105560', 1999],
#  ['Johnny Newman', '1100000', 1999],
#  ['Eldridge Recasner', '1100000', 1999],
#  ['Jud Buechler', '1100000', 1999],
#  ['Derek Harper', '1100000', 1999],
#  ['Zan Tabak', '1100000', 1999],
#  ['Dennis Scott', '1100000', 1999],
#  ['Rex Walters', '1100000', 1999],
#  ['Malik Sealy', '1100000', 1999],
#  ['Anthony Johnson', '1100000', 1999],
#  ['Corie Blount', '1100000', 1999],
#  ['Greg Anthony', '1100000', 1999],
#  ['Aaron Williams', '1100000', 1999],
#  ['Metta World Peace', '1079760', 1999],
#  ['Radoslav Nesterovic', '1050240', 1999],
#  ['Cal Bowdler', '1025880', 1999],
#  ['Paul Grant', '1021080', 1999],
#  ['Sherman Douglas', '1000000', 1999],
#  ['Scott Burrell', '1000000', 1999],
#  ['Don Reid', '1000000', 1999],
#  ['Eddie Johnson', '1000000', 1999],
#  ['Antoine Carr', '1000000', 1999],
#  ['Jelani McCoy', '1000000', 1999],
#  ['Jerome Kersey', '1000000', 1999],
#  ['Anthony Parker', '980280', 1999],
#  ['James Posey', '974520', 1999],
#  ['Pat Garrity', '952800', 1999],
#  ['Frederic Weis', '947200', 1999],
#  ['Ed Gray', '941040', 1999],
#  ['Quincy Lewis', '930720', 1999],
#  ['Roshown McLeod', '914760', 1999],
#  ['Bobby Jackson', '903360', 1999],
#  ['Ruben Patterson', '900000', 1999],
#  ['Ben Wallace', '893750', 1999],
#  ['Dion Glover', '893400', 1999],
#  ['Ricky Davis', '878160', 1999],
#  ['Jeff Foster', '857760', 1999],
#  ['Brian Skinner', '843000', 1999],
#  ['John Thomas', '832560', 1999],
#  ['Mirsad Turkcan', '830745', 1999],
#  ['Kenny Thomas', '823440', 1999],
#  ['Tyronn Lue', '809280', 1999],
#  ['Fred Hoiberg', '800000', 1999],
#  ['Jon Barry', '800000', 1999],
#  ['Devean George', '790440', 1999],
#  ['Jacque Vaughn', '781800', 1999],
#  ['Charles Smith', '779960', 1999],
#  ['Keith Booth', '776880', 1999],
#  ['Hubert Davis', '752500', 1999],
#  ['Al Harrington', '745800', 1999],
#  ['Sam Jacobson', '743727', 1999],
#  ['Tim James', '728520', 1999],
#  ['Rodrick Rhodes', '722000', 1999],
#  ['Vonteego Cummings', '704400', 1999],
#  ['Vladimir Stepania', '700320', 1999],
#  ['Corey Benjamin', '696000', 1999],
#  ['Nazr Mohammed', '690960', 1999],
#  ['Jumaine Jones', '684000', 1999],
#  ['Scott Padgett', '679800', 1999],
#  ['Efthimios Rentzias', '658700', 1999],
#  ['Andrei Kirilenko', '632400', 1999],
#  ['Eddie Robinson', '600000', 1999],
#  ['Doug Overton', '592000', 1999],
#  ['Darrick Martin', '572500', 1999],
#  ['Eric Washington', '550000', 1999],
#  ['Dwayne Schintzius', '550000', 1999],
#  ['Ansu Sesay', '535000', 1999],
#  ['Toby Bailey', '535000', 1999],
#  ['Gheorghe Muresan', '510000', 1999],
#  ['Jack Haley', '510000', 1999],
#  ['Michael Cage', '510000', 1999],
#  ['Chucky Brown', '510000', 1999],
#  ['Bruce Bowen', '510000', 1999],
#  ['BJ Armstrong', '510000', 1999],
#  ['Terry Mills', '510000', 1999],
#  ['Joe Dumars', '510000', 1999],
#  ['Tony Farmer', '510000', 1999],
#  ['Thomas Hamilton', '510000', 1999],
#  ['LaSalle Thompson', '510000', 1999],
#  ['Anthony Avent', '510000', 1999],
#  ['John Salley', '510000', 1999],
#  ['Byron Scott', '510000', 1999],
#  ['Blue Edwards', '510000', 1999],
#  ['Ed Pinckney', '510000', 1999],
#  ['Willie Anderson', '510000', 1999],
#  ['Haywoode Workman', '510000', 1999],
#  ['Jerome Allen', '510000', 1999],
#  ['Ricky Pierce', '510000', 1999],
#  ['David Wingate', '510000', 1999],
#  ['Andrew Lang', '510000', 1999],
#  ['Emanual Davis', '510000', 1999],
#  ['Chuck Person', '510000', 1999],
#  ['Monty Williams', '510000', 1999],
#  ['Rick Mahorn', '510000', 1999],
#  ['Oliver Miller', '510000', 1999],
#  ['Todd Day', '510000', 1999],
#  ['Mark West', '510000', 1999],
#  ['Antonio Harvey', '510000', 1999],
#  ['Joe Kleine', '510000', 1999],
#  ['Bill Wennington', '510000', 1999],
#  ['Tyrone Corbin', '510000', 1999],
#  ['Felton Spencer', '510000', 1999],
#  ['Muggsy Bogues', '510000', 1999],
#  ['Pete Chilcutt', '510000', 1999],
#  ['Thurl Bailey', '510000', 1999],
#  ['John Coker', '510000', 1999],
#  ['Reggie Jordan', '510000', 1999],
#  ['Pooh Richardson', '505882', 1999],
#  ['Shammond Williams', '500000', 1999],
#  ['Todd Fuller', '485000', 1999],
#  ['Roy Rogers', '485000', 1999],
#  ['Amal McCaskill', '485000', 1999],
#  ['Rick Brunson', '485000', 1999],
#  ['Fred Vinson', '485000', 1999],
#  ['Randy Livingston', '485000', 1999],
#  ['Tony Delk', '485000', 1999],
#  ['Michael Hawkins', '465029', 1999],
#  ['James Cotton', '460000', 1999],
#  ['Mikki Moore', '460000', 1999],
#  ['Mark Pope', '460000', 1999],
#  ['Troy Hudson', '460000', 1999],
#  ['DeJuan Wheat', '460000', 1999],
#  ['Darvin Ham', '460000', 1999],
#  ['Jeff McInnis', '460000', 1999],
#  ['Jerald Honeycutt', '460000', 1999],
#  ['Andrew Gaze', '460000', 1999],
#  ['Gerard King', '460000', 1999],
#  ['Leon Smith', '449920', 1999],
#  ['Kevin Ollie', '425088', 1999],
#  ['Michael Ruffin', '401875', 1999],
#  ['Jeffrey Sheppard', '385000', 1999],
#  ['Adrian Griffin', '385000', 1999],
#  ['Brad Miller', '385000', 1999],
#  ['Ryan Stack', '385000', 1999],
#  ['Bruno Sundov', '385000', 1999],
#  ['Cuttino Mobley', '385000', 1999],
#  ['Brent Scott', '385000', 1999],
#  ['Mate Skelin', '385000', 1999],
#  ['Charles Jones', '385000', 1999],
#  ['Shea Seals', '385000', 1999],
#  ['Anthony Carter', '385000', 1999],
#  ['Andrae Patterson', '385000', 1999],
#  ['Rashard Lewis', '385000', 1999],
#  ['Chucky Atkins', '385000', 1999],
#  ['John Amaechi', '385000', 1999],
#  ["Makhtar N'Diaye", '385000', 1999],
#  ['Miles Simon', '385000', 1999],
#  ['Gerald Brown', '385000', 1999],
#  ['Nikita Morgunov', '385000', 1999],
#  ['Sean Marks', '385000', 1999],
#  ['Jahidi White', '385000', 1999],
#  ['Marty Conlon', '343588', 1999],
#  ['Sam Mack', '315000', 1999],
#  ['Jermaine Jackson', '302875', 1999],
#  ['Evan Eschmeyer', '301875', 1999],
#  ['Ryan Bowen', '301875', 1999],
#  ['Chris Herren', '301875', 1999],
#  ['Tim Young', '301875', 1999],
#  ['Shannon Smith', '301875', 1999],
#  ['John Celestand', '301875', 1999],
#  ['Milt Palacio', '301875', 1999],
#  ['Obinna Ekezie', '301875', 1999],
#  ['Harold Jamison', '301875', 1999],
#  ['Rodney Buford', '301875', 1999],
#  ['Rafer Alston', '301875', 1999],
#  ['Lazaro Borrell', '301875', 1999],
#  ['Todd MacCulloch', '301875', 1999],
#  ['Ryan Robertson', '301875', 1999],
#  ['Derrick Dial', '301875', 1999],
#  ['Calvin Booth', '301875', 1999],
#  ['Laron Profit', '301875', 1999],
#  ['Jamie Watson', '250000', 1999],
#  ['Dominique Wilkins', '250000', 1999],
#  ['Danny Schayes', '211765', 1999],
#  ['Kornel David', '202941', 1999],
#  ['Damon Jones', '176647', 1999],
#  ['Mitchell Butler', '150000', 1999],
#  ['Dedric Willoughby', '134956', 1999],
#  ['Benoit Benjamin', '123529', 1999],
#  ['A.J. Bramlett', '118974', 1999],
#  ['Bill Curley', '117867', 1999],
#  ['Randell Jackson', '115500', 1999],
#  ['Rick Hughes', '115423', 1999],
#  ['DeMarco Johnson', '111871', 1999],
#  ['Mark Davis', '106000', 1999],
#  ['Stanley Roberts', '102824', 1999],
#  ['Corey Brewer', '100000', 1999],
#  ['Jermaine Walker', '100000', 1999],
#  ['Lou Roe', '97412', 1999],
#  ['Lari Ketner', '92338', 1999],
#  ['Chris Carr', '90000', 1999],
#  ['Joe Stephens', '88441', 1999],
#  ['Earl Boykins', '88324', 1999],
#  ['Devin Gray', '88223', 1999],
#  ['Drew Barry', '62765', 1999],
#  ['Mark Hendrickson', '62764', 1999],
#  ['Kiwane Garris', '61147', 1999],
#  ['Jamel Thomas', '58599', 1999],
#  ['Eric Riley', '50206', 1999],
#  ['Adrian Caldwell', '50000', 1999],
#  ['Terry Dehere', '50000', 1999],
#  ['Derek Hood', '49721', 1999],
#  ['Greg Buckner', '47647', 1999],
#  ['Ben Davis', '45847', 1999],
#  ['Marcus Brown', '43294', 1999],
#  ['Rusty Larue', '40588', 1999],
#  ['Tyrone Grant', '37290', 1999],
#  ['Brandon Williams', '35176', 1999],
#  ['Bakari Hendrix', '31706', 1999],
#  ['Khalid Reeves', '30309', 1999],
#  ['Wayne Turner', '30000', 1999],
#  ['Anthony Miller', '30000', 1999],
#  ['Casey Shaw', '25000', 1999],
#  ['LaMarcus Golden', '25000', 1999],
#  ['Mike Brown', '25000', 1999],
#  ['Art Long', '25000', 1999],
#  ['Jason Lawson', '25000', 1999],
#  ['Maceo Baston', '20000', 1999],
#  ['Brett Robisch', '20000', 1999],
#  ['Kebu Stewart', '18941', 1999],
#  ['Jason Miskiri', '15982', 1999],
#  ['Louis Bullock', '10000', 1999],
#  ['Robert Werdann', '7471', 1999],
#  ['Jimmy Oliver', '7471', 1999],
#  ['John Morton', '6735', 1999],
#  ['Andy Panko', '5000', 1999],
#  ['Jonathan Kerner', '5000', 1999],
#  ['Ira Bowman', '4529', 1999],
#  ['Trevor Winter', '4529', 1999],
#  ['Steve Goodrich', '4529', 1999],
#  ['Jason Sasser', '2706', 1999],
#  ['Kevin Garnett', '19610000', 2000],
#  ["Shaquille O'Neal", '19285715', 2000],
#  ['Alonzo Mourning', '16880000', 2000],
#  ['Juwan Howard', '16875000', 2000],
#  ['Hakeem Olajuwon', '16700000', 2000],
#  ['Karl Malone', '15750000', 2000],
#  ['David Robinson', '14700000', 2000],
#  ['Dikembe Mutombo', '14400000', 2000],
#  ['Patrick Ewing', '14000000', 2000],
#  ['Jayson Williams', '13800000', 2000],
#  ['Scottie Pippen', '13750000', 2000],
#  ['Rasheed Wallace', '12600000', 2000],
#  ['Gary Payton', '12200000', 2000],
#  ['Tim Hardaway', '12000000', 2000],
#  ['Chris Webber', '12000000', 2000],
#  ['Shawn Kemp', '11720000', 2000],
#  ['Damon Stoudamire', '11250000', 2000],
#  ['Arvydas Sabonis', '11250000', 2000],
#  ['Larry Johnson', '11000000', 2000],
#  ['John Stockton', '11000000', 2000],
#  ['Antonio McDyess', '10800000', 2000],
#  ['Reggie Miller', '10670000', 2000],
#  ['Antoine Walker', '10130000', 2000],
#  ['Stephon Marbury', '10130000', 2000],
#  ['Zydrunas Ilgauskas', '10130000', 2000],
#  ['Kobe Bryant', '10130000', 2000],
#  ['Shareef Abdur-Rahim', '10130000', 2000],
#  ['Ray Allen', '10130000', 2000],
#  ['Vin Baker', '10130000', 2000],
#  ['Allen Iverson', '10130000', 2000],
#  ['Anfernee Hardaway', '10130000', 2000],
#  ['Latrell Sprewell', '10125000', 2000],
#  ['Bryant Reeves', '10110000', 2000],
#  ['Mitch Richmond', '10000000', 2000],
#  ['Rod Strickland', '10000000', 2000],
#  ['Jalen Rose', '9660000', 2000],
#  ['Grant Hill', '9660000', 2000],
#  ['Tracy McGrady', '9660000', 2000],
#  ['Tim Duncan', '9660000', 2000],
#  ['Vlade Divac', '9640000', 2000],
#  ['Tom Gugliotta', '9360000', 2000],
#  ['Nick Van Exel', '9200000', 2000],
#  ['Keith Van Horn', '9000000', 2000],
#  ['Allan Houston', '9000000', 2000],
#  ['Eddie Jones', '8960000', 2000],
#  ['Brian Grant', '8900000', 2000],
#  ['Tim Thomas', '8510000', 2000],
#  ['Michael Finley', '8400000', 2000],
#  ['Shawn Bradley', '8370000', 2000],
#  ['Terrell Brandon', '8330000', 2000],
#  ['Glenn Robinson', '8120000', 2000],
#  ['Steve Smith', '8100000', 2000],
#  ['Elden Campbell', '8050000', 2000],
#  ['Danny Manning', '8030000', 2000],
#  ['Derrick Coleman', '8000000', 2000],
#  ['Avery Johnson', '8000000', 2000],
#  ['Theo Ratliff', '7800000', 2000],
#  ['Kerry Kittles', '7770000', 2000],
#  ...]

# %%
draft()
# Out:
# [['1', 'Michael Olowokandi', 1998],
#  ['2', 'Mike Bibby', 1998],
#  ['3', 'Raef LaFrentz', 1998],
#  ['4', 'Antawn Jamison', 1998],
#  ['5', 'Vince Carter', 1998],
#  ['6', 'Robert Traylor', 1998],
#  ['7', 'Jason Williams', 1998],
#  ['8', 'Larry Hughes', 1998],
#  ['9', 'Dirk Nowitzki', 1998],
#  ['10', 'Paul Pierce', 1998],
#  ['11', 'Bonzi Wells', 1998],
#  ['12', 'Michael Doleac', 1998],
#  ['13', 'Keon Clark', 1998],
#  ['14', 'Michael Dickerson', 1998],
#  ['15', 'Matt Harpring', 1998],
#  ['16', 'Bryce Drew', 1998],
#  ['17', 'Rasho Nesterović', 1998],
#  ['18', 'Mirsad Türkcan', 1998],
#  ['19', 'Pat Garrity', 1998],
#  ['20', 'Roshown McLeod', 1998],
#  ['21', 'Ricky Davis', 1998],
#  ['22', 'Brian Skinner', 1998],
#  ['23', 'Tyronn Lue', 1998],
#  ['24', 'Felipe López', 1998],
#  ['25', 'Al Harrington', 1998],
#  ['26', 'Sam Jacobson', 1998],
#  ['27', 'Vladimir Stepania', 1998],
#  ['28', 'Corey Benjamin', 1998],
#  ['29', 'Nazr Mohammed', 1998],
#  ['30', 'Ansu Sesay', 1998],
#  ['31', 'Ruben Patterson', 1998],
#  ['32', 'Rashard Lewis', 1998],
#  ['33', 'Jelani McCoy', 1998],
#  ['34', 'Shammond Williams', 1998],
#  ['35', 'Bruno Šundov', 1998],
#  ['36', 'Jerome James', 1998],
#  ['37', 'Casey Shaw', 1998],
#  ['38', 'DeMarco Johnson', 1998],
#  ['39', 'Rafer Alston', 1998],
#  ['40', 'Korleone Young', 1998],
#  ['41', 'Cuttino Mobley', 1998],
#  ['42', 'Miles Simon', 1998],
#  ['43', 'Jahidi White', 1998],
#  ['44', 'Sean Marks', 1998],
#  ['45', 'Toby Bailey', 1998],
#  ['46', 'Andrae Patterson', 1998],
#  ['47', 'Tyson Wheeler', 1998],
#  ['48', 'Ryan Stack', 1998],
#  ['49', 'Cory Carr', 1998],
#  ['50', 'Andrew Betts', 1998],
#  ['51', 'Corey Brewer', 1998],
#  ['52', 'Derrick Dial', 1998],
#  ['53', 'Greg Buckner', 1998],
#  ['54', 'Tremaine Fowlkes', 1998],
#  ['55', 'Ryan Bowen', 1998],
#  ['56', 'J.R. Henderson', 1998],
#  ['57', 'Torraye Braggs', 1998],
#  ['58', 'Maceo Baston', 1998],
#  ['1', 'Elton Brand', 1999],
#  ['2', 'Steve Francis', 1999],
#  ['3', 'Baron Davis', 1999],
#  ['4', 'Lamar Odom', 1999],
#  ['5', 'Jonathan Bender', 1999],
#  ['6', 'Wally Szczerbiak', 1999],
#  ['7', 'Richard Hamilton', 1999],
#  ['8', 'Andre Miller', 1999],
#  ['9', 'Shawn Marion', 1999],
#  ['10', 'Jason Terry', 1999],
#  ['11', 'Trajan Langdon', 1999],
#  ['12', 'Aleksandar Radojević', 1999],
#  ['13', 'Corey Maggette', 1999],
#  ['14', 'William Avery', 1999],
#  ['15', 'Frederic Weis', 1999],
#  ['16', 'Metta World Peace', 1999],
#  ['17', 'Cal Bowdler', 1999],
#  ['18', 'James Posey', 1999],
#  ['19', 'Quincy Lewis', 1999],
#  ['20', 'Dion Glover', 1999],
#  ['21', 'Jeff Foster', 1999],
#  ['22', 'Kenny Thomas', 1999],
#  ['23', 'Devean George', 1999],
#  ['24', 'Andrei Kirilenko', 1999],
#  ['25', 'Tim James', 1999],
#  ['26', 'Vonteego Cummings', 1999],
#  ['27', 'Jumaine Jones', 1999],
#  ['28', 'Scott Padgett', 1999],
#  ['29', 'Leon Smith', 1999],
#  ['30', 'John Celestand', 1999],
#  ['31', 'Rico Hill', 1999],
#  ['32', 'Michael Ruffin', 1999],
#  ['33', 'Chris Herren', 1999],
#  ['34', 'Evan Eschmeyer', 1999],
#  ['35', 'Calvin Booth', 1999],
#  ['36', 'Wang Zhizhi', 1999],
#  ['37', 'Obinna Ekezie', 1999],
#  ['38', 'Laron Profit', 1999],
#  ['39', 'A.J. Bramlett', 1999],
#  ['40', 'Gordan Giriček', 1999],
#  ['41', 'Francisco Elson', 1999],
#  ['42', 'Louis Bullock', 1999],
#  ['43', 'Lee Nailon', 1999],
#  ['44', 'Tyrone Washington', 1999],
#  ['45', 'Ryan Robertson', 1999],
#  ['46', 'J.R. Koch', 1999],
#  ['47', 'Todd MacCulloch', 1999],
#  ['48', 'Galen Young', 1999],
#  ['49', 'Lari Ketner', 1999],
#  ['50', 'Venson Hamilton', 1999],
#  ['51', 'Antwain Smith', 1999],
#  ['52', 'Roberto Bergersen', 1999],
#  ['53', 'Rodney Buford', 1999],
#  ['54', 'Melvin Levett', 1999],
#  ['55', 'Kris Clack', 1999],
#  ['56', 'Tim Young', 1999],
#  ['57', 'Manu Ginóbili', 1999],
#  ['58', 'Eddie Lucas', 1999],
#  ['1', 'Kenyon Martin', 2000],
#  ['2', 'Stromile Swift', 2000],
#  ['3', 'Darius Miles', 2000],
#  ['4', 'Marcus Fizer', 2000],
#  ['5', 'Mike Miller', 2000],
#  ['6', 'DerMarr Johnson', 2000],
#  ['7', 'Chris Mihm', 2000],
#  ['8', 'Jamal Crawford', 2000],
#  ['9', 'Joel Przybilla', 2000],
#  ['10', 'Keyon Dooling', 2000],
#  ['11', 'Jérôme Moïso', 2000],
#  ['12', 'Etan Thomas', 2000],
#  ['13', 'Courtney Alexander', 2000],
#  ['14', 'Mateen Cleaves', 2000],
#  ['15', 'Jason Collier', 2000],
#  ['16', 'Hedo Türkoğlu', 2000],
#  ['17', 'Desmond Mason', 2000],
#  ['18', 'Quentin Richardson', 2000],
#  ['19', 'Jamaal Magloire', 2000],
#  ['20', 'Speedy Claxton', 2000],
#  ['21', 'Morris Peterson', 2000],
#  ['22', 'Donnell Harvey', 2000],
#  ['23', 'DeShawn Stevenson', 2000],
#  ['24', 'Dalibor Bagarić', 2000],
#  ['25', 'Jake Tsakalidis', 2000],
#  ['26', "Mamadou N'Diaye", 2000],
#  ['27', 'Primož Brezec', 2000],
#  ['28', 'Erick Barkley', 2000],
#  ['29', 'Mark Madsen', 2000],
#  ['30', 'Marko Jarić', 2000],
#  ['31', 'Dan Langhi', 2000],
#  ['32', 'A.J. Guyton', 2000],
#  ['33', 'Jake Voskuhl', 2000],
#  ['34', 'Khalid El-Amin', 2000],
#  ['35', 'Mike Smith', 2000],
#  ['36', 'Soumaila Samake', 2000],
#  ['37', 'Eddie House', 2000],
#  ['38', 'Eduardo Nájera', 2000],
#  ['39', 'Lavor Postell', 2000],
#  ['40', 'Hanno Möttölä', 2000],
#  ['41', 'Chris Carrawell', 2000],
#  ['42', 'Olumide Oyedeji', 2000],
#  ['43', 'Michael Redd', 2000],
#  ['44', 'Brian Cardinal', 2000],
#  ['45', 'Jabari Smith', 2000],
#  ['46', 'DeeAndre Hulett', 2000],
#  ['47', 'Josip Sesar', 2000],
#  ['48', 'Mark Karcher', 2000],
#  ['49', 'Jason Hart', 2000],
#  ['50', 'Kaniel Dickens', 2000],
#  ['51', 'Igor Rakočević', 2000],
#  ['52', 'Ernest Brown', 2000],
#  ['53', 'Dan McClintock', 2000],
#  ['54', 'Cory Hightower', 2000],
#  ['55', 'Chris Porter', 2000],
#  ['56', 'Jaquay Walls', 2000],
#  ['57', 'Scoonie Penn', 2000],
#  ['58', 'Pete Mickeal', 2000],
#  ['1', 'Kwame Brown', 2001],
#  ['2', 'Tyson Chandler', 2001],
#  ['3', 'Pau Gasol', 2001],
#  ['4', 'Eddy Curry', 2001],
#  ['5', 'Jason Richardson', 2001],
#  ['6', 'Shane Battier', 2001],
#  ['7', 'Eddie Griffin', 2001],
#  ['8', 'DeSagana Diop', 2001],
#  ['9', 'Rodney White', 2001],
#  ['10', 'Joe Johnson', 2001],
#  ['11', 'Kedrick Brown', 2001],
#  ['12', 'Vladimir Radmanović', 2001],
#  ['13', 'Richard Jefferson', 2001],
#  ['14', 'Troy Murphy', 2001],
#  ['15', 'Steven Hunter', 2001],
#  ['16', 'Kirk Haston', 2001],
#  ['17', 'Michael Bradley', 2001],
#  ['18', 'Jason Collins', 2001],
#  ['19', 'Zach Randolph', 2001],
#  ['20', 'Brendan Haywood', 2001],
#  ['21', 'Joseph Forte', 2001],
#  ['22', 'Jeryl Sasser', 2001],
#  ['23', 'Brandon Armstrong', 2001],
#  ['24', 'Raül López', 2001],
#  ['25', 'Gerald Wallace', 2001],
#  ['26', 'Samuel Dalembert', 2001],
#  ['27', 'Jamaal Tinsley', 2001],
#  ['28', 'Tony Parker', 2001],
#  ['30', 'Trenton Hassell', 2001],
#  ['31', 'Gilbert Arenas', 2001],
#  ['32', 'Omar Cook', 2001],
#  ['33', 'Will Solomon', 2001],
#  ['34', 'Terence Morris', 2001],
#  ['35', 'Brian Scalabrine', 2001],
#  ['36', 'Jeff Trepagnier', 2001],
#  ['37', 'Damone Brown', 2001],
#  ['38', 'Mehmet Okur', 2001],
#  ['39', 'Michael Wright', 2001],
#  ['40', 'Earl Watson', 2001],
#  ['41', 'Jamison Brewer', 2001],
#  ['42', 'Bobby Simmons', 2001],
#  ['43', 'Eric Chenowith', 2001],
#  ['44', 'Kyle Hill', 2001],
#  ['45', 'Sean Lampley', 2001],
#  ['46', 'Loren Woods', 2001],
#  ['47', 'Ousmane Cisse', 2001],
#  ['48', 'Antonis Fotsis', 2001],
#  ['49', 'Ken Johnson', 2001],
#  ['50', 'Ruben Boumtje-Boumtje', 2001],
#  ['51', 'Alton Ford', 2001],
#  ['52', 'Andre Hutson', 2001],
#  ['53', 'Jarron Collins', 2001],
#  ['54', 'Kenny Satterfield', 2001],
#  ['55', 'Maurice Jeffers', 2001],
#  ['56', 'Robertas Javtokas', 2001],
#  ['57', 'Alvin Jones', 2001],
#  ['58', 'Bryan Bracey', 2001],
#  ['1', 'Yao Ming', 2002],
#  ['2', 'Jay Williams', 2002],
#  ['3', 'Mike Dunleavy', 2002],
#  ['4', 'Drew Gooden', 2002],
#  ['5', 'Nikoloz Tskitishvili', 2002],
#  ['6', 'Dajuan Wagner', 2002],
#  ['7', 'Nenê Hilário', 2002],
#  ['8', 'Chris Wilcox', 2002],
#  ['9', "Amar'e Stoudemire", 2002],
#  ['10', 'Caron Butler', 2002],
#  ['11', 'Jared Jeffries', 2002],
#  ['12', 'Melvin Ely', 2002],
#  ['13', 'Marcus Haislip', 2002],
#  ['14', 'Fred Jones', 2002],
#  ['15', 'Boštjan Nachbar', 2002],
#  ['16', 'Jiří Welsch', 2002],
#  ['17', 'Juan Dixon', 2002],
#  ['18', 'Curtis Borchardt', 2002],
#  ['19', 'Ryan Humphrey', 2002],
#  ['20', 'Kareem Rush', 2002],
#  ['21', 'Qyntel Woods', 2002],
#  ['22', 'Casey Jacobsen', 2002],
#  ['23', 'Tayshaun Prince', 2002],
#  ['24', 'Nenad Krstić', 2002],
#  ['25', 'Frank Williams', 2002],
#  ['26', 'John Salmons', 2002],
#  ['27', 'Chris Jefferies', 2002],
#  ['28', 'Dan Dickau', 2002],
#  ['30', 'Steve Logan', 2002],
#  ['31', 'Roger Mason', 2002],
#  ['32', 'Robert Archibald', 2002],
#  ['33', 'Vincent Yarbrough', 2002],
#  ['34', 'Dan Gadzuric', 2002],
#  ['35', 'Carlos Boozer', 2002],
#  ['36', 'Milos Vujanic', 2002],
#  ['37', 'David Andersen', 2002],
#  ['38', 'Tito Maddox', 2002],
#  ['39', 'Rod Grizzard', 2002],
#  ['40', 'Juan Carlos Navarro', 2002],
#  ['41', 'Mario Kasun', 2002],
#  ['42', 'Ronald Murray', 2002],
#  ['43', 'Jason Jennings', 2002],
#  ['44', 'Lonny Baxter', 2002],
#  ['45', 'Sam Clancy', 2002],
#  ['46', 'Matt Barnes', 2002],
#  ['47', 'Jamal Sampson', 2002],
#  ['48', 'Chris Owens', 2002],
#  ['49', 'Peter Fehse', 2002],
#  ['50', 'Darius Songaila', 2002],
#  ['51', 'Federico Kammerichs', 2002],
#  ['52', 'Marcus Taylor', 2002],
#  ['53', 'Rasual Butler', 2002],
#  ['54', 'Tamar Slay', 2002],
#  ['55', 'Mladen Sekularac', 2002],
#  ['56', 'Luis Scola', 2002],
#  ['57', 'Randy Holcomb', 2002],
#  ['58', 'Corsley Edwards', 2002],
#  ['1', 'LeBron James', 2003],
#  ['2', 'Darko Miličić', 2003],
#  ['3', 'Carmelo Anthony', 2003],
#  ['4', 'Chris Bosh', 2003],
#  ['5', 'Dwyane Wade', 2003],
#  ['6', 'Chris Kaman', 2003],
#  ['7', 'Kirk Hinrich', 2003],
#  ['8', 'T.J. Ford', 2003],
#  ['9', 'Mike Sweetney', 2003],
#  ['10', 'Jarvis Hayes', 2003],
#  ['11', 'Mickaël Piétrus', 2003],
#  ['12', 'Nick Collison', 2003],
#  ['13', 'Marcus Banks', 2003],
#  ['14', 'Luke Ridnour', 2003],
#  ['15', 'Reece Gaines', 2003],
#  ['16', 'Troy Bell', 2003],
#  ['17', 'Žarko Čabarkapa', 2003],
#  ['18', 'David West', 2003],
#  ['19', 'Sasha Pavlović', 2003],
#  ['20', 'Dahntay Jones', 2003],
#  ['21', 'Boris Diaw', 2003],
#  ['22', 'Zoran Planinić', 2003],
#  ['23', 'Travis Outlaw', 2003],
#  ['24', 'Brian Cook', 2003],
#  ['25', 'Carlos Delfino', 2003],
#  ['26', 'Ndudi Ebi', 2003],
#  ['27', 'Kendrick Perkins', 2003],
#  ['28', 'Leandro Barbosa', 2003],
#  ['29', 'Josh Howard', 2003],
#  ['30', 'Maciej Lampe', 2003],
#  ['31', 'Jason Kapono', 2003],
#  ['32', 'Luke Walton', 2003],
#  ['33', 'Jerome Beasley', 2003],
#  ['34', 'Sofoklis Schortsanitis', 2003],
#  ['35', 'Szymon Szewczyk', 2003],
#  ['36', 'Mario Austin', 2003],
#  ['37', 'Travis Hansen', 2003],
#  ['38', 'Steve Blake', 2003],
#  ['39', 'Slavko Vraneš', 2003],
#  ['40', 'Derrick Zimmerman', 2003],
#  ['41', 'Willie Green', 2003],
#  ['42', 'Zaza Pachulia', 2003],
#  ['43', 'Keith Bogans', 2003],
#  ['44', 'Malick Badiane', 2003],
#  ['45', 'Matt Bonner', 2003],
#  ['46', 'Sani Bečirovič', 2003],
#  ['47', 'Mo Williams', 2003],
#  ['48', 'James Lang', 2003],
#  ['49', 'James Jones', 2003],
#  ['50', 'Paccelis Morlende', 2003],
#  ['51', 'Kyle Korver', 2003],
#  ['52', 'Remon Van de Hare', 2003],
#  ['53', 'Tommy Smith', 2003],
#  ['54', 'Nedžad Sinanović', 2003],
#  ['55', 'Rick Rickert', 2003],
#  ['56', 'Brandon Hunter', 2003],
#  ['57', 'Xue Yuyang', 2003],
#  ['58', 'Andreas Glyniadakis', 2003],
#  ['1', 'Dwight Howard', 2004],
#  ['2', 'Emeka Okafor', 2004],
#  ['3', 'Ben Gordon', 2004],
#  ['4', 'Shaun Livingston', 2004],
#  ['5', 'Devin Harris', 2004],
#  ['6', 'Josh Childress', 2004],
#  ['7', 'Luol Deng', 2004],
#  ['8', 'Rafael Araújo', 2004],
#  ['9', 'Andre Iguodala', 2004],
#  ['10', 'Luke Jackson', 2004],
#  ['11', 'Andris Biedriņš', 2004],
#  ['12', 'Robert Swift', 2004],
#  ['13', 'Sebastian Telfair', 2004],
#  ['14', 'Kris Humphries', 2004],
#  ['15', 'Al Jefferson', 2004],
#  ['16', 'Kirk Snyder', 2004],
#  ['17', 'Josh Smith', 2004],
#  ['18', 'J.R. Smith', 2004],
#  ['19', 'Dorell Wright', 2004],
#  ['20', 'Jameer Nelson', 2004],
#  ['21', 'Pavel Podkolzin', 2004],
#  ['22', 'Viktor Khryapa', 2004],
#  ['23', 'Sergei Monia', 2004],
#  ['24', 'Delonte West', 2004],
#  ['25', 'Tony Allen', 2004],
#  ['26', 'Kevin Martin', 2004],
#  ['27', 'Sasha Vujačić', 2004],
#  ['28', 'Beno Udrih', 2004],
#  ['29', 'David Harrison', 2004],
#  ['30', 'Anderson Varejão', 2004],
#  ['31', 'Jackson Vroman', 2004],
#  ['32', 'Peter John Ramos', 2004],
#  ['33', 'Lionel Chalmers', 2004],
#  ['34', 'Donta Smith', 2004],
#  ['35', 'Andre Emmett', 2004],
#  ['36', 'Antonio Burks', 2004],
#  ['37', 'Royal Ivey', 2004],
#  ['38', 'Chris Duhon', 2004],
#  ['39', 'Albert Miralles', 2004],
#  ['40', 'Justin Reed', 2004],
#  ['41', 'David Young', 2004],
#  ['42', 'Viktor Sanikidze', 2004],
#  ['43', 'Trevor Ariza', 2004],
#  ['44', 'Tim Pickett', 2004],
#  ['45', 'Bernard Robinson', 2004],
#  ['46', 'Ha Seung-Jin', 2004],
#  ['47', 'Pape Sow', 2004],
#  ['48', 'Ricky Minard', 2004],
#  ['49', 'Sergei Lishouk', 2004],
#  ['50', 'Vassilis Spanoulis', 2004],
#  ['51', 'Christian Drejer', 2004],
#  ['52', 'Romain Sato', 2004],
#  ['53', 'Matt Freije', 2004],
#  ['54', 'Rickey Paulding', 2004],
#  ['55', 'Luis Flores', 2004],
#  ['56', 'Marcus Douthit', 2004],
#  ['57', 'Sergei Karaulov', 2004],
#  ['58', 'Blake Stepp', 2004],
#  ['59', 'Rashad Wright', 2004],
#  ['1', 'Andrew Bogut', 2005],
#  ['2', 'Marvin Williams', 2005],
#  ['3', 'Deron Williams', 2005],
#  ['4', 'Chris Paul', 2005],
#  ['5', 'Raymond Felton', 2005],
#  ['6', 'Martell Webster', 2005],
#  ['7', 'Charlie Villanueva', 2005],
#  ['8', 'Channing Frye', 2005],
#  ['9', 'Ike Diogu', 2005],
#  ['10', 'Andrew Bynum', 2005],
#  ['11', 'Fran Vázquez', 2005],
#  ['12', 'Yaroslav Korolev', 2005],
#  ['13', 'Sean May', 2005],
#  ['14', 'Rashad McCants', 2005],
#  ['15', 'Antoine Wright', 2005],
#  ['16', 'Joey Graham', 2005],
#  ['17', 'Danny Granger', 2005],
#  ['18', 'Gerald Green', 2005],
#  ['19', 'Hakim Warrick', 2005],
#  ['20', 'Julius Hodge', 2005],
#  ['21', 'Nate Robinson', 2005],
#  ['22', 'Jarrett Jack', 2005],
#  ['23', 'Francisco García', 2005],
#  ['24', 'Luther Head', 2005],
#  ['25', 'Johan Petro', 2005],
#  ['26', 'Jason Maxiell', 2005],
#  ['27', 'Linas Kleiza', 2005],
#  ['28', 'Ian Mahinmi', 2005],
#  ['29', 'Wayne Simien', 2005],
#  ['30', 'David Lee', 2005],
#  ['31', 'Salim Stoudamire', 2005],
#  ['32', 'Daniel Ewing', 2005],
#  ['33', 'Brandon Bass', 2005],
#  ['34', 'C.J. Miles', 2005],
#  ['35', 'Ricky Sanchez', 2005],
#  ['36', 'Ersan İlyasova', 2005],
#  ['37', 'Ronny Turiaf', 2005],
#  ['38', 'Travis Diener', 2005],
#  ['39', 'Von Wafer', 2005],
#  ['40', 'Monta Ellis', 2005],
#  ['41', 'Roko Ukić', 2005],
#  ['42', 'Chris Taft', 2005],
#  ['43', 'Mile Ilić', 2005],
#  ['44', 'Martynas Andriuškevičius', 2005],
#  ['45', 'Lou Williams', 2005],
#  ['46', 'Erazem Lorbek', 2005],
#  ['47', 'Bracey Wright', 2005],
#  ['48', 'Mickaël Gelabale', 2005],
#  ['49', 'Andray Blatche', 2005],
#  ['50', 'Ryan Gomes', 2005],
#  ['51', 'Robert Whaley', 2005],
#  ['52', 'Axel Hervelle', 2005],
#  ['53', 'Orien Greene', 2005],
#  ['54', 'Dijon Thompson', 2005],
#  ['55', 'Lawrence Roberts', 2005],
#  ['56', 'Amir Johnson', 2005],
#  ['57', 'Marcin Gortat', 2005],
#  ['58', 'Uroš Slokar', 2005],
#  ['59', 'Cenk Akyol', 2005],
#  ['60', 'Alex Acker', 2005],
#  ['1', 'Andrea Bargnani', 2006],
#  ['2', 'LaMarcus Aldridge', 2006],
#  ['3', 'Adam Morrison', 2006],
#  ['4', 'Tyrus Thomas', 2006],
#  ['5', 'Shelden Williams', 2006],
#  ['6', 'Brandon Roy', 2006],
#  ['7', 'Randy Foye', 2006],
#  ['8', 'Rudy Gay', 2006],
#  ['9', "Patrick O'Bryant", 2006],
#  ['10', 'Mouhamed Sene', 2006],
#  ['11', 'J.J. Redick', 2006],
#  ['12', 'Hilton Armstrong', 2006],
#  ['13', 'Thabo Sefolosha', 2006],
#  ['14', 'Ronnie Brewer', 2006],
#  ['15', 'Cedric Simmons', 2006],
#  ['16', 'Rodney Carney', 2006],
#  ['17', 'Shawne Williams', 2006],
#  ['18', 'Oleksiy Pecherov', 2006],
#  ['19', 'Quincy Douby', 2006],
#  ['20', 'Renaldo Balkman', 2006],
#  ['21', 'Rajon Rondo', 2006],
#  ['22', 'Marcus Williams', 2006],
#  ['23', 'Josh Boone', 2006],
#  ['24', 'Kyle Lowry', 2006],
#  ['25', 'Shannon Brown', 2006],
#  ['26', 'Jordan Farmar', 2006],
#  ['27', 'Sergio Rodríguez', 2006],
#  ['28', 'Maurice Ager', 2006],
#  ['29', 'Mardy Collins', 2006],
#  ['30', 'Joel Freeland', 2006],
#  ['31', 'James White', 2006],
#  ['32', 'Steve Novak', 2006],
#  ['33', 'Solomon Jones', 2006],
#  ['34', 'Paul Davis', 2006],
#  ['35', 'P.J. Tucker', 2006],
#  ['36', 'Craig Smith', 2006],
#  ['37', 'Bobby Jones', 2006],
#  ['38', 'Kosta Perović', 2006],
#  ['39', 'David Noel', 2006],
#  ['40', 'Denham Brown', 2006],
#  ['41', 'James Augustine', 2006],
#  ['42', 'Daniel Gibson', 2006],
#  ['43', 'Marcus Vinicius', 2006],
#  ['44', 'Lior Eliyahu', 2006],
#  ['45', 'Alexander Johnson', 2006],
#  ['46', 'Dee Brown', 2006],
#  ['47', 'Paul Millsap', 2006],
#  ['48', 'Vladimir Veremeenko', 2006],
#  ['49', 'Leon Powe', 2006],
#  ['50', 'Ryan Hollins', 2006],
#  ['51', 'Cheikh Samb', 2006],
#  ['52', 'Guillermo Díaz', 2006],
#  ['53', 'Yotam Halperin', 2006],
#  ['54', 'Hassan Adams', 2006],
#  ['55', 'Ejike Ugboaja', 2006],
#  ['56', 'Edin Bavčić', 2006],
#  ['57', 'Loukas Mavrokefalidis', 2006],
#  ['58', 'J.R. Pinnock', 2006],
#  ['59', 'Damir Markota', 2006],
#  ['60', 'Will Blalock', 2006],
#  ['1', 'Greg Oden', 2007],
#  ['2', 'Kevin Durant', 2007],
#  ['3', 'Al Horford', 2007],
#  ['4', 'Mike Conley', 2007],
#  ['5', 'Jeff Green', 2007],
#  ['6', 'Yi Jianlian', 2007],
#  ['7', 'Corey Brewer', 2007],
#  ['8', 'Brandan Wright', 2007],
#  ['9', 'Joakim Noah', 2007],
#  ['10', 'Spencer Hawes', 2007],
#  ['11', 'Acie Law', 2007],
#  ['12', 'Thaddeus Young', 2007],
#  ['13', 'Julian Wright', 2007],
#  ['14', 'Al Thornton', 2007],
#  ['15', 'Rodney Stuckey', 2007],
#  ['16', 'Nick Young', 2007],
#  ['17', 'Sean Williams', 2007],
#  ['18', 'Marco Belinelli', 2007],
#  ['19', 'Javaris Crittenton', 2007],
#  ['20', 'Jason Smith', 2007],
#  ['21', 'Daequan Cook', 2007],
#  ['22', 'Jared Dudley', 2007],
#  ['23', 'Wilson Chandler', 2007],
#  ['24', 'Rudy Fernández', 2007],
#  ['25', 'Morris Almond', 2007],
#  ['26', 'Aaron Brooks', 2007],
#  ['27', 'Arron Afflalo', 2007],
#  ['28', 'Tiago Splitter', 2007],
#  ['29', 'Alando Tucker', 2007],
#  ['30', 'Petteri Koponen', 2007],
#  ['31', 'Carl Landry', 2007],
#  ['32', 'Gabe Pruitt', 2007],
#  ['33', 'Marcus Williams', 2007],
#  ['34', 'Nick Fazekas', 2007],
#  ['35', 'Glen Davis', 2007],
#  ['36', 'Jermareo Davidson', 2007],
#  ['37', 'Josh McRoberts', 2007],
#  ['38', 'Kyrylo Fesenko', 2007],
#  ['39', 'Stanko Barać', 2007],
#  ['40', 'Sun Yue', 2007],
#  ['41', 'Chris Richard', 2007],
#  ['42', 'Derrick Byars', 2007],
#  ['43', 'Adam Haluska', 2007],
#  ['44', 'Reyshawn Terry', 2007],
#  ['45', 'Jared Jordan', 2007],
#  ['46', 'Stéphane Lasme', 2007],
#  ['47', 'Dominic McGuire', 2007],
#  ['48', 'Marc Gasol', 2007],
#  ['49', 'Aaron Gray', 2007],
#  ['50', 'Renaldas Seibutis', 2007],
#  ['51', 'JamesOn Curry', 2007],
#  ['52', 'Taurean Green', 2007],
#  ['53', 'Demetris Nichols', 2007],
#  ['54', 'Brad Newley', 2007],
#  ['55', 'Herbert Hill', 2007],
#  ['56', 'Ramon Sessions', 2007],
#  ['57', 'Sammy Mejia', 2007],
#  ['58', 'Georgios Printezis', 2007],
#  ['59', 'D.J. Strawberry', 2007],
#  ['60', 'Milovan Raković', 2007],
#  ['1', 'Derrick Rose', 2008],
#  ['2', 'Michael Beasley', 2008],
#  ['3', 'O.J. Mayo', 2008],
#  ['4', 'Russell Westbrook', 2008],
#  ['5', 'Kevin Love', 2008],
#  ['6', 'Danilo Gallinari', 2008],
#  ['7', 'Eric Gordon', 2008],
#  ['8', 'Joe Alexander', 2008],
#  ['9', 'D.J. Augustin', 2008],
#  ['10', 'Brook Lopez', 2008],
#  ['11', 'Jerryd Bayless', 2008],
#  ['12', 'Jason Thompson', 2008],
#  ['13', 'Brandon Rush', 2008],
#  ['14', 'Anthony Randolph', 2008],
#  ['15', 'Robin Lopez', 2008],
#  ['16', 'Marreese Speights', 2008],
#  ['17', 'Roy Hibbert', 2008],
#  ['18', 'JaVale McGee', 2008],
#  ['19', 'J.J. Hickson', 2008],
#  ['20', 'Alexis Ajinça', 2008],
#  ['21', 'Ryan Anderson', 2008],
#  ['22', 'Courtney Lee', 2008],
#  ['23', 'Kosta Koufos', 2008],
#  ['24', 'Serge Ibaka', 2008],
#  ['25', 'Nicolas Batum', 2008],
#  ['26', 'George Hill', 2008],
#  ['27', 'Darrell Arthur', 2008],
#  ['28', 'Donté Greene', 2008],
#  ['29', 'D.J. White', 2008],
#  ['30', 'J.R. Giddens', 2008],
#  ['31', 'Nikola Peković', 2008],
#  ['32', 'Walter Sharpe', 2008],
#  ['33', 'Joey Dorsey', 2008],
#  ['34', 'Mario Chalmers', 2008],
#  ['35', 'DeAndre Jordan', 2008],
#  ['36', 'Ömer Aşık', 2008],
#  ['37', 'Luc Mbah a Moute', 2008],
#  ['38', 'Kyle Weaver', 2008],
#  ['39', 'Sonny Weems', 2008],
#  ['40', 'Chris Douglas-Roberts', 2008],
#  ['41', 'Nathan Jawai', 2008],
#  ['42', 'Sean Singletary', 2008],
#  ['43', 'Patrick Ewing', 2008],
#  ['44', 'Ante Tomić', 2008],
#  ['45', 'Goran Dragić', 2008],
#  ['46', 'Trent Plaisted', 2008],
#  ['47', 'Henry Walker', 2008],
#  ['48', 'Malik Hairston', 2008],
#  ['49', 'Richard Hendrix', 2008],
#  ['50', 'DeVon Hardin', 2008],
#  ['51', 'Shan Foster', 2008],
#  ['52', 'Darnell Jackson', 2008],
#  ['53', 'Tadija Dragićević', 2008],
#  ['54', 'Maarty Leunen', 2008],
#  ['55', 'Mike Taylor', 2008],
#  ['56', 'Sasha Kaun', 2008],
#  ['57', 'James Gist', 2008],
#  ['58', 'Joe Crawford', 2008],
#  ['59', 'Deron Washington', 2008],
#  ['60', 'Semih Erden', 2008],
#  ['1', 'Blake Griffin', 2009],
#  ['2', 'Hasheem Thabeet', 2009],
#  ['3', 'James Harden', 2009],
#  ['4', 'Tyreke Evans', 2009],
#  ['5', 'Ricky Rubio', 2009],
#  ['6', 'Jonny Flynn', 2009],
#  ['7', 'Stephen Curry', 2009],
#  ['8', 'Jordan Hill', 2009],
#  ['9', 'DeMar DeRozan', 2009],
#  ['10', 'Brandon Jennings', 2009],
#  ['11', 'Terrence Williams', 2009],
#  ['12', 'Gerald Henderson', 2009],
#  ['13', 'Tyler Hansbrough', 2009],
#  ['14', 'Earl Clark', 2009],
#  ['15', 'Austin Daye', 2009],
#  ['16', 'James Johnson', 2009],
#  ['17', 'Jrue Holiday', 2009],
#  ['18', 'Ty Lawson', 2009],
#  ['19', 'Jeff Teague', 2009],
#  ['20', 'Eric Maynor', 2009],
#  ['21', 'Darren Collison', 2009],
#  ['22', 'Victor Claver', 2009],
#  ['23', 'Omri Casspi', 2009],
#  ['24', 'Byron Mullens', 2009],
#  ['25', 'Rodrigue Beaubois', 2009],
#  ['26', 'Taj Gibson', 2009],
#  ['27', 'DeMarre Carroll', 2009],
#  ['28', 'Wayne Ellington', 2009],
#  ['29', 'Toney Douglas', 2009],
#  ['30', 'Christian Eyenga', 2009],
#  ['31', 'Jeff Ayres', 2009],
#  ['32', 'Jermaine Taylor', 2009],
#  ['33', 'Dante Cunningham', 2009],
#  ['34', 'Sergio Llull', 2009],
#  ['35', 'DaJuan Summers', 2009],
#  ['36', 'Sam Young', 2009],
#  ['37', 'DeJuan Blair', 2009],
#  ['38', 'Jon Brockman', 2009],
#  ['39', 'Jonas Jerebko', 2009],
#  ['40', 'Derrick Brown', 2009],
#  ['41', 'Jodie Meeks', 2009],
#  ['42', 'Patrick Beverley', 2009],
#  ['43', 'Marcus Thornton', 2009],
#  ['44', 'Chase Budinger', 2009],
#  ['45', 'Nick Calathes', 2009],
#  ['46', 'Danny Green', 2009],
#  ['47', 'Henk Norel', 2009],
#  ['48', 'Taylor Griffin', 2009],
#  ['49', 'Sergiy Gladyr', 2009],
#  ['50', 'Goran Suton', 2009],
#  ['51', 'Jack McClinton', 2009],
#  ['52', 'A.J. Price', 2009],
#  ['53', 'Nando De Colo', 2009],
#  ['54', 'Robert Vaden', 2009],
#  ['55', 'Patty Mills', 2009],
#  ['56', 'Ahmad Nivins', 2009],
#  ['57', 'Emir Preldžić', 2009],
#  ['58', 'Lester Hudson', 2009],
#  ['59', 'Chinemelu Elonu', 2009],
#  ['60', 'Robert Dozier', 2009],
#  ['1', 'John Wall', 2010],
#  ['2', 'Evan Turner', 2010],
#  ['3', 'Derrick Favors', 2010],
#  ['4', 'Wesley Johnson', 2010],
#  ['5', 'DeMarcus Cousins', 2010],
#  ['6', 'Ekpe Udoh', 2010],
#  ['7', 'Greg Monroe', 2010],
#  ['8', 'Al-Farouq Aminu', 2010],
#  ['9', 'Gordon Hayward', 2010],
#  ['10', 'Paul George', 2010],
#  ['11', 'Cole Aldrich', 2010],
#  ['12', 'Xavier Henry', 2010],
#  ['13', 'Ed Davis', 2010],
#  ['14', 'Patrick Patterson', 2010],
#  ['15', 'Larry Sanders', 2010],
#  ['16', 'Luke Babbitt', 2010],
#  ['17', 'Kevin Séraphin', 2010],
#  ['18', 'Eric Bledsoe', 2010],
#  ['19', 'Avery Bradley', 2010],
#  ['20', 'James Anderson', 2010],
#  ['21', 'Craig Brackins', 2010],
#  ['22', 'Elliot Williams', 2010],
#  ['23', 'Trevor Booker', 2010],
#  ['24', 'Damion James', 2010],
#  ['25', 'Dominique Jones', 2010],
#  ['26', 'Quincy Pondexter', 2010],
#  ['27', 'Jordan Crawford', 2010],
#  ['28', 'Greivis Vásquez', 2010],
#  ['29', 'Daniel Orton', 2010],
#  ['30', 'Lazar Hayward', 2010],
#  ['31', 'Tibor Pleiß', 2010],
#  ['32', 'Dexter Pittman', 2010],
#  ['33', 'Hassan Whiteside', 2010],
#  ['34', 'Armon Johnson', 2010],
#  ['35', 'Nemanja Bjelica', 2010],
#  ['36', 'Terrico White', 2010],
#  ['37', 'Darington Hobson', 2010],
#  ['38', 'Andy Rautins', 2010],
#  ['39', 'Landry Fields', 2010],
#  ['40', 'Lance Stephenson', 2010],
#  ['41', 'Jarvis Varnado', 2010],
#  ['42', "Da'Sean Butler", 2010],
#  ['43', 'Devin Ebanks', 2010],
#  ['44', 'Jerome Jordan', 2010],
#  ['45', 'Paulo Prestes', 2010],
#  ['46', 'Gani Lawal', 2010],
#  ['47', 'Tiny Gallon', 2010],
#  ['48', 'Latavious Williams', 2010],
#  ['49', 'Ryan Richards', 2010],
#  ['50', 'Solomon Alabi', 2010],
#  ['51', 'Magnum Rolle', 2010],
#  ['52', 'Luke Harangody', 2010],
#  ['53', 'Pape Sy', 2010],
#  ['54', 'Willie Warren', 2010],
#  ['55', 'Jeremy Evans', 2010],
#  ['56', "Hamady N'Diaye", 2010],
#  ['57', 'Ryan Reid', 2010],
#  ['58', 'Derrick Caracter', 2010],
#  ['59', 'Stanley Robinson', 2010],
#  ['60', 'Dwayne Collins', 2010],
#  ['1', 'Kyrie Irving', 2011],
#  ['2', 'Derrick Williams', 2011],
#  ['3', 'Enes Kanter', 2011],
#  ['4', 'Tristan Thompson', 2011],
#  ['5', 'Jonas Valančiūnas', 2011],
#  ['6', 'Jan Veselý', 2011],
#  ['7', 'Bismack Biyombo', 2011],
#  ['8', 'Brandon Knight', 2011],
#  ['9', 'Kemba Walker', 2011],
#  ['10', 'Jimmer Fredette', 2011],
#  ['11', 'Klay Thompson', 2011],
#  ['12', 'Alec Burks', 2011],
#  ['13', 'Markieff Morris', 2011],
#  ['14', 'Marcus Morris', 2011],
#  ['15', 'Kawhi Leonard', 2011],
#  ['16', 'Nikola Vučević', 2011],
#  ['17', 'Iman Shumpert', 2011],
#  ['18', 'Chris Singleton', 2011],
#  ['19', 'Tobias Harris', 2011],
#  ['20', 'Donatas Motiejūnas', 2011],
#  ['21', 'Nolan Smith', 2011],
#  ['22', 'Kenneth Faried', 2011],
#  ['23', 'Nikola Mirotić', 2011],
#  ['24', 'Reggie Jackson', 2011],
#  ['25', 'MarShon Brooks', 2011],
#  ['26', 'Jordan Hamilton', 2011],
#  ['27', 'JaJuan Johnson', 2011],
#  ['28', 'Norris Cole', 2011],
#  ['29', 'Cory Joseph', 2011],
#  ['30', 'Jimmy Butler', 2011],
#  ['31', 'Bojan Bogdanović', 2011],
#  ['32', 'Justin Harper', 2011],
#  ['33', 'Kyle Singler', 2011],
#  ['34', 'Shelvin Mack', 2011],
#  ['35', 'Tyler Honeycutt', 2011],
#  ['36', 'Jordan Williams', 2011],
#  ['37', 'Trey Thompkins', 2011],
#  ['38', 'Chandler Parsons', 2011],
#  ['39', 'Jeremy Tyler', 2011],
#  ['40', 'Jon Leuer', 2011],
#  ['41', 'Darius Morris', 2011],
#  ['42', 'Dāvis Bertāns', 2011],
#  ['43', 'Malcolm Lee', 2011],
#  ['44', 'Charles Jenkins', 2011],
#  ['45', 'Josh Harrellson', 2011],
#  ['46', 'Andrew Goudelock', 2011],
#  ['47', 'Travis Leslie', 2011],
#  ['48', 'Keith Benson', 2011],
#  ['49', 'Josh Selby', 2011],
#  ['50', 'Lavoy Allen', 2011],
#  ['51', 'Jon Diebler', 2011],
#  ['52', 'Vernon Macklin', 2011],
#  ['53', 'DeAndre Liggins', 2011],
#  ['54', 'Milan Mačvan', 2011],
#  ['55', "E'Twaun Moore", 2011],
#  ['56', 'Chukwudiebere Maduabum', 2011],
#  ['57', 'Targuy Ngombo', 2011],
#  ['58', 'Ater Majok', 2011],
#  ['59', 'Ádám Hanga', 2011],
#  ['60', 'Isaiah Thomas', 2011],
#  ['1', 'Anthony Davis', 2012],
#  ['2', 'Michael Kidd-Gilchrist', 2012],
#  ['3', 'Bradley Beal', 2012],
#  ['4', 'Dion Waiters', 2012],
#  ['5', 'Thomas Robinson', 2012],
#  ['6', 'Damian Lillard', 2012],
#  ['7', 'Harrison Barnes', 2012],
#  ['8', 'Terrence Ross', 2012],
#  ['9', 'Andre Drummond', 2012],
#  ['10', 'Austin Rivers', 2012],
#  ['11', 'Meyers Leonard', 2012],
#  ['12', 'Jeremy Lamb', 2012],
#  ['13', 'Kendall Marshall', 2012],
#  ['14', 'John Henson', 2012],
#  ['15', 'Maurice Harkless', 2012],
#  ['16', 'Royce White', 2012],
#  ['17', 'Tyler Zeller', 2012],
#  ['18', 'Terrence Jones', 2012],
#  ['19', 'Andrew Nicholson', 2012],
#  ['20', 'Evan Fournier', 2012],
#  ['21', 'Jared Sullinger', 2012],
#  ['22', 'Fab Melo', 2012],
#  ['23', 'John Jenkins', 2012],
#  ['24', 'Jared Cunningham', 2012],
#  ['25', 'Tony Wroten', 2012],
#  ['26', 'Miles Plumlee', 2012],
#  ['27', 'Arnett Moultrie', 2012],
#  ['28', 'Perry Jones', 2012],
#  ['29', 'Marquis Teague', 2012],
#  ['30', 'Festus Ezeli', 2012],
#  ['31', 'Jeffery Taylor', 2012],
#  ['32', 'Tomáš Satoranský', 2012],
#  ['33', 'Bernard James', 2012],
#  ['34', 'Jae Crowder', 2012],
#  ['35', 'Draymond Green', 2012],
#  ['36', 'Orlando Johnson', 2012],
#  ['37', 'Quincy Acy', 2012],
#  ['38', 'Quincy Miller', 2012],
#  ['39', 'Khris Middleton', 2012],
#  ['40', 'Will Barton', 2012],
#  ['41', 'Tyshawn Taylor', 2012],
#  ['42', 'Doron Lamb', 2012],
#  ['43', 'Mike Scott', 2012],
#  ['44', 'Kim English', 2012],
#  ['45', 'Justin Hamilton', 2012],
#  ['46', 'Darius Miller', 2012],
#  ['47', 'Kevin Murphy', 2012],
#  ['48', 'Kostas Papanikolaou', 2012],
#  ['49', "Kyle O'Quinn", 2012],
#  ['50', 'İzzet Türkyılmaz', 2012],
#  ['51', 'Kris Joseph', 2012],
#  ['52', 'Ognjen Kuzmić', 2012],
#  ['53', 'Furkan Aldemir', 2012],
#  ['54', 'Tornike Shengelia', 2012],
#  ['55', 'Darius Johnson-Odom', 2012],
#  ['56', 'Tomislav Zubčić', 2012],
#  ['57', 'İlkan Karaman', 2012],
#  ['58', 'Robbie Hummel', 2012],
#  ['59', 'Marcus Denmon', 2012],
#  ['60', 'Robert Sacre', 2012],
#  ['1', 'Anthony Bennett', 2013],
#  ['2', 'Victor Oladipo', 2013],
#  ['3', 'Otto Porter', 2013],
#  ['4', 'Cody Zeller', 2013],
#  ['5', 'Alex Len', 2013],
#  ['6', 'Nerlens Noel', 2013],
#  ['7', 'Ben McLemore', 2013],
#  ['8', 'Kentavious Caldwell-Pope', 2013],
#  ['9', 'Trey Burke', 2013],
#  ['10', 'CJ McCollum', 2013],
#  ['11', 'Michael Carter-Williams', 2013],
#  ['12', 'Steven Adams', 2013],
#  ['13', 'Kelly Olynyk', 2013],
#  ['14', 'Shabazz Muhammad', 2013],
#  ['15', 'Giannis Antetokounmpo', 2013],
#  ['16', 'Lucas Nogueira', 2013],
#  ['17', 'Dennis Schröder', 2013],
#  ['18', 'Shane Larkin', 2013],
#  ['19', 'Sergey Karasev', 2013],
#  ['20', 'Tony Snell', 2013],
#  ['21', 'Gorgui Dieng', 2013],
#  ['22', 'Mason Plumlee', 2013],
#  ['23', 'Solomon Hill', 2013],
#  ['24', 'Tim Hardaway', 2013],
#  ['25', 'Reggie Bullock', 2013],
#  ['26', 'Andre Roberson', 2013],
#  ['27', 'Rudy Gobert', 2013],
#  ['28', 'Livio Jean-Charles', 2013],
#  ['29', 'Archie Goodwin', 2013],
#  ['30', 'Nemanja Nedović', 2013],
#  ['31', 'Allen Crabbe', 2013],
#  ['32', 'Álex Abrines', 2013],
#  ['33', 'Carrick Felix', 2013],
#  ['34', 'Isaiah Canaan', 2013],
#  ['35', 'Glen Rice', 2013],
#  ['36', 'Ray McCallum', 2013],
#  ['37', 'Tony Mitchell', 2013],
#  ['38', 'Nate Wolters', 2013],
#  ['39', 'Jeff Withey', 2013],
#  ['40', 'Grant Jerrett', 2013],
#  ['41', 'Jamaal Franklin', 2013],
#  ['42', 'Pierre Jackson', 2013],
#  ['43', 'Ricky Ledo', 2013],
#  ['44', 'Mike Muscala', 2013],
#  ['45', 'Marko Todorović', 2013],
#  ['46', 'Erick Green', 2013],
#  ['47', 'Raul Neto', 2013],
#  ['48', 'Ryan Kelly', 2013],
#  ['49', 'Erik Murphy', 2013],
#  ['50', 'James Ennis', 2013],
#  ['51', 'Romero Osby', 2013],
#  ['52', 'Lorenzo Brown', 2013],
#  ['53', 'Colton Iverson', 2013],
#  ['54', 'Arsalan Kazemi', 2013],
#  ['55', 'Joffrey Lauvergne', 2013],
#  ['56', 'Peyton Siva', 2013],
#  ['57', 'Alex Oriakhi', 2013],
#  ['58', 'Deshaun Thomas', 2013],
#  ['59', 'Bojan Dubljević', 2013],
#  ['60', 'Jānis Timma', 2013],
#  ['1', 'Andrew Wiggins', 2014],
#  ['2', 'Jabari Parker', 2014],
#  ['3', 'Joel Embiid', 2014],
#  ['4', 'Aaron Gordon', 2014],
#  ['5', 'Dante Exum', 2014],
#  ['6', 'Marcus Smart', 2014],
#  ['7', 'Julius Randle', 2014],
#  ['8', 'Nik Stauskas', 2014],
#  ['9', 'Noah Vonleh', 2014],
#  ['10', 'Elfrid Payton', 2014],
#  ['11', 'Doug McDermott', 2014],
#  ['12', 'Dario Šarić', 2014],
#  ['13', 'Zach LaVine', 2014],
#  ['14', 'T.J. Warren', 2014],
#  ['15', 'Adreian Payne', 2014],
#  ['16', 'Jusuf Nurkić', 2014],
#  ['17', 'James Young', 2014],
#  ['18', 'Tyler Ennis', 2014],
#  ['19', 'Gary Harris', 2014],
#  ['20', 'Bruno Caboclo', 2014],
#  ['21', 'Mitch McGary', 2014],
#  ['22', 'Jordan Adams', 2014],
#  ['23', 'Rodney Hood', 2014],
#  ['24', 'Shabazz Napier', 2014],
#  ['25', 'Clint Capela', 2014],
#  ['26', 'P.J. Hairston', 2014],
#  ['27', 'Bogdan Bogdanović', 2014],
#  ['28', 'C.J. Wilcox', 2014],
#  ['29', 'Josh Huestis', 2014],
#  ['30', 'Kyle Anderson', 2014],
#  ['31', 'Damien Inglis', 2014],
#  ['32', 'K.J. McDaniels', 2014],
#  ['33', 'Joe Harris', 2014],
#  ['34', 'Cleanthony Early', 2014],
#  ['35', 'Jarnell Stokes', 2014],
#  ['36', "Johnny O'Bryant", 2014],
#  ['37', 'DeAndre Daniels', 2014],
#  ['38', 'Spencer Dinwiddie', 2014],
#  ['39', 'Jerami Grant', 2014],
#  ['40', 'Glenn Robinson', 2014],
#  ['41', 'Nikola Jokić', 2014],
#  ['42', 'Nick Johnson', 2014],
#  ['43', 'Edy Tavares', 2014],
#  ['44', 'Markel Brown', 2014],
#  ['45', 'Dwight Powell', 2014],
#  ['46', 'Jordan Clarkson', 2014],
#  ['47', 'Russ Smith', 2014],
#  ['48', 'Lamar Patterson', 2014],
#  ['49', 'Cameron Bairstow', 2014],
#  ['50', 'Alec Brown', 2014],
#  ['51', 'Thanasis Antetokounmpo', 2014],
#  ['52', 'Vasilije Micić', 2014],
#  ['53', 'Alessandro Gentile', 2014],
#  ['54', 'Nemanja Dangubić', 2014],
#  ['55', 'Semaj Christon', 2014],
#  ...]

# %%
EV()
# Out:
# [['1', '76.9'],
#  ['2', '63.9'],
#  ['3', '56.2'],
#  ['4', '50.8'],
#  ['5', '46.6'],
#  ['6', '43.2'],
#  ['7', '40.3'],
#  ['8', '37.8'],
#  ['9', '35.6'],
#  ['10', '33.6'],
#  ['11', '31.8'],
#  ['12', '30.2'],
#  ['13', '28.7'],
#  ['14', '27.3'],
#  ['15', '26.0'],
#  ['16', '24.8'],
#  ['17', '23.6'],
#  ['18', '22.6'],
#  ['19', '21.5'],
#  ['20', '20.6'],
#  ['21', '19.7'],
#  ['22', '18.8'],
#  ['23', '18.0'],
#  ['24', '17.2'],
#  ['25', '16.4'],
#  ['26', '15.6'],
#  ['27', '14.9'],
#  ['28', '14.3'],
#  ['29', '13.6'],
#  ['30', '13.0'],
#  ['31', '12.3'],
#  ['32', '11.7'],
#  ['33', '11.2'],
#  ['34', '10.6'],
#  ['35', '10.1'],
#  ['36', '9.5'],
#  ['37', '9.0'],
#  ['38', '8.5'],
#  ['39', '8.0'],
#  ['40', '7.5'],
#  ['41', '7.1'],
#  ['42', '6.6'],
#  ['43', '6.2'],
#  ['44', '5.8'],
#  ['45', '5.3'],
#  ['46', '4.9'],
#  ['47', '4.5'],
#  ['48', '4.1'],
#  ['49', '3.7'],
#  ['50', '3.4'],
#  ['51', '3.0'],
#  ['52', '2.6'],
#  ['53', '2.3'],
#  ['54', '1.9'],
#  ['55', '1.6'],
#  ['56', '1.2'],
#  ['57', '0.9'],
#  ['58', '0.6'],
#  ['59', '0.2'],
#  ['60', '-0.1']]

# %% [markdown]
# ### Store Data to Disk
#
# Raw data looks pretty good, so we just have to store them each into a csv file in the folder

# %%
import csv


## Export list of lists to csv files
## Original data 
with open('ori_position_1.csv', 'w', newline = '') as myfile:
    wr = csv.writer(myfile, quoting = csv.QUOTE_ALL)
    wr.writerow(('player_name', 'position'))
    wr.writerows(records[0])

with open('ori_FGA.csv', 'w', newline = '') as myfile:
    wr = csv.writer(myfile, quoting = csv.QUOTE_ALL)
    wr.writerow(('player_name', 'field_goal_attempt', 'games_played', 'minutes_played_per_game', 'year'))
    wr.writerows(records[1])

with open('ori_USG.csv', 'w', newline = '') as myfile:
    wr = csv.writer(myfile, quoting = csv.QUOTE_ALL)
    wr.writerow(('player_name', 'usage_percentage', 'games_played', 'total_minutes_played', 'year'))
    wr.writerows(records[2])

with open('ori_salary.csv', 'w', newline = '') as myfile:
    wr = csv.writer(myfile, quoting = csv.QUOTE_ALL)
    wr.writerow(('player_name', 'salary', 'year'))
    wr.writerows(records[3])

with open('ori_draft.csv', 'w', newline = '') as myfile:
    wr = csv.writer(myfile, quoting = csv.QUOTE_ALL)
    wr.writerow(('pick_rank', 'player_name', 'year'))
    wr.writerows(records[4])

with open('ori_EV.csv', 'w', newline = '') as myfile:
    wr = csv.writer(myfile, quoting = csv.QUOTE_ALL)
    wr.writerow(('pick_rank', 'expected_value'))
    wr.writerows(records[5])

# %% [markdown]
# ### Model Data
#
# Here we take raw data from the csv files we created in the last step adn pass them into pandas data frames.
# Here we are conducting some data cleaning
#
# 1. In the 2 players position dataset, we make sure the posiitons are only G, F and C. They will be merged into 1 position dataset
#
#
# 2. There could be players that only play less than 15 games per season and less than 15 minutes per game but with very high FGA or USG%. They are noise in the data for this analysis. Therefore, we are dropping players in such category to make they don't skew this result.
#
#
# 3. To quantify the value or importance of rankings in the draft, we replace the Daft position for each player with ev of the ranking.
#
#
# 4. last step is to merge FGA, USG, Salary and Draft EV with the postion data. For example, one of the modeled dataframe should look likie this. Say for FGA, a player in there should have the name with his correpsonding position and FGA in the season. The whole FGA dataframe contains such information from 1998 to 2018 season.
#
# Modeled dataframe will be output as csv files as well like the raw data

# %%
import pandas as pd


## Convert stored data into DataFrames
ori_position_1_df = pd.read_csv('ori_position_1.csv')
ori_position_2_df = pd.read_csv('ori_position_2.csv')
ori_FGA_df = pd.read_csv('ori_FGA.csv')
ori_USG_df = pd.read_csv('ori_USG.csv')
ori_salary_df = pd.read_csv('ori_salary.csv')
ori_draft_df = pd.read_csv('ori_draft.csv')
ori_EV_df = pd.read_csv('ori_EV.csv')


## Make a copy of the original data frame
position_1_df = ori_position_1_df.copy()
FGA_df = ori_FGA_df.copy()
USG_df = ori_USG_df.copy()
salary_df = ori_salary_df.copy()
draft_df = ori_draft_df.copy()
EV_df = ori_EV_df.copy()


## Data Cleaning
## combine SF and PF as F (forwards), SG and PG as G (guards)
position_1_df = position_1_df.replace(['SF', 'PF'], 'F')
position_1_df = position_1_df.replace(['SG', 'PG'], 'G')

## Clean alternative position csv
position_2_df = ori_position_2_df.copy()
position_2_df = position_2_df[['player_name', 'position']]
position_2_df['player_name'] = position_2_df['player_name'].apply(lambda x: x.split('\\')[0])
position_2_df['player_name'] = position_2_df['player_name'].apply(lambda x: x.strip('*'))
position_2_df = position_2_df.drop_duplicates(subset = 'player_name', keep='first')
position_2_df['position'] = position_2_df['position'].apply(lambda x: x.split('-')[0])
position_2_df = position_2_df.replace(['SF', 'PF'], 'F')
position_2_df = position_2_df.replace(['SG', 'PG'], 'G')

## delete players that have games played less than 30 and minutes played per game less than 15 minutes
FGA_df.games_played = FGA_df.games_played.astype(int)
FGA_df = FGA_df[FGA_df.games_played >= 30]
FGA_df.minutes_played_per_game = FGA_df.minutes_played_per_game.astype(float)
FGA_df = FGA_df[FGA_df.minutes_played_per_game >= 15.0]
#FGA_df.info()
FGA_df = FGA_df.drop('games_played', axis = 1)
FGA_df = FGA_df.drop('minutes_played_per_game', axis = 1)

# ## delete players that have games played less than 30 and total minutes played less than 15 minutes
USG_df.games_played = USG_df.games_played.astype(int)
USG_df = USG_df[USG_df.games_played >= 30]
USG_df.total_minutes_played = USG_df.total_minutes_played.astype(float)
USG_df = USG_df[USG_df.total_minutes_played >= 450.0]
#USG_df.info()
USG_df = USG_df.drop('games_played', axis = 1)
USG_df = USG_df.drop('total_minutes_played', axis = 1)

## Sort FGA DataFrame according to its top 100 values group by years
FGA_df.field_goal_attempt = FGA_df.field_goal_attempt.astype(float)
FGA_df = FGA_df.groupby(['year']).apply(lambda x: x.sort_values(["field_goal_attempt"], ascending = False)).reset_index(drop=True)
#FGA_df = FGA_df.groupby(['year']).head(100)

## Sort USG DataFrame according to its top 100 values group by years 
USG_df.usage_percentage = USG_df.usage_percentage.astype(float)
USG_df = USG_df.groupby(['year']).apply(lambda x: x.sort_values(["usage_percentage"], ascending = False)).reset_index(drop=True)
#USG_df = USG_df.groupby(['year']).head(200)

## Sort salary DataFrame according to its top 100 values group by years
salary_df.salary = salary_df.salary.astype(int)
salary_df = salary_df.groupby(['year']).apply(lambda x: x.sort_values(["salary"], ascending = False)).reset_index(drop=True)
salary_df = salary_df.groupby(['year']).head(100)

## Integrate draft DataFrame and EV DataFrame and sort the new DataFrame according to its top 30 values group by year
new_draft_df = pd.merge(draft_df, EV_df, on = 'pick_rank')
new_draft_df = new_draft_df.drop(['pick_rank'], axis = 1)
new_draft_df = new_draft_df[['player_name', 'expected_value', 'year']]
new_draft_df.expected_value = new_draft_df.expected_value.astype(float)
new_draft_df = new_draft_df.groupby(['year']).apply(lambda x: x.sort_values(["expected_value"], ascending = False)).reset_index(drop=True)
#new_draft_df = new_draft_df.groupby(['year']).head(30)


## Integrate all data into four data frames: position vs FGA, position vs USG, position vs salary, position vs draft
## Integrate position_1_df and position_2_df into position_df
#position_df = position_1_df.join(position_2_df, on = ['player_name', 'position'])
#position_df = position_1_df.join(position_2_df.set_index('position'), on='position')

position_df = position_1_df.append(position_2_df)


## position vs FGA
position_FGA_df = pd.merge(position_df, FGA_df, on = 'player_name')
position_FGA_df = position_FGA_df.drop('player_name', axis = 1)
position_FGA_df = position_FGA_df[['position', 'field_goal_attempt', 'year']]
position_FGA_df = position_FGA_df.groupby(['year']).apply(lambda x: x.sort_values(["field_goal_attempt"], ascending = False)).reset_index(drop=True)

## position vs USG
position_USG_df = pd.merge(position_df, USG_df, on = 'player_name')
position_USG_df = position_USG_df.drop('player_name', axis = 1)
position_USG_df = position_USG_df[['position', 'usage_percentage', 'year']]
position_USG_df = position_USG_df.groupby(['year']).apply(lambda x: x.sort_values(["usage_percentage"], ascending = False)).reset_index(drop=True)

## position vs salary
position_salary_df = pd.merge(position_df, salary_df, on = 'player_name')
position_salary_df = position_salary_df.drop('player_name', axis = 1)
position_salary_df = position_salary_df[['position', 'salary', 'year']]
position_salary_df = position_salary_df.groupby(['year']).apply(lambda x: x.sort_values(["salary"], ascending = False)).reset_index(drop=True)

## position vs draft
position_draft_df = pd.merge(position_df, new_draft_df, on = 'player_name')
position_draft_df = position_draft_df.drop(['player_name'], axis = 1)
position_draft_df = position_draft_df[['position', 'expected_value', 'year']]
position_draft_df = position_draft_df.groupby(['year']).apply(lambda x: x.sort_values(["expected_value"], ascending = False)).reset_index(drop=True)


## Keep grouping data frames, make relationships between position vs average FGA, average USG, average salary, and average expected value from draft
## position vs average FGA
position_avgFGA_df = position_FGA_df.groupby(['year', 'position'], as_index = False).mean()
position_avgFGA_df = position_avgFGA_df.pivot(index = 'year', columns = 'position', values = 'field_goal_attempt')
## position vs average USG
position_avgUSG_df = position_USG_df.groupby(['year', 'position'], as_index = False).mean()
position_avgUSG_df = position_avgUSG_df.pivot(index = 'year', columns = 'position', values = 'usage_percentage')
## position vs average salary
position_avgsalary_df = position_salary_df.groupby(['year', 'position'], as_index = False).mean()
position_avgsalary_df = position_avgsalary_df.pivot(index = 'year', columns = 'position', values = 'salary')
## position vs average expected value from draft
position_avgdraft_df = position_draft_df.groupby(['year', 'position'], as_index = False).sum()
position_avgdraft_df = position_avgdraft_df.pivot(index = 'year', columns = 'position', values = 'expected_value')


## Export DataFrame to csv files
## First update after data cleaning

# position_1_df.to_csv('position_1.csv')
# position_2_df.to_csv('position_2.csv')
# FGA_df.to_csv('FGA.csv')
# USG_df.to_csv('USG.csv')
# salary_df.to_csv('salary.csv')
# draft_df.to_csv('draft.csv')
# EV_df.to_csv('EV.csv')
# new_draft_df.to_csv('new_draft.csv')



## Second update after combining tabels 

# position_df.to_csv('position.csv')
# position_FGA_df.to_csv('position_FGA.csv')
# position_USG_df.to_csv('position_USG.csv')
# position_salary_df.to_csv('position_salary.csv')
# position_draft_df.to_csv('position_draft.csv')



## Thrid update after reshaping tables

position_avgFGA_df.to_csv('position_avgFGA.csv')
position_avgUSG_df.to_csv('position_avgUSG.csv')
position_avgsalary_df.to_csv('position_avgsalary.csv')
position_avgdraft_df.to_csv('position_sumdraft.csv')

# %% [markdown]
# ## Visualization and Final Conclusion

# %%
import matplotlib.pyplot as plt
import numpy as np

fig, axes = plt.subplots(2, 2, figsize = (25, 10))
fig.subplots_adjust(wspace = 0.2, hspace = 0.5)

## Set up legend
positions = ['C', 'F', 'G']

for i in range(3):
    axes[0, 0].plot(position_avgFGA_df.iloc[:,i], label=positions[i])
    axes[0, 1].plot(position_avgUSG_df.iloc[:,i], label=positions[i])
    axes[1, 0].plot(position_avgsalary_df.iloc[:,i], label=positions[i])
    axes[1, 1].plot(position_avgdraft_df.iloc[:,i], label=positions[i])

## Upper left, visualize players' average field goal attempts vs position over year
axes[0, 0].legend()
axes[0, 0].set_title('Average Field Goal Attempt vs Position over year')
axes[0, 0].set_xlabel('year')
axes[0, 0].set_ylabel('average FGA')
x_ticks_1 = np.arange(1998, 2019, 1)
y_ticks_1 = np.arange(6, 11, 0.5)
axes[0, 0].set_xticks(x_ticks_1)
axes[0, 0].set_yticks(y_ticks_1)

## Upper right, visualize players' average usage percentange vs position over year 
axes[0, 1].legend()
axes[0, 1].set_title('Average Usage Percentange vs Position over year')
axes[0, 1].set_xlabel('year')
axes[0, 1].set_ylabel('average USG%')
x_ticks_2 = np.arange(1998, 2019, 1)
y_ticks_2 = np.arange(15, 22, 1)
axes[0, 1].set_xticks(x_ticks_2)
axes[0, 1].set_yticks(y_ticks_2)

## Bottom left, visualize players' average salaries vs position over year 
axes[1, 0].legend()
axes[1, 0].set_title('Average Salary vs Position over year')
axes[1, 0].set_xlabel('year')
axes[1, 0].set_ylabel('average salary')
x_ticks_3 = np.arange(1998, 2019, 1)
y_ticks_3 = np.arange(5000000, 25000000, 1000000)
axes[1, 0].set_xticks(x_ticks_3)
axes[1, 0].set_yticks(y_ticks_3)

## Bottom right, visualize players' expected values of draft vs position over year 
axes[1, 1].legend()
axes[1, 1].set_title('Sum of Draft Eexpected Value vs Position over year')
axes[1, 1].set_xlabel('year')
axes[1, 1].set_ylabel('average EV')
x_ticks_4 = np.arange(1998, 2019, 1)
y_ticks_4 = np.arange(100, 1000, 100)
axes[1, 1].set_xticks(x_ticks_4)
axes[1, 1].set_yticks(y_ticks_4)

## Export figure 
#fig.show()
fig.savefig('Visualization')

# %% [markdown]
# ### Conclusion
#
# The original assumption is partially confirmed as the result shows that it is the guards that are dominating the league in recent years and centers faded. However, since 1998, centers were already not as dominant as guards and forwards, and their dominance was dropping during the year 2000 to 2008 period. Centers are making a small comeback after year 2008 and 2009, but they are still down. An interesting finding is that forwards were at the level with guards before around year 2008 but started to go down after that time and on the same dominance level as centers till today.
